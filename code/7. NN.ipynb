# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import os

# Mount Google Drive
drive.mount('/content/drive')

# Replace 'df.csv' with the actual path to your file in Google Drive if it's not in the root directory
file_path = '/content/drive/My Drive/data.xlsx'

# 读取数据，time列解析为日期但不设为索引
df1 = pd.read_excel(file_path, parse_dates=['time'])

display(df1.head(6))
print(df1.dtypes)

# 去掉df最后5行
df = df1[:-5]
print(f"删除后数据形状：{df.shape}")
# Out:
# Mounted at /content/drive
#         time  ln_gdp_sa  ln_gdp_seasonal_factor  dln_gdp_sa  city_mean_light  \
# 0 2008-01-01   7.477351               -0.078167         NaN        12.553247
# 1 2008-04-01   7.498888               -0.053482    0.021537        13.280818
# 2 2008-07-01   7.529319                0.074136    0.030430        13.191190
# 3 2008-10-01   7.554362                0.074117    0.025043        13.697327
# 4 2009-01-01   7.565732               -0.103575    0.011370        12.906907
# 5 2009-04-01   7.599352               -0.054602    0.033620        13.654976
#
#    region_mean_light   ln_city  ln_region      GDP    ln_gdp       pc1  \
# 0           0.953015  2.529979  -0.048125  1634.65  7.399184 -0.930701
# 1           0.986813  2.586321  -0.013275  1711.98  7.445406 -0.810655
# 2           0.972665  2.579549  -0.027716  2005.11  7.603454  0.061691
# 3           1.017466  2.617201   0.017316  2055.92  7.628479  0.236543
# 4           0.980980  2.557763  -0.019203  1740.90  7.462157  0.327092
# 5           1.015769  2.614104   0.015646  1890.79  7.544750 -0.003495
#
#         pc2       pc3      dpc2  quarter  dln_city  dln_region
# 0  0.185353  0.281816       NaN        1       NaN         NaN
# 1  0.314787  0.089018  0.129435        2  0.056341    0.034850
# 2  0.290403  0.006259 -0.024384        3 -0.006772   -0.014441
# 3  0.422133 -0.012724  0.131730        4  0.037652    0.045031
# 4  0.505859 -0.071886  0.083726        1 -0.059438   -0.036519
# 5  0.485063 -0.394677 -0.020796        2  0.056341    0.034850
# time                      datetime64[ns]
# ln_gdp_sa                        float64
# ln_gdp_seasonal_factor           float64
# dln_gdp_sa                       float64
# city_mean_light                  float64
# region_mean_light                float64
# ln_city                          float64
# ln_region                        float64
# GDP                              float64
# ln_gdp                           float64
# pc1                              float64
# pc2                              float64
# pc3                              float64
# dpc2                             float64
# quarter                            int64
# dln_city                         float64
# dln_region                       float64
# dtype: object
# 删除后数据形状：(59, 17)

# %%
# 1. 数据准备
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

target = 'dln_gdp_sa'
base_vars = ['pc1', 'pc3', 'dpc2', 'dln_city', 'dln_region']
max_lag = 4

# 创建滞后变量
data = df.copy()
candidates = []

for var in base_vars + [target]:
    for lag in range(1, max_lag + 1):
        lag_name = f'{var}_lag{lag}'
        data[lag_name] = df[var].shift(lag)
        candidates.append(lag_name)

print(f"候选变量数: {len(candidates)}")
print(f"原始数据: {data.shape}")

# 处理缺失值
data_clean1 = data.dropna()
print(f"清理后数据: {data_clean1.shape}")
print(f"删除了 {data.shape[0] - data_clean1.shape[0]} 行缺失值")

# 归一化处理
scaler_X = MinMaxScaler(feature_range=(-1, 1))
scaler_y = MinMaxScaler(feature_range=(-1, 1))

cols_to_keep_and_scale = candidates + [target] + ['time']
data_to_scale = data_clean1[cols_to_keep_and_scale].copy()

# 对特征列进行归一化
feature_cols_to_scale = candidates
data_to_scale[feature_cols_to_scale] = scaler_X.fit_transform(data_to_scale[feature_cols_to_scale])

# 对目标列进行归一化
target_col_to_scale = [target]
data_to_scale[target_col_to_scale] = scaler_y.fit_transform(data_to_scale[target_col_to_scale])

data_clean = data_to_scale
print("数据归一化完成")
# Out:
# 候选变量数: 24
# 原始数据: (59, 41)
# 清理后数据: (54, 41)
# 删除了 5 行缺失值
# 数据归一化完成

# %%
import joblib
import os
from google.colab import drive

drive.mount('/content/drive')  # 确保Google Drive已挂载

scaler_save_path = '/content/drive/My Drive'
os.makedirs(scaler_save_path, exist_ok=True)

scaler_x_filename = os.path.join(scaler_save_path, 'scaler_X.joblib')
scaler_y_filename = os.path.join(scaler_save_path, 'scaler_y.joblib')

joblib.dump(scaler_X, scaler_x_filename)
joblib.dump(scaler_y, scaler_y_filename)
print(f"归一化器已保存")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 归一化器已保存

# %%
# Ensure data_clean1 is available from previous cells
if 'data_clean1' not in globals():
    print("错误：未找到 data_clean1 数据框。请确保您已运行数据加载和预处理代码。")
else:
    # Define the target variable column name
    target = 'dln_gdp_sa'

    # Define the list of independent variable (feature) column names
    # Exclude 'time' and the target column from the list of all columns
    independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

    # Check if the specified columns exist in data_clean1
    required_columns = [target] + independent_variables + ['time']
    if not all(col in data_clean1.columns for col in required_columns):
        missing_cols = [col for col in required_columns if col not in data_clean1.columns]
        print(f"错误：data_clean1 中缺少必需的列：{missing_cols}。请检查数据预处理步骤。")
    else:
        # Select the independent variables (features)
        X_data = data_clean1[independent_variables].copy()

        # Select the dependent variable (target)
        y_data = data_clean1[target].copy()

        # Optionally keep the time column separate
        time_data = data_clean1['time'].copy()

        print(f"已从 data_clean1 中创建自变量集 X_data ({X_data.shape}) 和因变量集 y_data ({y_data.shape})。")
        print(f"自变量列: {X_data.columns.tolist()}")
        print(f"因变量列: {target}")
        print(f"时间列已单独保留为 time_data ({time_data.shape})。")

        # Display the first few rows of the created datasets
        display("X_data head:", X_data.head())
        display("y_data head:", y_data.head())
        display("time_data head:", time_data.head())
# Out:
# 已从 data_clean1 中创建自变量集 X_data ((54, 16)) 和因变量集 y_data ((54,))。
# 自变量列: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
# 因变量列: dln_gdp_sa
# 时间列已单独保留为 time_data ((54,))。
# 'X_data head:'
#    pc3_lag4  dln_gdp_sa_lag1  dln_gdp_sa_lag4  dpc2_lag4  dln_region_lag3  \
# 5  0.089018         0.011370         0.021537   0.129435        -0.014441
# 6  0.006259         0.033620         0.030430  -0.024384         0.045031
# 7 -0.012724         0.026588         0.025043   0.131730        -0.036519
# 8 -0.071886         0.040039         0.011370   0.083726         0.034850
# 9 -0.394677         0.053382         0.033620  -0.020796        -0.014441
#
#    pc1_lag1  dln_city_lag1  dln_gdp_sa_lag3  dln_gdp_sa_lag2  dln_region_lag2  \
# 5  0.327092      -0.059438         0.030430         0.025043         0.045031
# 6 -0.003495       0.056341         0.025043         0.011370        -0.036519
# 7  0.160463      -0.006772         0.011370         0.033620         0.034850
# 8  0.214866       0.037652         0.033620         0.026588        -0.014441
# 9 -1.119556      -0.015751         0.026588         0.040039         0.045031
#
#    pc3_lag3  dln_city_lag2  dpc2_lag3  dpc2_lag1  pc1_lag4  pc3_lag1
# 5  0.006259       0.037652  -0.024384   0.083726 -0.810655 -0.071886
# 6 -0.012724      -0.059438   0.131730  -0.020796  0.061691 -0.394677
# 7 -0.071886       0.056341   0.083726  -0.300986  0.236543 -0.114024
# 8 -0.394677      -0.006772  -0.020796   0.096575  0.327092 -0.031341
# 9 -0.114024       0.037652  -0.300986  -0.144311 -0.003495  0.231504
# 'y_data head:'
# 5    0.033620
# 6    0.026588
# 7    0.040039
# 8    0.053382
# 9    0.049996
# Name: dln_gdp_sa, dtype: float64
# 'time_data head:'
# 5   2009-04-01
# 6   2009-07-01
# 7   2009-10-01
# 8   2010-01-01
# 9   2010-04-01
# Name: time, dtype: datetime64[ns]

# %%
# Define the target variable
target = 'dln_gdp_sa'

# Define the list of candidate independent variables
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# Check if the target column exists in data_clean1
if target not in data_clean1.columns:
    print(f"Error: Target column '{target}' not found in data_clean1.")
else:
    print(f"Target variable '{target}' is defined and exists in data_clean1.")

# Check if all candidate independent variable columns exist in data_clean1
missing_candidate_cols = [col for col in candidate_independent_variables if col not in data_clean1.columns]

if missing_candidate_cols:
    print(f"Error: Missing candidate independent variable columns in data_clean1: {missing_candidate_cols}")
else:
    print("All candidate independent variable columns exist in data_clean1.")
    print(f"Candidate independent variables: {candidate_independent_variables}")

# Display the first few rows and columns of data_clean1 for visual inspection
display("First 5 rows of data_clean1:", data_clean.head())
display("Columns in data_clean1:", data_clean.columns.tolist())
# Out:
# Target variable 'dln_gdp_sa' is defined and exists in data_clean1.
# All candidate independent variable columns exist in data_clean1.
# Candidate independent variables: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
# 'First 5 rows of data_clean1:'
#    pc1_lag1  pc1_lag2  pc1_lag3  pc1_lag4  pc3_lag1  pc3_lag2  pc3_lag3  \
# 5  0.379795  0.303054  0.154866 -0.584454 -0.088699  0.078325  0.131918
# 6  0.099620  0.379795  0.303054  0.154866 -1.000000 -0.088699  0.078325
# 7  0.238576  0.099620  0.379795  0.303054 -0.207664 -1.000000 -0.088699
# 8  0.284683  0.238576  0.099620  0.379795  0.025767 -0.207664 -1.000000
# 9 -0.846249  0.284683  0.238576  0.099620  0.767828  0.025767 -0.207664
#
#    pc3_lag4  dpc2_lag1  dpc2_lag2  ...  dln_region_lag1  dln_region_lag2  \
# 5  0.365562   0.614922   0.801469  ...        -0.040532         0.157725
# 6  0.131918   0.208738   0.614922  ...         0.132972        -0.040532
# 7  0.078325  -0.880110   0.208738  ...         0.013142         0.132972
# 8 -0.088699   0.664855  -0.880110  ...         0.157725         0.013142
# 9 -1.000000  -0.271255   0.664855  ...         0.555243         0.157725
#
#    dln_region_lag3  dln_region_lag4  dln_gdp_sa_lag1  dln_gdp_sa_lag2  \
# 5         0.013142         0.132972         0.170179         0.253089
# 6         0.157725         0.013142         0.305093         0.170179
# 7        -0.040532         0.157725         0.262455         0.305093
# 8         0.132972        -0.040532         0.344014         0.262455
# 9         0.013142         0.132972         0.424926         0.344014
#
#    dln_gdp_sa_lag3  dln_gdp_sa_lag4  dln_gdp_sa       time
# 5         0.285753         0.231828    0.305093 2009-04-01
# 6         0.253089         0.285753    0.262455 2009-07-01
# 7         0.170179         0.253089    0.344014 2009-10-01
# 8         0.305093         0.170179    0.424926 2010-01-01
# 9         0.262455         0.305093    0.404393 2010-04-01
#
# [5 rows x 26 columns]
# 'Columns in data_clean1:'
# ['pc1_lag1',
#  'pc1_lag2',
#  'pc1_lag3',
#  'pc1_lag4',
#  'pc3_lag1',
#  'pc3_lag2',
#  'pc3_lag3',
#  'pc3_lag4',
#  'dpc2_lag1',
#  'dpc2_lag2',
#  'dpc2_lag3',
#  'dpc2_lag4',
#  'dln_city_lag1',
#  'dln_city_lag2',
#  'dln_city_lag3',
#  'dln_city_lag4',
#  'dln_region_lag1',
#  'dln_region_lag2',
#  'dln_region_lag3',
#  'dln_region_lag4',
#  'dln_gdp_sa_lag1',
#  'dln_gdp_sa_lag2',
#  'dln_gdp_sa_lag3',
#  'dln_gdp_sa_lag4',
#  'dln_gdp_sa',
#  'time']

# %% [markdown]
# ## Define gru model architecture
#
# ### Subtask:
# Create a function to build the GRU model with specified layers, dropout, activation, and output shape.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_gru_model(input_shape, output_shape):
    """
    Builds a Sequential GRU model with specified architecture.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).
        output_shape (int): The number of units in the output layer.

    Returns:
        keras.src.engine.sequential.Sequential: Compiled GRU model.
    """
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh')) # Using tanh activation as requested
    model.compile(optimizer=Adam(), loss='mse')
    return model

print("GRU model building function defined.")
# Out:
# GRU model building function defined.

# %% [markdown]
# ## Implement rolling window cross-validation
#
# ### Subtask:
# Develop a function to generate training, validation, and testing sets using a rolling window approach with fixed sizes.

# %%
import numpy as np

def create_sliding_window_datasets(data, input_length, output_length, independent_variables, target):
    """
    Creates sliding window datasets for time series forecasting.

    Args:
        data (pd.DataFrame): The input data.
        input_length (int): The length of the input sequence (X).
        output_length (int): The length of the output sequence (y).
        independent_variables (list): A list of column names for the independent variables.
        target (str): The column name for the target variable.

    Returns:
        tuple: A tuple containing (X, y) where X is the input data and y is the target data.
    """
    X, y = [], []
    for i in range(len(data) - input_length - output_length + 1):
        # Extract the input sequence (X)
        X_sequence = data[independent_variables].iloc[i:(i + input_length)].values
        X.append(X_sequence)

        # Extract the output sequence (y)
        y_sequence = data[target].iloc[(i + input_length):(i + input_length + output_length)].values
        y.append(y_sequence)

    return np.array(X), np.array(y)

# Define the target variable
target = 'dln_gdp_sa'

# Define the list of candidate independent variables
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# Example usage with the defined variables and sliding window
input_length = 40
output_length = 5

# Initially use all candidate variables to create the full dataset for splitting
X_full, y_full = create_sliding_window_datasets(data_clean, input_length, output_length, candidate_independent_variables, target)

# Split the data into training and validation sets (8 samples for training, 2 for validation)
num_samples = X_full.shape[0]
num_train_samples = 8
num_val_samples = 2

if num_samples < num_train_samples + num_val_samples:
    print(f"Error: Not enough samples ({num_samples}) for the requested train/validation split ({num_train_samples}/{num_val_samples}).")
else:
    X_train_full = X_full[:num_train_samples]
    y_train_full = y_full[:num_train_samples]
    X_val_full = X_full[num_train_samples:num_train_samples + num_val_samples]
    y_val_full = y_full[num_train_samples:num_train_samples + num_val_samples]

    print(f"Created datasets with sliding window:")
    print(f"X_full shape: {X_full.shape}")
    print(f"y_full shape: {y_full.shape}")
    print(f"X_train_full shape: {X_train_full.shape}")
    print(f"y_train_full shape: {y_train_full.shape}")
    print(f"X_val_full shape: {X_val_full.shape}")
    print(f"y_val_full shape: {y_val_full.shape}")
# Out:
# Created datasets with sliding window:
# X_full shape: (10, 40, 16)
# y_full shape: (10, 5)
# X_train_full shape: (8, 40, 16)
# y_train_full shape: (8, 5)
# X_val_full shape: (2, 40, 16)
# y_val_full shape: (2, 5)

# %% [markdown]
# ## Implement forward selection and train GRU models
#
# ### Subtask:
# Implement the forward selection algorithm to iteratively add variables, train GRU models with different learning rates and a fixed random seed, evaluate performance using validation loss and Early Stopping, and save the best models at each step.

# %%
import tensorflow as tf
import numpy as np
import random
import joblib
import os
import pandas as pd
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# 确保可复现性
random_seeds = [1, 2]
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 定义GRU模型构建函数
def build_gru_model(input_shape, output_shape):
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh'))
    model.compile(optimizer=Adam(), loss='mse')
    return model

# 定义目标变量和候选自变量
target = 'dln_gdp_sa'
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# 滑动窗口参数
input_length = 40
output_length = 5

# 超参数
learning_rates = [0.01, 0.001]
epochs = 50
batch_size = 4
early_stopping_patience = 10
early_stopping_min_delta = 0.001

# 前向选择初始化
selected_variables = []
remaining_variables = candidate_independent_variables.copy()
forward_selection_results = []  # 存储结果表格

print("开始前向选择，使用多个随机种子...")
print(f"随机种子: {random_seeds}")

for step in range(7):
    best_variable_for_this_step = None
    best_avg_loss_for_this_step = float('inf')
    best_lr_for_this_step = None
    candidate_results = []  # 存储候选变量结果

    print(f"\n步骤 {step + 1}: 选择第 {len(selected_variables) + 1} 个变量")
    print(f"当前已选变量: {selected_variables}")
    print(f"剩余候选变量: {remaining_variables}")

    for candidate_variable in remaining_variables:
        current_variables = selected_variables + [candidate_variable]
        print(f"\n测试变量组合: {current_variables}")

        # 创建滑动窗口数据集
        X_full_current, y_full_current = create_sliding_window_datasets(
            data_clean, input_length, output_length, current_variables, target
        )

        num_samples_current = X_full_current.shape[0]
        num_train_samples_current = 8
        num_val_samples_current = 2

        if num_samples_current < num_train_samples_current + num_val_samples_current:
             print(f"跳过组合，样本不足 ({num_samples_current})")
             continue

        X_train_current = X_full_current[:num_train_samples_current]
        y_train_current = y_full_current[:num_train_samples_current]
        X_val_current = X_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]
        y_val_current = y_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]

        # 不同学习率训练
        for lr in learning_rates:
            print(f"  学习率: {lr}")
            seed_losses = []
            seed_models = {}
            seed_epochs = []

            for seed in random_seeds:
                # 设置种子
                np.random.seed(seed)
                tf.random.set_seed(seed)
                os.environ['PYTHONHASHSEED'] = str(seed)
                random.seed(seed)

                print(f"    种子 {seed}:")

                # 构建模型
                model = build_gru_model(input_shape=(input_length, len(current_variables)),
                                      output_shape=output_length)
                model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

                # 早停回调
                early_stopping = EarlyStopping(
                    monitor='val_loss',
                    patience=early_stopping_patience,
                    min_delta=early_stopping_min_delta,
                    restore_best_weights=True
                )

                # 训练模型
                history = model.fit(
                    X_train_current, y_train_current,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val_current, y_val_current),
                    callbacks=[early_stopping],
                    verbose=0
                )

                # 获取最佳验证损失和轮次
                min_val_loss = min(history.history['val_loss'])
                best_epoch = history.history['val_loss'].index(min_val_loss) + 1

                # 记录结果
                seed_losses.append(min_val_loss)
                seed_models[seed] = model
                seed_epochs.append(best_epoch)

                print(f"      验证损失: {min_val_loss:.4f} (轮次: {best_epoch})")

            # 计算平均损失
            avg_loss = np.mean(seed_losses)
            print(f"  平均验证损失: {avg_loss:.4f} (学习率 {lr})")

            # 存储候选结果
            candidate_results.append({
                'variable': candidate_variable,
                'lr': lr,
                'avg_loss': avg_loss,
                'seed_losses': seed_losses,
                'seed_epochs': seed_epochs,
                'seed_models': seed_models
            })

            # 检查是否最佳组合
            if avg_loss < best_avg_loss_for_this_step:
                best_avg_loss_for_this_step = avg_loss
                best_variable_for_this_step = candidate_variable
                best_lr_for_this_step = lr

                # 暂时保存最佳模型
                best_seed_idx = np.argmin(seed_losses)
                best_seed = random_seeds[best_seed_idx]
                best_model_for_step = seed_models[best_seed]

                temp_model_save_path = f'/content/drive/My Drive/GRU3temp_best_model_step_{step+1}.keras'
                best_model_for_step.save(temp_model_save_path)
                print(f"  临时保存步骤 {step+1} 最佳模型: '{candidate_variable}', 学习率 {lr}, 种子 {best_seed}")

    # 添加最佳变量到已选列表
    if best_variable_for_this_step:
        selected_variables.append(best_variable_for_this_step)
        remaining_variables.remove(best_variable_for_this_step)

        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print(f"选中变量: '{best_variable_for_this_step}'")
        print(f"最佳平均验证损失: {best_avg_loss_for_this_step:.4f}")
        print(f"最佳学习率: {best_lr_for_this_step}")
        print(f"当前已选变量: {selected_variables}")

        # 获取最佳候选结果
        best_candidate_data = [d for d in candidate_results
                              if d['variable'] == best_variable_for_this_step
                              and d['lr'] == best_lr_for_this_step][0]

        # 记录结果到表格
        step_result = {
            'Step': step + 1,
            'Variable number': len(selected_variables),
            'Selected Variables': ', '.join(selected_variables),
            'Best average Val Loss': best_avg_loss_for_this_step,
            'Best average LR': best_lr_for_this_step,
        }

        # 添加种子详细结果
        for i, seed in enumerate(random_seeds):
            step_result[f'seed {seed} Val Loss'] = best_candidate_data['seed_losses'][i]
            step_result[f'seed {seed} Epochs Used'] = best_candidate_data['seed_epochs'][i]

        forward_selection_results.append(step_result)

        # 保存最终模型（两个种子中MSE最低的）
        best_seed_idx = np.argmin(best_candidate_data['seed_losses'])
        best_seed = random_seeds[best_seed_idx]
        best_model = best_candidate_data['seed_models'][best_seed]

        # 修改：使用新命名规则 GRU3_{变量数量}
        final_model_name = f'GRU3_{len(selected_variables)}.keras'  # 修改点
        final_model_save_path = os.path.join('/content/drive/My Drive', final_model_name)
        best_model.save(final_model_save_path)
        print(f"已保存最优模型到Google Drive: '{final_model_name}' (seed {best_seed})")

    else:
        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print("本步骤无改进变量")
        break

print("\n前向选择完成")
print(f"最终选中变量: {selected_variables}")

# 保存结果表格
results_df = pd.DataFrame(forward_selection_results)
results_csv_path = os.path.join('/content/drive/My Drive', 'GRU3_results.csv')
results_df.to_csv(results_csv_path, index=False)
print(f"已保存前向选择结果表格到Google Drive: {results_csv_path}")

# 显示结果表格
print("\n前向选择详细结果:")
display(results_df)
# Out:
# 开始前向选择，使用多个随机种子...
# 随机种子: [1, 2]
#
# 步骤 1: 选择第 1 个变量
# 当前已选变量: []
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 20)
#     种子 2:
#       验证损失: 0.0025 (轮次: 14)
#   平均验证损失: 0.0025 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0029 (轮次: 50)
#     种子 2:
#       验证损失: 0.0064 (轮次: 50)
#   平均验证损失: 0.0046 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 17)
#     种子 2:
#       验证损失: 0.0035 (轮次: 25)
#   平均验证损失: 0.0030 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0071 (轮次: 50)
#     种子 2:
#       验证损失: 0.0098 (轮次: 50)
#   平均验证损失: 0.0085 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 19)
#     种子 2:
#       验证损失: 0.0030 (轮次: 10)
#   平均验证损失: 0.0027 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0081 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0074 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0033 (轮次: 7)
#     种子 2:
#       验证损失: 0.0042 (轮次: 44)
#   平均验证损失: 0.0037 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0184 (轮次: 50)
#   平均验证损失: 0.0138 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 7)
#     种子 2:
#       验证损失: 0.0025 (轮次: 18)
#   平均验证损失: 0.0022 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0051 (轮次: 50)
#     种子 2:
#       验证损失: 0.0053 (轮次: 50)
#   平均验证损失: 0.0052 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 13)
#     种子 2:
#       验证损失: 0.0022 (轮次: 34)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0121 (轮次: 50)
#     种子 2:
#       验证损失: 0.0157 (轮次: 50)
#   平均验证损失: 0.0139 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0028 (轮次: 6)
#     种子 2:
#       验证损失: 0.0028 (轮次: 28)
#   平均验证损失: 0.0028 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0042 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0059 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 15)
#     种子 2:
#       验证损失: 0.0033 (轮次: 12)
#   平均验证损失: 0.0027 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0104 (轮次: 50)
#     种子 2:
#       验证损失: 0.0091 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 19)
#     种子 2:
#       验证损失: 0.0030 (轮次: 30)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0070 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0072 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 7)
#     种子 2:
#       验证损失: 0.0023 (轮次: 21)
#   平均验证损失: 0.0020 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0042 (轮次: 50)
#     种子 2:
#       验证损失: 0.0051 (轮次: 50)
#   平均验证损失: 0.0046 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0027 (轮次: 12)
#     种子 2:
#       验证损失: 0.0022 (轮次: 14)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0035 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0046 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 6)
#     种子 2:
#       验证损失: 0.0035 (轮次: 19)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0033 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0045 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 8)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dpc2_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0103 (轮次: 50)
#     种子 2:
#       验证损失: 0.0090 (轮次: 50)
#   平均验证损失: 0.0096 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 8)
#     种子 2:
#       验证损失: 0.0029 (轮次: 19)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0075 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0079 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0051 (轮次: 21)
#     种子 2:
#       验证损失: 0.0044 (轮次: 23)
#   平均验证损失: 0.0047 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0129 (轮次: 50)
#     种子 2:
#       验证损失: 0.0161 (轮次: 50)
#   平均验证损失: 0.0145 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 21)
#     种子 2:
#       验证损失: 0.0023 (轮次: 22)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0058 (轮次: 50)
#     种子 2:
#       验证损失: 0.0080 (轮次: 50)
#   平均验证损失: 0.0069 (学习率 0.001)
#
# --- 步骤 1 结果 ---
# 选中变量: 'dpc2_lag3'
# 最佳平均验证损失: 0.0015
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3']
# 已保存最优模型到Google Drive: 'GRU3_1.keras' (seed 2)
#
# 步骤 2: 选择第 2 个变量
# 当前已选变量: ['dpc2_lag3']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dpc2_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0031 (轮次: 8)
#     种子 2:
#       验证损失: 0.0017 (轮次: 11)
#   平均验证损失: 0.0024 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0112 (轮次: 50)
#     种子 2:
#       验证损失: 0.0091 (轮次: 50)
#   平均验证损失: 0.0102 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0033 (轮次: 10)
#     种子 2:
#       验证损失: 0.0016 (轮次: 22)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0169 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0123 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 22)
#   平均验证损失: 0.0016 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0156 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 50)
#   平均验证损失: 0.0113 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0037 (轮次: 11)
#     种子 2:
#       验证损失: 0.0020 (轮次: 13)
#   平均验证损失: 0.0028 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0201 (轮次: 50)
#     种子 2:
#       验证损失: 0.0077 (轮次: 50)
#   平均验证损失: 0.0139 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 14)
#   平均验证损失: 0.0016 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0124 (轮次: 50)
#     种子 2:
#       验证损失: 0.0082 (轮次: 50)
#   平均验证损失: 0.0103 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0029 (轮次: 9)
#     种子 2:
#       验证损失: 0.0025 (轮次: 22)
#   平均验证损失: 0.0027 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0184 (轮次: 50)
#     种子 2:
#       验证损失: 0.0104 (轮次: 50)
#   平均验证损失: 0.0144 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0039 (轮次: 9)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0128 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0106 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 14)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0162 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0118 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 9)
#     种子 2:
#       验证损失: 0.0019 (轮次: 20)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0144 (轮次: 50)
#     种子 2:
#       验证损失: 0.0077 (轮次: 50)
#   平均验证损失: 0.0110 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 9)
#     种子 2:
#       验证损失: 0.0018 (轮次: 14)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0118 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 9)
#     种子 2:
#       验证损失: 0.0017 (轮次: 11)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0119 (轮次: 50)
#     种子 2:
#       验证损失: 0.0090 (轮次: 50)
#   平均验证损失: 0.0105 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0019 (轮次: 11)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0110 (轮次: 50)
#     种子 2:
#       验证损失: 0.0084 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 10)
#     种子 2:
#       验证损失: 0.0017 (轮次: 13)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0156 (轮次: 50)
#     种子 2:
#       验证损失: 0.0073 (轮次: 50)
#   平均验证损失: 0.0115 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 19)
#     种子 2:
#       验证损失: 0.0025 (轮次: 20)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0191 (轮次: 50)
#     种子 2:
#       验证损失: 0.0114 (轮次: 50)
#   平均验证损失: 0.0152 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0029 (轮次: 11)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0134 (轮次: 50)
#     种子 2:
#       验证损失: 0.0100 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# --- 步骤 2 结果 ---
# 选中变量: 'dln_region_lag3'
# 最佳平均验证损失: 0.0016
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3']
# 已保存最优模型到Google Drive: 'GRU3_2.keras' (seed 2)
#
# 步骤 3: 选择第 3 个变量
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 22)
#   平均验证损失: 0.0020 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0135 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0105 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0035 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 13)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0164 (轮次: 50)
#     种子 2:
#       验证损失: 0.0051 (轮次: 50)
#   平均验证损失: 0.0108 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 9)
#     种子 2:
#       验证损失: 0.0016 (轮次: 14)
#   平均验证损失: 0.0019 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0151 (轮次: 50)
#     种子 2:
#       验证损失: 0.0054 (轮次: 50)
#   平均验证损失: 0.0102 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0032 (轮次: 9)
#     种子 2:
#       验证损失: 0.0018 (轮次: 8)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0169 (轮次: 50)
#     种子 2:
#       验证损失: 0.0052 (轮次: 50)
#   平均验证损失: 0.0110 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0028 (轮次: 28)
#     种子 2:
#       验证损失: 0.0023 (轮次: 21)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0195 (轮次: 50)
#     种子 2:
#       验证损失: 0.0046 (轮次: 50)
#   平均验证损失: 0.0120 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0028 (轮次: 9)
#     种子 2:
#       验证损失: 0.0018 (轮次: 10)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0134 (轮次: 50)
#     种子 2:
#       验证损失: 0.0059 (轮次: 50)
#   平均验证损失: 0.0096 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0018 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_gdp_sa_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0156 (轮次: 50)
#     种子 2:
#       验证损失: 0.0046 (轮次: 50)
#   平均验证损失: 0.0101 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 9)
#     种子 2:
#       验证损失: 0.0021 (轮次: 10)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0101 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 9)
#     种子 2:
#       验证损失: 0.0019 (轮次: 18)
#   平均验证损失: 0.0018 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0122 (轮次: 50)
#     种子 2:
#       验证损失: 0.0061 (轮次: 50)
#   平均验证损失: 0.0091 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 10)
#     种子 2:
#       验证损失: 0.0017 (轮次: 21)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0153 (轮次: 50)
#     种子 2:
#       验证损失: 0.0079 (轮次: 50)
#   平均验证损失: 0.0116 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 22)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_city_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0116 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0093 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 9)
#     种子 2:
#       验证损失: 0.0021 (轮次: 9)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0140 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0104 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0029 (轮次: 26)
#     种子 2:
#       验证损失: 0.0023 (轮次: 22)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0221 (轮次: 50)
#     种子 2:
#       验证损失: 0.0064 (轮次: 50)
#   平均验证损失: 0.0143 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0031 (轮次: 9)
#     种子 2:
#       验证损失: 0.0020 (轮次: 20)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0161 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0114 (学习率 0.001)
#
# --- 步骤 3 结果 ---
# 选中变量: 'dln_city_lag2'
# 最佳平均验证损失: 0.0014
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2']
# 已保存最优模型到Google Drive: 'GRU3_3.keras' (seed 1)
#
# 步骤 4: 选择第 4 个变量
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0028 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 20)
#   平均验证损失: 0.0022 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0145 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0105 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 11)
#     种子 2:
#       验证损失: 0.0020 (轮次: 19)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0227 (轮次: 50)
#     种子 2:
#       验证损失: 0.0062 (轮次: 50)
#   平均验证损失: 0.0144 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0020 (轮次: 18)
#   平均验证损失: 0.0017 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0237 (轮次: 50)
#     种子 2:
#       验证损失: 0.0061 (轮次: 50)
#   平均验证损失: 0.0149 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 11)
#     种子 2:
#       验证损失: 0.0013 (轮次: 9)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0260 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0164 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 12)
#     种子 2:
#       验证损失: 0.0016 (轮次: 28)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0294 (轮次: 50)
#     种子 2:
#       验证损失: 0.0053 (轮次: 50)
#   平均验证损失: 0.0174 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 18)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0162 (轮次: 50)
#     种子 2:
#       验证损失: 0.0062 (轮次: 50)
#   平均验证损失: 0.0112 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 18)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_gdp_sa_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0243 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0150 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0021 (轮次: 18)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0207 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0137 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 9)
#     种子 2:
#       验证损失: 0.0021 (轮次: 18)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0163 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0115 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 10)
#     种子 2:
#       验证损失: 0.0018 (轮次: 19)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0152 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0110 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 11)
#     种子 2:
#       验证损失: 0.0023 (轮次: 11)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0233 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 50)
#   平均验证损失: 0.0152 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 13)
#     种子 2:
#       验证损失: 0.0018 (轮次: 22)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0294 (轮次: 50)
#     种子 2:
#       验证损失: 0.0064 (轮次: 50)
#   平均验证损失: 0.0179 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0020 (轮次: 15)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0181 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0124 (学习率 0.001)
#
# --- 步骤 4 结果 ---
# 选中变量: 'dln_gdp_sa_lag3'
# 最佳平均验证损失: 0.0014
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3']
# 已保存最优模型到Google Drive: 'GRU3_4.keras' (seed 1)
#
# 步骤 5: 选择第 5 个变量
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0244 (轮次: 50)
#     种子 2:
#       验证损失: 0.0062 (轮次: 50)
#   平均验证损失: 0.0153 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 21)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0175 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0120 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0159 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0019 (轮次: 15)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0175 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0122 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 9)
#     种子 2:
#       验证损失: 0.0020 (轮次: 12)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0150 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0109 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0214 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0136 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 10)
#     种子 2:
#       验证损失: 0.0017 (轮次: 19)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0179 (轮次: 50)
#     种子 2:
#       验证损失: 0.0073 (轮次: 50)
#   平均验证损失: 0.0126 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 20)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0202 (轮次: 50)
#     种子 2:
#       验证损失: 0.0062 (轮次: 50)
#   平均验证损失: 0.0132 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0211 (轮次: 50)
#     种子 2:
#       验证损失: 0.0059 (轮次: 50)
#   平均验证损失: 0.0135 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 9)
#     种子 2:
#       验证损失: 0.0012 (轮次: 20)
#   平均验证损失: 0.0012 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dpc2_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0162 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0115 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0018 (轮次: 11)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0163 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 10)
#     种子 2:
#       验证损失: 0.0016 (轮次: 11)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0192 (轮次: 50)
#     种子 2:
#       验证损失: 0.0065 (轮次: 50)
#   平均验证损失: 0.0128 (学习率 0.001)
#
# --- 步骤 5 结果 ---
# 选中变量: 'dpc2_lag1'
# 最佳平均验证损失: 0.0012
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1']
# 已保存最优模型到Google Drive: 'GRU3_5.keras' (seed 1)
#
# 步骤 6: 选择第 6 个变量
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 9)
#     种子 2:
#       验证损失: 0.0018 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0156 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0112 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0009 (轮次: 8)
#     种子 2:
#       验证损失: 0.0019 (轮次: 21)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0109 (轮次: 50)
#     种子 2:
#       验证损失: 0.0090 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 8)
#     种子 2:
#       验证损失: 0.0014 (轮次: 30)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0100 (轮次: 50)
#     种子 2:
#       验证损失: 0.0100 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0118 (轮次: 50)
#     种子 2:
#       验证损失: 0.0080 (轮次: 50)
#   平均验证损失: 0.0099 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 8)
#     种子 2:
#       验证损失: 0.0022 (轮次: 16)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0105 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0008 (轮次: 9)
#     种子 2:
#       验证损失: 0.0011 (轮次: 18)
#   平均验证损失: 0.0009 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_city_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0027 (轮次: 9)
#     种子 2:
#       验证损失: 0.0033 (轮次: 21)
#   平均验证损失: 0.0030 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0128 (轮次: 50)
#     种子 2:
#       验证损失: 0.0120 (轮次: 50)
#   平均验证损失: 0.0124 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 9)
#     种子 2:
#       验证损失: 0.0028 (轮次: 17)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0142 (轮次: 50)
#     种子 2:
#       验证损失: 0.0080 (轮次: 50)
#   平均验证损失: 0.0111 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 10)
#     种子 2:
#       验证损失: 0.0012 (轮次: 22)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0151 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0112 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 9)
#     种子 2:
#       验证损失: 0.0022 (轮次: 22)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0117 (轮次: 50)
#     种子 2:
#       验证损失: 0.0097 (轮次: 50)
#   平均验证损失: 0.0107 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 9)
#     种子 2:
#       验证损失: 0.0020 (轮次: 19)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0103 (学习率 0.001)
#
# --- 步骤 6 结果 ---
# 选中变量: 'dln_city_lag1'
# 最佳平均验证损失: 0.0009
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1']
# 已保存最优模型到Google Drive: 'GRU3_6.keras' (seed 1)
#
# 步骤 7: 选择第 7 个变量
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0010 (轮次: 9)
#     种子 2:
#       验证损失: 0.0007 (轮次: 22)
#   平均验证损失: 0.0009 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0127 (轮次: 50)
#     种子 2:
#       验证损失: 0.0051 (轮次: 50)
#   平均验证损失: 0.0089 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 18)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0132 (轮次: 50)
#     种子 2:
#       验证损失: 0.0058 (轮次: 50)
#   平均验证损失: 0.0095 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0010 (轮次: 9)
#     种子 2:
#       验证损失: 0.0017 (轮次: 17)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0119 (轮次: 50)
#     种子 2:
#       验证损失: 0.0055 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 10)
#     种子 2:
#       验证损失: 0.0016 (轮次: 10)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0150 (轮次: 50)
#     种子 2:
#       验证损失: 0.0085 (轮次: 50)
#   平均验证损失: 0.0118 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 8)
#     种子 2:
#       验证损失: 0.0010 (轮次: 31)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0137 (轮次: 50)
#     种子 2:
#       验证损失: 0.0044 (轮次: 50)
#   平均验证损失: 0.0091 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0011 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 21)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0126 (轮次: 50)
#     种子 2:
#       验证损失: 0.0062 (轮次: 50)
#   平均验证损失: 0.0094 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0010 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 18)
#   平均验证损失: 0.0012 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0131 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0094 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0008 (轮次: 9)
#     种子 2:
#       验证损失: 0.0008 (轮次: 21)
#   平均验证损失: 0.0008 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0131 (轮次: 50)
#     种子 2:
#       验证损失: 0.0055 (轮次: 50)
#   平均验证损失: 0.0093 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 9)
#     种子 2:
#       验证损失: 0.0010 (轮次: 25)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0134 (轮次: 50)
#     种子 2:
#       验证损失: 0.0055 (轮次: 50)
#   平均验证损失: 0.0095 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 9)
#     种子 2:
#       验证损失: 0.0006 (轮次: 28)
#   平均验证损失: 0.0010 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0137 (轮次: 50)
#     种子 2:
#       验证损失: 0.0048 (轮次: 50)
#   平均验证损失: 0.0092 (学习率 0.001)
#
# --- 步骤 7 结果 ---
# 选中变量: 'pc3_lag3'
# 最佳平均验证损失: 0.0008
# 最佳学习率: 0.01
# 当前已选变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc3_lag3']
# 已保存最优模型到Google Drive: 'GRU3_7.keras' (seed 2)
#
# 前向选择完成
# 最终选中变量: ['dpc2_lag3', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3', 'dpc2_lag1', 'dln_city_lag1', 'pc3_lag3']
# 已保存前向选择结果表格到Google Drive: /content/drive/My Drive/GRU3_results.csv
#
# 前向选择详细结果:
#    Step  Variable number                                 Selected Variables  \
# 0     1                1                                          dpc2_lag3
# 1     2                2                         dpc2_lag3, dln_region_lag3
# 2     3                3          dpc2_lag3, dln_region_lag3, dln_city_lag2
# 3     4                4  dpc2_lag3, dln_region_lag3, dln_city_lag2, dln...
# 4     5                5  dpc2_lag3, dln_region_lag3, dln_city_lag2, dln...
# 5     6                6  dpc2_lag3, dln_region_lag3, dln_city_lag2, dln...
# 6     7                7  dpc2_lag3, dln_region_lag3, dln_city_lag2, dln...
#
#    Best average Val Loss  Best average LR  seed 1 Val Loss  \
# 0               0.001549             0.01         0.001641
# 1               0.001558             0.01         0.001640
# 2               0.001432             0.01         0.001335
# 3               0.001399             0.01         0.001266
# 4               0.001237             0.01         0.001233
# 5               0.000943             0.01         0.000772
# 6               0.000770             0.01         0.000779
#
#    seed 1 Epochs Used  seed 2 Val Loss  seed 2 Epochs Used
# 0                   8         0.001458                  11
# 1                   9         0.001475                  14
# 2                   9         0.001529                  22
# 3                  11         0.001532                  18
# 4                   9         0.001242                  20
# 5                   9         0.001113                  18
# 6                   9         0.000762                  21

# %% [markdown]
# # 试试GRU 4

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_gru_model_4_neurons(input_shape, output_shape):
    """
    Builds a Sequential GRU model with 1 layer and 4 neurons.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).
        output_shape (int): The number of units in the output layer.

    Returns:
        keras.src.engine.sequential.Sequential: Compiled GRU model.
    """
    model = Sequential()
    model.add(GRU(units=4, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh')) # Using tanh activation as requested
    model.compile(optimizer=Adam(), loss='mse')
    return model

print("New GRU model building function with 4 neurons defined.")
# Out:
# New GRU model building function with 4 neurons defined.

# %%
import tensorflow as tf
import numpy as np
import random
import joblib
import os
import pandas as pd
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# 确保可复现性
random_seeds = [1, 2]
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 定义GRU模型构建函数
def build_gru_model(input_shape, output_shape):
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh'))
    model.compile(optimizer=Adam(), loss='mse')
    return model

# 定义目标变量和候选自变量
target = 'dln_gdp_sa'
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# 滑动窗口参数
input_length = 40
output_length = 5

# 超参数
learning_rates = [0.01, 0.001]
epochs = 50
batch_size = 4
early_stopping_patience = 10
early_stopping_min_delta = 0.001

# 前向选择初始化
selected_variables = []
remaining_variables = candidate_independent_variables.copy()
forward_selection_results = []  # 存储结果表格

print("开始前向选择，使用多个随机种子...")
print(f"随机种子: {random_seeds}")

for step in range(7):
    best_variable_for_this_step = None
    best_avg_loss_for_this_step = float('inf')
    best_lr_for_this_step = None
    candidate_results = []  # 存储候选变量结果

    print(f"\n步骤 {step + 1}: 选择第 {len(selected_variables) + 1} 个变量")
    print(f"当前已选变量: {selected_variables}")
    print(f"剩余候选变量: {remaining_variables}")

    for candidate_variable in remaining_variables:
        current_variables = selected_variables + [candidate_variable]
        print(f"\n测试变量组合: {current_variables}")

        # 创建滑动窗口数据集
        X_full_current, y_full_current = create_sliding_window_datasets(
            data_clean, input_length, output_length, current_variables, target
        )

        num_samples_current = X_full_current.shape[0]
        num_train_samples_current = 8
        num_val_samples_current = 2

        if num_samples_current < num_train_samples_current + num_val_samples_current:
             print(f"跳过组合，样本不足 ({num_samples_current})")
             continue

        X_train_current = X_full_current[:num_train_samples_current]
        y_train_current = y_full_current[:num_train_samples_current]
        X_val_current = X_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]
        y_val_current = y_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]

        # 不同学习率训练
        for lr in learning_rates:
            print(f"  学习率: {lr}")
            seed_losses = []
            seed_models = {}
            seed_epochs = []

            for seed in random_seeds:
                # 设置种子
                np.random.seed(seed)
                tf.random.set_seed(seed)
                os.environ['PYTHONHASHSEED'] = str(seed)
                random.seed(seed)

                print(f"    种子 {seed}:")

                # 构建模型
                model = build_gru_model_4_neurons(input_shape=(input_length, len(current_variables)),
                                      output_shape=output_length)
                model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

                # 早停回调
                early_stopping = EarlyStopping(
                    monitor='val_loss',
                    patience=early_stopping_patience,
                    min_delta=early_stopping_min_delta,
                    restore_best_weights=True
                )

                # 训练模型
                history = model.fit(
                    X_train_current, y_train_current,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val_current, y_val_current),
                    callbacks=[early_stopping],
                    verbose=0
                )

                # 获取最佳验证损失和轮次
                min_val_loss = min(history.history['val_loss'])
                best_epoch = history.history['val_loss'].index(min_val_loss) + 1

                # 记录结果
                seed_losses.append(min_val_loss)
                seed_models[seed] = model
                seed_epochs.append(best_epoch)

                print(f"      验证损失: {min_val_loss:.4f} (轮次: {best_epoch})")

            # 计算平均损失
            avg_loss = np.mean(seed_losses)
            print(f"  平均验证损失: {avg_loss:.4f} (学习率 {lr})")

            # 存储候选结果
            candidate_results.append({
                'variable': candidate_variable,
                'lr': lr,
                'avg_loss': avg_loss,
                'seed_losses': seed_losses,
                'seed_epochs': seed_epochs,
                'seed_models': seed_models
            })

            # 检查是否最佳组合
            if avg_loss < best_avg_loss_for_this_step:
                best_avg_loss_for_this_step = avg_loss
                best_variable_for_this_step = candidate_variable
                best_lr_for_this_step = lr

                # 暂时保存最佳模型
                best_seed_idx = np.argmin(seed_losses)
                best_seed = random_seeds[best_seed_idx]
                best_model_for_step = seed_models[best_seed]

                temp_model_save_path = f'/content/drive/My Drive/GRU4temp_best_model_step_{step+1}.keras'
                best_model_for_step.save(temp_model_save_path)
                print(f"  临时保存步骤 {step+1} 最佳模型: '{candidate_variable}', 学习率 {lr}, 种子 {best_seed}")

    # 添加最佳变量到已选列表
    if best_variable_for_this_step:
        selected_variables.append(best_variable_for_this_step)
        remaining_variables.remove(best_variable_for_this_step)

        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print(f"选中变量: '{best_variable_for_this_step}'")
        print(f"最佳平均验证损失: {best_avg_loss_for_this_step:.4f}")
        print(f"最佳学习率: {best_lr_for_this_step}")
        print(f"当前已选变量: {selected_variables}")

        # 获取最佳候选结果
        best_candidate_data = [d for d in candidate_results
                              if d['variable'] == best_variable_for_this_step
                              and d['lr'] == best_lr_for_this_step][0]

        # 记录结果到表格
        step_result = {
            'Step': step + 1,
            'Variable number': len(selected_variables),
            'Selected Variables': ', '.join(selected_variables),
            'Best average Val Loss': best_avg_loss_for_this_step,
            'Best average LR': best_lr_for_this_step,
        }

        # 添加种子详细结果
        for i, seed in enumerate(random_seeds):
            step_result[f'seed {seed} Val Loss'] = best_candidate_data['seed_losses'][i]
            step_result[f'seed {seed} Epochs Used'] = best_candidate_data['seed_epochs'][i]

        forward_selection_results.append(step_result)

        # 保存最终模型（两个种子中MSE最低的）
        best_seed_idx = np.argmin(best_candidate_data['seed_losses'])
        best_seed = random_seeds[best_seed_idx]
        best_model = best_candidate_data['seed_models'][best_seed]

        # 修改：使用新命名规则 GRU4_{变量数量}
        final_model_name = f'GRU4_{len(selected_variables)}.keras'  # 修改点
        final_model_save_path = os.path.join('/content/drive/My Drive', final_model_name)
        best_model.save(final_model_save_path)
        print(f"已保存最优模型到Google Drive: '{final_model_name}' (seed {best_seed})")

    else:
        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print("本步骤无改进变量")
        break

print("\n前向选择完成")
print(f"最终选中变量: {selected_variables}")

# 保存结果表格
results_df = pd.DataFrame(forward_selection_results)
results_csv_path = os.path.join('/content/drive/My Drive', 'GRU4_results.csv')
results_df.to_csv(results_csv_path, index=False)
print(f"已保存前向选择结果表格到Google Drive: {results_csv_path}")

# 显示结果表格
print("\n前向选择详细结果:")
display(results_df)
# Out:
# 开始前向选择，使用多个随机种子...
# 随机种子: [1, 2]
#
# 步骤 1: 选择第 1 个变量
# 当前已选变量: []
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 12)
#     种子 2:
#       验证损失: 0.0017 (轮次: 18)
#   平均验证损失: 0.0017 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0017 (轮次: 50)
#     种子 2:
#       验证损失: 0.0043 (轮次: 50)
#   平均验证损失: 0.0030 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 14)
#     种子 2:
#       验证损失: 0.0024 (轮次: 19)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0030 (轮次: 50)
#     种子 2:
#       验证损失: 0.0088 (轮次: 50)
#   平均验证损失: 0.0059 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 24)
#     种子 2:
#       验证损失: 0.0022 (轮次: 14)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0033 (轮次: 50)
#     种子 2:
#       验证损失: 0.0105 (轮次: 50)
#   平均验证损失: 0.0069 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0030 (轮次: 7)
#     种子 2:
#       验证损失: 0.0037 (轮次: 20)
#   平均验证损失: 0.0033 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0035 (轮次: 50)
#     种子 2:
#       验证损失: 0.0116 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 15)
#     种子 2:
#       验证损失: 0.0023 (轮次: 17)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0021 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0050 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 24)
#     种子 2:
#       验证损失: 0.0019 (轮次: 17)
#   平均验证损失: 0.0016 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc1_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0039 (轮次: 50)
#     种子 2:
#       验证损失: 0.0096 (轮次: 50)
#   平均验证损失: 0.0068 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 23)
#     种子 2:
#       验证损失: 0.0016 (轮次: 20)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0016 (轮次: 50)
#     种子 2:
#       验证损失: 0.0057 (轮次: 50)
#   平均验证损失: 0.0036 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 14)
#     种子 2:
#       验证损失: 0.0019 (轮次: 10)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0036 (轮次: 50)
#     种子 2:
#       验证损失: 0.0092 (轮次: 50)
#   平均验证损失: 0.0064 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0034 (轮次: 14)
#     种子 2:
#       验证损失: 0.0027 (轮次: 11)
#   平均验证损失: 0.0031 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0045 (轮次: 50)
#     种子 2:
#       验证损失: 0.0100 (轮次: 50)
#   平均验证损失: 0.0073 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0033 (轮次: 14)
#     种子 2:
#       验证损失: 0.0040 (轮次: 8)
#   平均验证损失: 0.0037 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0028 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0052 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 11)
#     种子 2:
#       验证损失: 0.0016 (轮次: 14)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0023 (轮次: 50)
#     种子 2:
#       验证损失: 0.0043 (轮次: 50)
#   平均验证损失: 0.0033 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0031 (轮次: 15)
#     种子 2:
#       验证损失: 0.0045 (轮次: 17)
#   平均验证损失: 0.0038 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0026 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0047 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 16)
#     种子 2:
#       验证损失: 0.0019 (轮次: 11)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0043 (轮次: 50)
#     种子 2:
#       验证损失: 0.0104 (轮次: 50)
#   平均验证损失: 0.0074 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 24)
#     种子 2:
#       验证损失: 0.0031 (轮次: 12)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0040 (轮次: 50)
#     种子 2:
#       验证损失: 0.0104 (轮次: 50)
#   平均验证损失: 0.0072 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 13)
#     种子 2:
#       验证损失: 0.0020 (轮次: 15)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0060 (轮次: 50)
#     种子 2:
#       验证损失: 0.0090 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 5)
#     种子 2:
#       验证损失: 0.0027 (轮次: 16)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0025 (轮次: 50)
#     种子 2:
#       验证损失: 0.0055 (轮次: 50)
#   平均验证损失: 0.0040 (学习率 0.001)
#
# --- 步骤 1 结果 ---
# 选中变量: 'pc1_lag1'
# 最佳平均验证损失: 0.0016
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1']
# 已保存最优模型到Google Drive: 'GRU4_1.keras' (seed 1)
#
# 步骤 2: 选择第 2 个变量
# 当前已选变量: ['pc1_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc1_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 26)
#     种子 2:
#       验证损失: 0.0018 (轮次: 13)
#   平均验证损失: 0.0017 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0040 (轮次: 50)
#     种子 2:
#       验证损失: 0.0097 (轮次: 50)
#   平均验证损失: 0.0069 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0054 (轮次: 15)
#     种子 2:
#       验证损失: 0.0033 (轮次: 10)
#   平均验证损失: 0.0043 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0069 (轮次: 50)
#     种子 2:
#       验证损失: 0.0140 (轮次: 50)
#   平均验证损失: 0.0104 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 7)
#     种子 2:
#       验证损失: 0.0029 (轮次: 10)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0061 (轮次: 50)
#     种子 2:
#       验证损失: 0.0137 (轮次: 50)
#   平均验证损失: 0.0099 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0045 (轮次: 25)
#     种子 2:
#       验证损失: 0.0026 (轮次: 16)
#   平均验证损失: 0.0035 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0125 (轮次: 50)
#     种子 2:
#       验证损失: 0.0122 (轮次: 50)
#   平均验证损失: 0.0123 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 22)
#     种子 2:
#       验证损失: 0.0017 (轮次: 18)
#   平均验证损失: 0.0016 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0042 (轮次: 50)
#     种子 2:
#       验证损失: 0.0122 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0047 (轮次: 15)
#     种子 2:
#       验证损失: 0.0026 (轮次: 17)
#   平均验证损失: 0.0036 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0062 (轮次: 50)
#     种子 2:
#       验证损失: 0.0124 (轮次: 50)
#   平均验证损失: 0.0093 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 7)
#     种子 2:
#       验证损失: 0.0030 (轮次: 10)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0063 (轮次: 50)
#     种子 2:
#       验证损失: 0.0140 (轮次: 50)
#   平均验证损失: 0.0101 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 25)
#     种子 2:
#       验证损失: 0.0022 (轮次: 17)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0076 (轮次: 50)
#     种子 2:
#       验证损失: 0.0128 (轮次: 50)
#   平均验证损失: 0.0102 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 26)
#     种子 2:
#       验证损失: 0.0015 (轮次: 19)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0055 (轮次: 50)
#     种子 2:
#       验证损失: 0.0118 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 14)
#     种子 2:
#       验证损失: 0.0019 (轮次: 14)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0042 (轮次: 50)
#     种子 2:
#       验证损失: 0.0099 (轮次: 50)
#   平均验证损失: 0.0071 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 17)
#     种子 2:
#       验证损失: 0.0018 (轮次: 17)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0057 (轮次: 50)
#     种子 2:
#       验证损失: 0.0117 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 7)
#     种子 2:
#       验证损失: 0.0014 (轮次: 21)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0061 (轮次: 50)
#     种子 2:
#       验证损失: 0.0107 (轮次: 50)
#   平均验证损失: 0.0084 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 22)
#     种子 2:
#       验证损失: 0.0018 (轮次: 19)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0083 (轮次: 50)
#     种子 2:
#       验证损失: 0.0117 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 14)
#     种子 2:
#       验证损失: 0.0016 (轮次: 11)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0154 (轮次: 50)
#   平均验证损失: 0.0123 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 14)
#     种子 2:
#       验证损失: 0.0035 (轮次: 19)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0044 (轮次: 50)
#     种子 2:
#       验证损失: 0.0133 (轮次: 50)
#   平均验证损失: 0.0089 (学习率 0.001)
#
# --- 步骤 2 结果 ---
# 选中变量: 'dln_region_lag2'
# 最佳平均验证损失: 0.0014
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2']
# 已保存最优模型到Google Drive: 'GRU4_2.keras' (seed 1)
#
# 步骤 3: 选择第 3 个变量
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 24)
#     种子 2:
#       验证损失: 0.0013 (轮次: 19)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0069 (轮次: 50)
#     种子 2:
#       验证损失: 0.0116 (轮次: 50)
#   平均验证损失: 0.0093 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 8)
#     种子 2:
#       验证损失: 0.0014 (轮次: 20)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0118 (轮次: 50)
#     种子 2:
#       验证损失: 0.0134 (轮次: 50)
#   平均验证损失: 0.0126 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0029 (轮次: 8)
#     种子 2:
#       验证损失: 0.0014 (轮次: 19)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 50)
#     种子 2:
#       验证损失: 0.0152 (轮次: 50)
#   平均验证损失: 0.0144 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0028 (轮次: 11)
#     种子 2:
#       验证损失: 0.0019 (轮次: 11)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0162 (轮次: 50)
#     种子 2:
#       验证损失: 0.0132 (轮次: 50)
#   平均验证损失: 0.0147 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 27)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0097 (轮次: 50)
#     种子 2:
#       验证损失: 0.0133 (轮次: 50)
#   平均验证损失: 0.0115 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 25)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0072 (轮次: 50)
#     种子 2:
#       验证损失: 0.0118 (轮次: 50)
#   平均验证损失: 0.0095 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 20)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0159 (轮次: 50)
#     种子 2:
#       验证损失: 0.0147 (轮次: 50)
#   平均验证损失: 0.0153 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0037 (轮次: 17)
#     种子 2:
#       验证损失: 0.0014 (轮次: 12)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 50)
#     种子 2:
#       验证损失: 0.0152 (轮次: 50)
#   平均验证损失: 0.0144 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 27)
#     种子 2:
#       验证损失: 0.0023 (轮次: 17)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0093 (轮次: 50)
#     种子 2:
#       验证损失: 0.0140 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 20)
#     种子 2:
#       验证损失: 0.0017 (轮次: 11)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0071 (轮次: 50)
#     种子 2:
#       验证损失: 0.0129 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 20)
#     种子 2:
#       验证损失: 0.0012 (轮次: 12)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0197 (轮次: 50)
#     种子 2:
#       验证损失: 0.0157 (轮次: 50)
#   平均验证损失: 0.0177 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0027 (轮次: 9)
#     种子 2:
#       验证损失: 0.0023 (轮次: 13)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0146 (轮次: 50)
#     种子 2:
#       验证损失: 0.0152 (轮次: 50)
#   平均验证损失: 0.0149 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0030 (轮次: 21)
#     种子 2:
#       验证损失: 0.0012 (轮次: 19)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0216 (轮次: 50)
#     种子 2:
#       验证损失: 0.0170 (轮次: 50)
#   平均验证损失: 0.0193 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 23)
#     种子 2:
#       验证损失: 0.0021 (轮次: 16)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0110 (轮次: 50)
#     种子 2:
#       验证损失: 0.0144 (轮次: 50)
#   平均验证损失: 0.0127 (学习率 0.001)
#
# --- 步骤 3 结果 ---
# 选中变量: 'dln_region_lag3'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3']
# 已保存最优模型到Google Drive: 'GRU4_3.keras' (seed 2)
#
# 步骤 4: 选择第 4 个变量
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 26)
#     种子 2:
#       验证损失: 0.0014 (轮次: 20)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0089 (轮次: 50)
#     种子 2:
#       验证损失: 0.0145 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 17)
#     种子 2:
#       验证损失: 0.0020 (轮次: 12)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0148 (轮次: 50)
#   平均验证损失: 0.0120 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 17)
#     种子 2:
#       验证损失: 0.0013 (轮次: 13)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 50)
#     种子 2:
#       验证损失: 0.0140 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 35)
#     种子 2:
#       验证损失: 0.0034 (轮次: 14)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0113 (轮次: 50)
#     种子 2:
#       验证损失: 0.0155 (轮次: 50)
#   平均验证损失: 0.0134 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0027 (轮次: 16)
#     种子 2:
#       验证损失: 0.0020 (轮次: 12)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 50)
#     种子 2:
#       验证损失: 0.0144 (轮次: 50)
#   平均验证损失: 0.0120 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 18)
#     种子 2:
#       验证损失: 0.0013 (轮次: 12)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0090 (轮次: 50)
#     种子 2:
#       验证损失: 0.0147 (轮次: 50)
#   平均验证损失: 0.0118 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 18)
#     种子 2:
#       验证损失: 0.0009 (轮次: 12)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_gdp_sa_lag2', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0097 (轮次: 50)
#     种子 2:
#       验证损失: 0.0131 (轮次: 50)
#   平均验证损失: 0.0114 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 17)
#     种子 2:
#       验证损失: 0.0010 (轮次: 17)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0141 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 27)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_city_lag2', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0097 (轮次: 50)
#     种子 2:
#       验证损失: 0.0127 (轮次: 50)
#   平均验证损失: 0.0112 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 18)
#     种子 2:
#       验证损失: 0.0014 (轮次: 13)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0090 (轮次: 50)
#     种子 2:
#       验证损失: 0.0158 (轮次: 50)
#   平均验证损失: 0.0124 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 30)
#     种子 2:
#       验证损失: 0.0014 (轮次: 13)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0104 (轮次: 50)
#     种子 2:
#       验证损失: 0.0131 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 17)
#     种子 2:
#       验证损失: 0.0015 (轮次: 14)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0100 (轮次: 50)
#     种子 2:
#       验证损失: 0.0175 (轮次: 50)
#   平均验证损失: 0.0138 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 17)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0159 (轮次: 50)
#   平均验证损失: 0.0125 (学习率 0.001)
#
# --- 步骤 4 结果 ---
# 选中变量: 'dln_city_lag2'
# 最佳平均验证损失: 0.0014
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2']
# 已保存最优模型到Google Drive: 'GRU4_4.keras' (seed 2)
#
# 步骤 5: 选择第 5 个变量
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 17)
#     种子 2:
#       验证损失: 0.0014 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0098 (轮次: 50)
#     种子 2:
#       验证损失: 0.0120 (轮次: 50)
#   平均验证损失: 0.0109 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 17)
#     种子 2:
#       验证损失: 0.0045 (轮次: 9)
#   平均验证损失: 0.0033 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0107 (轮次: 50)
#     种子 2:
#       验证损失: 0.0111 (轮次: 50)
#   平均验证损失: 0.0109 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 8)
#     种子 2:
#       验证损失: 0.0018 (轮次: 9)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0098 (轮次: 50)
#     种子 2:
#       验证损失: 0.0081 (轮次: 50)
#   平均验证损失: 0.0089 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0034 (轮次: 17)
#     种子 2:
#       验证损失: 0.0048 (轮次: 9)
#   平均验证损失: 0.0041 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0117 (轮次: 50)
#     种子 2:
#       验证损失: 0.0119 (轮次: 50)
#   平均验证损失: 0.0118 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 17)
#     种子 2:
#       验证损失: 0.0026 (轮次: 10)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0107 (轮次: 50)
#     种子 2:
#       验证损失: 0.0126 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 8)
#     种子 2:
#       验证损失: 0.0028 (轮次: 19)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0114 (轮次: 50)
#     种子 2:
#       验证损失: 0.0099 (轮次: 50)
#   平均验证损失: 0.0106 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 8)
#     种子 2:
#       验证损失: 0.0019 (轮次: 19)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0098 (轮次: 50)
#     种子 2:
#       验证损失: 0.0103 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 16)
#     种子 2:
#       验证损失: 0.0017 (轮次: 11)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0100 (轮次: 50)
#     种子 2:
#       验证损失: 0.0117 (轮次: 50)
#   平均验证损失: 0.0109 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 8)
#     种子 2:
#       验证损失: 0.0022 (轮次: 19)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0106 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0088 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 17)
#     种子 2:
#       验证损失: 0.0024 (轮次: 10)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0110 (轮次: 50)
#     种子 2:
#       验证损失: 0.0105 (轮次: 50)
#   平均验证损失: 0.0108 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 21)
#     种子 2:
#       验证损失: 0.0022 (轮次: 12)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0141 (轮次: 50)
#     种子 2:
#       验证损失: 0.0106 (轮次: 50)
#   平均验证损失: 0.0123 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 7)
#     种子 2:
#       验证损失: 0.0019 (轮次: 11)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0107 (轮次: 50)
#     种子 2:
#       验证损失: 0.0113 (轮次: 50)
#   平均验证损失: 0.0110 (学习率 0.001)
#
# --- 步骤 5 结果 ---
# 选中变量: 'dln_gdp_sa_lag4'
# 最佳平均验证损失: 0.0015
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4']
# 已保存最优模型到Google Drive: 'GRU4_5.keras' (seed 1)
#
# 步骤 6: 选择第 6 个变量
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dpc2_lag4', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 8)
#     种子 2:
#       验证损失: 0.0026 (轮次: 26)
#   平均验证损失: 0.0021 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0102 (轮次: 50)
#     种子 2:
#       验证损失: 0.0096 (轮次: 50)
#   平均验证损失: 0.0099 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 6)
#     种子 2:
#       验证损失: 0.0016 (轮次: 9)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0043 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0058 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 6)
#     种子 2:
#       验证损失: 0.0020 (轮次: 17)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0056 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0063 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 7)
#     种子 2:
#       验证损失: 0.0015 (轮次: 9)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_city_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0071 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0072 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 5)
#     种子 2:
#       验证损失: 0.0019 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0034 (轮次: 50)
#     种子 2:
#       验证损失: 0.0089 (轮次: 50)
#   平均验证损失: 0.0061 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 6)
#     种子 2:
#       验证损失: 0.0023 (轮次: 9)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0038 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0056 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 7)
#     种子 2:
#       验证损失: 0.0025 (轮次: 17)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0087 (轮次: 50)
#     种子 2:
#       验证损失: 0.0107 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 5)
#     种子 2:
#       验证损失: 0.0022 (轮次: 8)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0023 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0050 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 5)
#     种子 2:
#       验证损失: 0.0019 (轮次: 9)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0040 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0056 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 6)
#     种子 2:
#       验证损失: 0.0037 (轮次: 9)
#   平均验证损失: 0.0027 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0055 (轮次: 50)
#     种子 2:
#       验证损失: 0.0132 (轮次: 50)
#   平均验证损失: 0.0093 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0010 (轮次: 7)
#     种子 2:
#       验证损失: 0.0022 (轮次: 9)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0071 (轮次: 50)
#     种子 2:
#       验证损失: 0.0091 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# --- 步骤 6 结果 ---
# 选中变量: 'dln_city_lag1'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1']
# 已保存最优模型到Google Drive: 'GRU4_6.keras' (seed 1)
#
# 步骤 7: 选择第 7 个变量
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dpc2_lag4', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0010 (轮次: 7)
#     种子 2:
#       验证损失: 0.0017 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0068 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0073 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0022 (轮次: 8)
#     种子 2:
#       验证损失: 0.0015 (轮次: 9)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0116 (轮次: 50)
#     种子 2:
#       验证损失: 0.0077 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0042 (轮次: 17)
#     种子 2:
#       验证损失: 0.0041 (轮次: 9)
#   平均验证损失: 0.0041 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0131 (轮次: 50)
#     种子 2:
#       验证损失: 0.0116 (轮次: 50)
#   平均验证损失: 0.0124 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 9)
#     种子 2:
#       验证损失: 0.0021 (轮次: 8)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0146 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0108 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 8)
#     种子 2:
#       验证损失: 0.0016 (轮次: 19)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0126 (轮次: 50)
#     种子 2:
#       验证损失: 0.0079 (轮次: 50)
#   平均验证损失: 0.0102 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 8)
#     种子 2:
#       验证损失: 0.0016 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0080 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 9)
#     种子 2:
#       验证损失: 0.0016 (轮次: 9)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0156 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0112 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0028 (轮次: 19)
#     种子 2:
#       验证损失: 0.0018 (轮次: 9)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0142 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0110 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 10)
#     种子 2:
#       验证损失: 0.0026 (轮次: 11)
#   平均验证损失: 0.0023 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0163 (轮次: 50)
#     种子 2:
#       验证损失: 0.0093 (轮次: 50)
#   平均验证损失: 0.0128 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 8)
#     种子 2:
#       验证损失: 0.0014 (轮次: 9)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0104 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0090 (学习率 0.001)
#
# --- 步骤 7 结果 ---
# 选中变量: 'pc3_lag4'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'pc3_lag4']
# 已保存最优模型到Google Drive: 'GRU4_7.keras' (seed 1)
#
# 前向选择完成
# 最终选中变量: ['pc1_lag1', 'dln_region_lag2', 'dln_region_lag3', 'dln_city_lag2', 'dln_gdp_sa_lag4', 'dln_city_lag1', 'pc3_lag4']
# 已保存前向选择结果表格到Google Drive: /content/drive/My Drive/GRU4_results.csv
#
# 前向选择详细结果:
#    Step  Variable number                                 Selected Variables  \
# 0     1                1                                           pc1_lag1
# 1     2                2                          pc1_lag1, dln_region_lag2
# 2     3                3         pc1_lag1, dln_region_lag2, dln_region_lag3
# 3     4                4  pc1_lag1, dln_region_lag2, dln_region_lag3, dl...
# 4     5                5  pc1_lag1, dln_region_lag2, dln_region_lag3, dl...
# 5     6                6  pc1_lag1, dln_region_lag2, dln_region_lag3, dl...
# 6     7                7  pc1_lag1, dln_region_lag2, dln_region_lag3, dl...
#
#    Best average Val Loss  Best average LR  seed 1 Val Loss  \
# 0               0.001646             0.01         0.001384
# 1               0.001432             0.01         0.001406
# 2               0.001344             0.01         0.001406
# 3               0.001372             0.01         0.001414
# 4               0.001532             0.01         0.001309
# 5               0.001336             0.01         0.001206
# 6               0.001322             0.01         0.000994
#
#    seed 1 Epochs Used  seed 2 Val Loss  seed 2 Epochs Used
# 0                  24         0.001908                  17
# 1                  26         0.001457                  19
# 2                  27         0.001281                  11
# 3                  27         0.001330                  11
# 4                   8         0.001755                   9
# 5                   7         0.001466                   9
# 6                   7         0.001651                  10

# %% [markdown]
# # GRU 2X2

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_gru_model_2_layers_2_neurons(input_shape, output_shape):
    """
    Builds a Sequential GRU model with 2 layers and 2 neurons each.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).
        output_shape (int): The number of units in the output layer.

    Returns:
        keras.src.engine.sequential.Sequential: Compiled GRU model.
    """
    model = Sequential()
    model.add(GRU(units=2, return_sequences=True, input_shape=input_shape)) # Return sequences for the first layer
    model.add(Dropout(0.1))
    model.add(GRU(units=2, return_sequences=False)) # Last GRU layer does not return sequences
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh')) # Using tanh activation as requested
    model.compile(optimizer=Adam(), loss='mse')
    return model

print("New GRU model building function with 2 layers (2 neurons each) defined.")
# Out:
# New GRU model building function with 2 layers (2 neurons each) defined.

# %%
import tensorflow as tf
import numpy as np
import random
import joblib
import os
import pandas as pd
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# 确保可复现性
random_seeds = [1, 2]
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 定义GRU模型构建函数
def build_gru_model(input_shape, output_shape):
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh'))
    model.compile(optimizer=Adam(), loss='mse')
    return model

# 定义目标变量和候选自变量
target = 'dln_gdp_sa'
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# 滑动窗口参数
input_length = 40
output_length = 5

# 超参数
learning_rates = [0.01, 0.001]
epochs = 50
batch_size = 4
early_stopping_patience = 10
early_stopping_min_delta = 0.001

# 前向选择初始化
selected_variables = []
remaining_variables = candidate_independent_variables.copy()
forward_selection_results = []  # 存储结果表格

print("开始前向选择，使用多个随机种子...")
print(f"随机种子: {random_seeds}")

for step in range(7):
    best_variable_for_this_step = None
    best_avg_loss_for_this_step = float('inf')
    best_lr_for_this_step = None
    candidate_results = []  # 存储候选变量结果

    print(f"\n步骤 {step + 1}: 选择第 {len(selected_variables) + 1} 个变量")
    print(f"当前已选变量: {selected_variables}")
    print(f"剩余候选变量: {remaining_variables}")

    for candidate_variable in remaining_variables:
        current_variables = selected_variables + [candidate_variable]
        print(f"\n测试变量组合: {current_variables}")

        # 创建滑动窗口数据集
        X_full_current, y_full_current = create_sliding_window_datasets(
            data_clean, input_length, output_length, current_variables, target
        )

        num_samples_current = X_full_current.shape[0]
        num_train_samples_current = 8
        num_val_samples_current = 2

        if num_samples_current < num_train_samples_current + num_val_samples_current:
             print(f"跳过组合，样本不足 ({num_samples_current})")
             continue

        X_train_current = X_full_current[:num_train_samples_current]
        y_train_current = y_full_current[:num_train_samples_current]
        X_val_current = X_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]
        y_val_current = y_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]

        # 不同学习率训练
        for lr in learning_rates:
            print(f"  学习率: {lr}")
            seed_losses = []
            seed_models = {}
            seed_epochs = []

            for seed in random_seeds:
                # 设置种子
                np.random.seed(seed)
                tf.random.set_seed(seed)
                os.environ['PYTHONHASHSEED'] = str(seed)
                random.seed(seed)

                print(f"    种子 {seed}:")

                # 构建模型
                model = build_gru_model_2_layers_2_neurons(input_shape=(input_length, len(current_variables)),
                                      output_shape=output_length)
                model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

                # 早停回调
                early_stopping = EarlyStopping(
                    monitor='val_loss',
                    patience=early_stopping_patience,
                    min_delta=early_stopping_min_delta,
                    restore_best_weights=True
                )

                # 训练模型
                history = model.fit(
                    X_train_current, y_train_current,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val_current, y_val_current),
                    callbacks=[early_stopping],
                    verbose=0
                )

                # 获取最佳验证损失和轮次
                min_val_loss = min(history.history['val_loss'])
                best_epoch = history.history['val_loss'].index(min_val_loss) + 1

                # 记录结果
                seed_losses.append(min_val_loss)
                seed_models[seed] = model
                seed_epochs.append(best_epoch)

                print(f"      验证损失: {min_val_loss:.4f} (轮次: {best_epoch})")

            # 计算平均损失
            avg_loss = np.mean(seed_losses)
            print(f"  平均验证损失: {avg_loss:.4f} (学习率 {lr})")

            # 存储候选结果
            candidate_results.append({
                'variable': candidate_variable,
                'lr': lr,
                'avg_loss': avg_loss,
                'seed_losses': seed_losses,
                'seed_epochs': seed_epochs,
                'seed_models': seed_models
            })

            # 检查是否最佳组合
            if avg_loss < best_avg_loss_for_this_step:
                best_avg_loss_for_this_step = avg_loss
                best_variable_for_this_step = candidate_variable
                best_lr_for_this_step = lr

                # 暂时保存最佳模型
                best_seed_idx = np.argmin(seed_losses)
                best_seed = random_seeds[best_seed_idx]
                best_model_for_step = seed_models[best_seed]

                temp_model_save_path = f'/content/drive/My Drive/GRU22temp_best_model_step_{step+1}.keras'
                best_model_for_step.save(temp_model_save_path)
                print(f"  临时保存步骤 {step+1} 最佳模型: '{candidate_variable}', 学习率 {lr}, 种子 {best_seed}")

    # 添加最佳变量到已选列表
    if best_variable_for_this_step:
        selected_variables.append(best_variable_for_this_step)
        remaining_variables.remove(best_variable_for_this_step)

        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print(f"选中变量: '{best_variable_for_this_step}'")
        print(f"最佳平均验证损失: {best_avg_loss_for_this_step:.4f}")
        print(f"最佳学习率: {best_lr_for_this_step}")
        print(f"当前已选变量: {selected_variables}")

        # 获取最佳候选结果
        best_candidate_data = [d for d in candidate_results
                              if d['variable'] == best_variable_for_this_step
                              and d['lr'] == best_lr_for_this_step][0]

        # 记录结果到表格
        step_result = {
            'Step': step + 1,
            'Variable number': len(selected_variables),
            'Selected Variables': ', '.join(selected_variables),
            'Best average Val Loss': best_avg_loss_for_this_step,
            'Best average LR': best_lr_for_this_step,
        }

        # 添加种子详细结果
        for i, seed in enumerate(random_seeds):
            step_result[f'seed {seed} Val Loss'] = best_candidate_data['seed_losses'][i]
            step_result[f'seed {seed} Epochs Used'] = best_candidate_data['seed_epochs'][i]

        forward_selection_results.append(step_result)

        # 保存最终模型（两个种子中MSE最低的）
        best_seed_idx = np.argmin(best_candidate_data['seed_losses'])
        best_seed = random_seeds[best_seed_idx]
        best_model = best_candidate_data['seed_models'][best_seed]

        # 修改：使用新命名规则 GRU22_{变量数量}
        final_model_name = f'GRU22_{len(selected_variables)}.keras'  # 修改点
        final_model_save_path = os.path.join('/content/drive/My Drive', final_model_name)
        best_model.save(final_model_save_path)
        print(f"已保存最优模型到Google Drive: '{final_model_name}' (seed {best_seed})")

    else:
        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print("本步骤无改进变量")
        break

print("\n前向选择完成")
print(f"最终选中变量: {selected_variables}")

# 保存结果表格
results_df = pd.DataFrame(forward_selection_results)
results_csv_path = os.path.join('/content/drive/My Drive', 'GRU22_results.csv')
results_df.to_csv(results_csv_path, index=False)
print(f"已保存前向选择结果表格到Google Drive: {results_csv_path}")

# 显示结果表格
print("\n前向选择详细结果:")
display(results_df)
# Out:
# 开始前向选择，使用多个随机种子...
# 随机种子: [1, 2]
#
# 步骤 1: 选择第 1 个变量
# 当前已选变量: []
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 11)
#     种子 2:
#       验证损失: 0.0018 (轮次: 10)
#   平均验证损失: 0.0019 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0081 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0076 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 10)
#     种子 2:
#       验证损失: 0.0019 (轮次: 9)
#   平均验证损失: 0.0017 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0076 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 12)
#     种子 2:
#       验证损失: 0.0017 (轮次: 9)
#   平均验证损失: 0.0019 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0075 (轮次: 50)
#     种子 2:
#       验证损失: 0.0061 (轮次: 50)
#   平均验证损失: 0.0068 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 14)
#     种子 2:
#       验证损失: 0.0016 (轮次: 12)
#   平均验证损失: 0.0021 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0077 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 10)
#     种子 2:
#       验证损失: 0.0016 (轮次: 8)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0070 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0069 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 31)
#     种子 2:
#       验证损失: 0.0027 (轮次: 24)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0110 (轮次: 50)
#     种子 2:
#       验证损失: 0.0318 (轮次: 11)
#   平均验证损失: 0.0214 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 12)
#     种子 2:
#       验证损失: 0.0022 (轮次: 9)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0071 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0070 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 11)
#     种子 2:
#       验证损失: 0.0016 (轮次: 10)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_gdp_sa_lag2', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0076 (轮次: 50)
#     种子 2:
#       验证损失: 0.0064 (轮次: 50)
#   平均验证损失: 0.0070 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0069 (轮次: 50)
#     种子 2:
#       验证损失: 0.0064 (轮次: 50)
#   平均验证损失: 0.0067 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0023 (轮次: 12)
#     种子 2:
#       验证损失: 0.0017 (轮次: 9)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0078 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0078 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0070 (轮次: 50)
#     种子 2:
#       验证损失: 0.0065 (轮次: 50)
#   平均验证损失: 0.0068 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 14)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0084 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 13)
#     种子 2:
#       验证损失: 0.0017 (轮次: 12)
#   平均验证损失: 0.0020 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0080 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0073 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0030 (轮次: 22)
#     种子 2:
#       验证损失: 0.0031 (轮次: 10)
#   平均验证损失: 0.0031 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0118 (轮次: 50)
#     种子 2:
#       验证损失: 0.0281 (轮次: 7)
#   平均验证损失: 0.0199 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 10)
#     种子 2:
#       验证损失: 0.0026 (轮次: 10)
#   平均验证损失: 0.0026 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0089 (轮次: 50)
#     种子 2:
#       验证损失: 0.0109 (轮次: 50)
#   平均验证损失: 0.0099 (学习率 0.001)
#
# --- 步骤 1 结果 ---
# 选中变量: 'dln_gdp_sa_lag2'
# 最佳平均验证损失: 0.0014
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2']
# 已保存最优模型到Google Drive: 'GRU22_1.keras' (seed 2)
#
# 步骤 2: 选择第 2 个变量
# 当前已选变量: ['dln_gdp_sa_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0075 (轮次: 50)
#     种子 2:
#       验证损失: 0.0064 (轮次: 50)
#   平均验证损失: 0.0069 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0020 (轮次: 12)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 50)
#     种子 2:
#       验证损失: 0.0065 (轮次: 50)
#   平均验证损失: 0.0074 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 13)
#     种子 2:
#       验证损失: 0.0014 (轮次: 11)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0085 (轮次: 50)
#     种子 2:
#       验证损失: 0.0077 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 11)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0078 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0081 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 9)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc1_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0094 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0077 (轮次: 50)
#     种子 2:
#       验证损失: 0.0065 (轮次: 50)
#   平均验证损失: 0.0071 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 12)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0086 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0077 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0080 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0073 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0076 (轮次: 50)
#     种子 2:
#       验证损失: 0.0062 (轮次: 50)
#   平均验证损失: 0.0069 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0079 (轮次: 50)
#     种子 2:
#       验证损失: 0.0066 (轮次: 50)
#   平均验证损失: 0.0072 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0091 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 12)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0087 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0080 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 9)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc1_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0075 (学习率 0.001)
#
# --- 步骤 2 结果 ---
# 选中变量: 'pc1_lag4'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4']
# 已保存最优模型到Google Drive: 'GRU22_2.keras' (seed 1)
#
# 步骤 3: 选择第 3 个变量
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc3_lag1']
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 9)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0093 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0012 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0094 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0084 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0085 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 9)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0098 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0091 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0096 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0086 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0012 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0093 (轮次: 50)
#     种子 2:
#       验证损失: 0.0073 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 9)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0093 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0073 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 11)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0086 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0094 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0084 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 9)
#     种子 2:
#       验证损失: 0.0016 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0099 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# --- 步骤 3 结果 ---
# 选中变量: 'dln_region_lag2'
# 最佳平均验证损失: 0.0012
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2']
# 已保存最优模型到Google Drive: 'GRU22_3.keras' (seed 1)
#
# 步骤 4: 选择第 4 个变量
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc3_lag1']
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0096 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 11)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0079 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0078 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 11)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0083 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0081 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0078 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 11)
#     种子 2:
#       验证损失: 0.0028 (轮次: 20)
#   平均验证损失: 0.0024 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0093 (轮次: 50)
#     种子 2:
#       验证损失: 0.0100 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 9)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0080 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0080 (轮次: 50)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0079 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0091 (轮次: 50)
#     种子 2:
#       验证损失: 0.0073 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0085 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0079 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0074 (轮次: 50)
#     种子 2:
#       验证损失: 0.0081 (轮次: 50)
#   平均验证损失: 0.0077 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0017 (轮次: 11)
#     种子 2:
#       验证损失: 0.0012 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0017 (轮次: 11)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0085 (轮次: 50)
#     种子 2:
#       验证损失: 0.0080 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# --- 步骤 4 结果 ---
# 选中变量: 'pc3_lag3'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3']
# 已保存最优模型到Google Drive: 'GRU22_4.keras' (seed 1)
#
# 步骤 5: 选择第 5 个变量
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc3_lag1']
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0090 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0079 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 12)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0099 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0091 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0111 (轮次: 50)
#     种子 2:
#       验证损失: 0.0076 (轮次: 50)
#   平均验证损失: 0.0094 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0019 (轮次: 12)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0017 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0107 (轮次: 50)
#     种子 2:
#       验证损失: 0.0089 (轮次: 50)
#   平均验证损失: 0.0098 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0016 (轮次: 9)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0099 (轮次: 50)
#     种子 2:
#       验证损失: 0.0081 (轮次: 50)
#   平均验证损失: 0.0090 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 9)
#     种子 2:
#       验证损失: 0.0034 (轮次: 10)
#   平均验证损失: 0.0025 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0139 (轮次: 50)
#     种子 2:
#       验证损失: 0.0100 (轮次: 50)
#   平均验证损失: 0.0119 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0091 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0081 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0111 (轮次: 50)
#     种子 2:
#       验证损失: 0.0085 (轮次: 50)
#   平均验证损失: 0.0098 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0084 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0129 (轮次: 50)
#     种子 2:
#       验证损失: 0.0079 (轮次: 50)
#   平均验证损失: 0.0104 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 12)
#     种子 2:
#       验证损失: 0.0013 (轮次: 10)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0109 (轮次: 50)
#     种子 2:
#       验证损失: 0.0085 (轮次: 50)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 8)
#     种子 2:
#       验证损失: 0.0018 (轮次: 10)
#   平均验证损失: 0.0022 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0116 (轮次: 50)
#     种子 2:
#       验证损失: 0.0083 (轮次: 50)
#   平均验证损失: 0.0100 (学习率 0.001)
#
# --- 步骤 5 结果 ---
# 选中变量: 'pc3_lag4'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4']
# 已保存最优模型到Google Drive: 'GRU22_5.keras' (seed 1)
#
# 步骤 6: 选择第 6 个变量
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4']
# 剩余候选变量: ['dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc3_lag1']
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0098 (轮次: 50)
#     种子 2:
#       验证损失: 0.0074 (轮次: 50)
#   平均验证损失: 0.0086 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 11)
#     种子 2:
#       验证损失: 0.0016 (轮次: 11)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0102 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0016 (轮次: 12)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0106 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0088 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0096 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0082 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0118 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0095 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0091 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0080 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0107 (轮次: 50)
#     种子 2:
#       验证损失: 0.0072 (轮次: 50)
#   平均验证损失: 0.0089 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 11)
#     种子 2:
#       验证损失: 0.0014 (轮次: 11)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_city_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0080 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0014 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0108 (轮次: 50)
#     种子 2:
#       验证损失: 0.0067 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0015 (轮次: 11)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0101 (轮次: 50)
#     种子 2:
#       验证损失: 0.0069 (轮次: 50)
#   平均验证损失: 0.0085 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 9)
#     种子 2:
#       验证损失: 0.0015 (轮次: 10)
#   平均验证损失: 0.0018 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0106 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0088 (学习率 0.001)
#
# --- 步骤 6 结果 ---
# 选中变量: 'dln_city_lag2'
# 最佳平均验证损失: 0.0014
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2']
# 已保存最优模型到Google Drive: 'GRU22_6.keras' (seed 1)
#
# 步骤 7: 选择第 7 个变量
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2']
# 剩余候选变量: ['dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc3_lag1']
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 13)
#   平均验证损失: 0.0014 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0077 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0013 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0086 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0085 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 12)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0090 (轮次: 50)
#     种子 2:
#       验证损失: 0.0075 (轮次: 50)
#   平均验证损失: 0.0083 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0018 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 12)
#   平均验证损失: 0.0016 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0096 (轮次: 50)
#     种子 2:
#       验证损失: 0.0090 (轮次: 50)
#   平均验证损失: 0.0093 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 11)
#     种子 2:
#       验证损失: 0.0013 (轮次: 11)
#   平均验证损失: 0.0013 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0090 (轮次: 50)
#     种子 2:
#       验证损失: 0.0070 (轮次: 50)
#   平均验证损失: 0.0080 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0016 (轮次: 14)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0089 (轮次: 50)
#     种子 2:
#       验证损失: 0.0084 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0014 (轮次: 10)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0089 (轮次: 50)
#     种子 2:
#       验证损失: 0.0089 (轮次: 50)
#   平均验证损失: 0.0089 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0012 (轮次: 10)
#     种子 2:
#       验证损失: 0.0015 (轮次: 11)
#   平均验证损失: 0.0014 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0089 (轮次: 50)
#     种子 2:
#       验证损失: 0.0087 (轮次: 50)
#   平均验证损失: 0.0088 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0013 (轮次: 10)
#     种子 2:
#       验证损失: 0.0017 (轮次: 11)
#   平均验证损失: 0.0015 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0092 (轮次: 50)
#     种子 2:
#       验证损失: 0.0081 (轮次: 50)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# --- 步骤 7 结果 ---
# 选中变量: 'dln_gdp_sa_lag4'
# 最佳平均验证损失: 0.0013
# 最佳学习率: 0.01
# 当前已选变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_gdp_sa_lag4']
# 已保存最优模型到Google Drive: 'GRU22_7.keras' (seed 1)
#
# 前向选择完成
# 最终选中变量: ['dln_gdp_sa_lag2', 'pc1_lag4', 'dln_region_lag2', 'pc3_lag3', 'pc3_lag4', 'dln_city_lag2', 'dln_gdp_sa_lag4']
# 已保存前向选择结果表格到Google Drive: /content/drive/My Drive/GRU22_results.csv
#
# 前向选择详细结果:
#    Step  Variable number                                 Selected Variables  \
# 0     1                1                                    dln_gdp_sa_lag2
# 1     2                2                          dln_gdp_sa_lag2, pc1_lag4
# 2     3                3         dln_gdp_sa_lag2, pc1_lag4, dln_region_lag2
# 3     4                4  dln_gdp_sa_lag2, pc1_lag4, dln_region_lag2, pc...
# 4     5                5  dln_gdp_sa_lag2, pc1_lag4, dln_region_lag2, pc...
# 5     6                6  dln_gdp_sa_lag2, pc1_lag4, dln_region_lag2, pc...
# 6     7                7  dln_gdp_sa_lag2, pc1_lag4, dln_region_lag2, pc...
#
#    Best average Val Loss  Best average LR  seed 1 Val Loss  \
# 0               0.001390             0.01         0.001407
# 1               0.001264             0.01         0.001175
# 2               0.001244             0.01         0.001184
# 3               0.001275             0.01         0.001186
# 4               0.001310             0.01         0.001176
# 5               0.001351             0.01         0.001261
# 6               0.001284             0.01         0.001242
#
#    seed 1 Epochs Used  seed 2 Val Loss  seed 2 Epochs Used
# 0                  11         0.001372                  10
# 1                  10         0.001352                   9
# 2                  10         0.001304                  10
# 3                  10         0.001364                  10
# 4                  10         0.001445                  10
# 5                  11         0.001440                  11
# 6                  10         0.001326                  11

# %%
import os
from google.colab import drive
import pandas as pd

# Mount Google Drive if not already mounted
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
else:
    print("Google Drive is already mounted.")

# Define the save path and filename
save_path = '/content/drive/My Drive'
summary_filename_2l2n = os.path.join(save_path, 'forward_selection_GRU2L2N_summary.csv') # Updated filename

# Save the summary DataFrame to a CSV file
if 'summary_df_2l2n' in globals():
    summary_df_2l2n.to_csv(summary_filename_2l2n, index=False)
    print(f"Forward selection summary (GRU 2 Layers, 2 Neurons Each) saved to: {summary_filename_2l2n}")
else:
    print("Error: 'summary_df_2l2n' DataFrame not found. Please ensure the forward selection code for GRU 2 Layers, 2 Neurons Each has been executed.")
# Out:
# Google Drive is already mounted.
# Forward selection summary (GRU 2 Layers, 2 Neurons Each) saved to: /content/drive/My Drive/forward_selection_GRU2L2N_summary.csv

# %% [markdown]
# # CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

def build_cnn_model(input_shape, output_shape):
    """
    Builds a Sequential CNN model for time series forecasting.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).
        output_shape (int): The number of units in the output layer (prediction length).

    Returns:
        keras.src.engine.sequential.Sequential: Compiled CNN model.
    """
    model = Sequential()
    model.add(Conv1D(filters=3, kernel_size=4, activation='tanh', padding='causal', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten()) # Flatten the output of the convolutional layers
    model.add(Dense(units=output_shape, activation='tanh')) # Output layer for forecasting

    model.compile(optimizer=Adam(), loss='mse') # Using Adam and MSE as requested
    return model

print("CNN model building function defined.")
# Out:
# CNN model building function defined.

# %%
import tensorflow as tf
import numpy as np
import random
import joblib
import os
import pandas as pd
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam

random_seeds = [1, 2]
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 定义GRU模型构建函数
def build_gru_model(input_shape, output_shape):
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh'))
    model.compile(optimizer=Adam(), loss='mse')
    return model

# 定义目标变量和候选自变量
target = 'dln_gdp_sa'
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# 滑动窗口参数
input_length = 40
output_length = 5

# 超参数
learning_rates = [0.01, 0.001]
epochs = 50
batch_size = 4
early_stopping_patience = 10
early_stopping_min_delta = 0.001

# 前向选择初始化
selected_variables = []
remaining_variables = candidate_independent_variables.copy()
forward_selection_results = []  # 存储结果表格

print("开始前向选择，使用多个随机种子...")
print(f"随机种子: {random_seeds}")

for step in range(7):
    best_variable_for_this_step = None
    best_avg_loss_for_this_step = float('inf')
    best_lr_for_this_step = None
    candidate_results = []  # 存储候选变量结果

    print(f"\n步骤 {step + 1}: 选择第 {len(selected_variables) + 1} 个变量")
    print(f"当前已选变量: {selected_variables}")
    print(f"剩余候选变量: {remaining_variables}")

    for candidate_variable in remaining_variables:
        current_variables = selected_variables + [candidate_variable]
        print(f"\n测试变量组合: {current_variables}")

        # 创建滑动窗口数据集
        X_full_current, y_full_current = create_sliding_window_datasets(
            data_clean, input_length, output_length, current_variables, target
        )

        num_samples_current = X_full_current.shape[0]
        num_train_samples_current = 8
        num_val_samples_current = 2

        if num_samples_current < num_train_samples_current + num_val_samples_current:
             print(f"跳过组合，样本不足 ({num_samples_current})")
             continue

        X_train_current = X_full_current[:num_train_samples_current]
        y_train_current = y_full_current[:num_train_samples_current]
        X_val_current = X_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]
        y_val_current = y_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]

        # 不同学习率训练
        for lr in learning_rates:
            print(f"  学习率: {lr}")
            seed_losses = []
            seed_models = {}
            seed_epochs = []

            for seed in random_seeds:
                # 设置种子
                np.random.seed(seed)
                tf.random.set_seed(seed)
                os.environ['PYTHONHASHSEED'] = str(seed)
                random.seed(seed)

                print(f"    种子 {seed}:")

                # 构建模型
                model = build_cnn_model(input_shape=(input_length, len(current_variables)),
                                      output_shape=output_length)
                model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

                # 早停回调
                early_stopping = EarlyStopping(
                    monitor='val_loss',
                    patience=early_stopping_patience,
                    min_delta=early_stopping_min_delta,
                    restore_best_weights=True
                )

                # 训练模型
                history = model.fit(
                    X_train_current, y_train_current,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val_current, y_val_current),
                    callbacks=[early_stopping],
                    verbose=0
                )

                # 获取最佳验证损失和轮次
                min_val_loss = min(history.history['val_loss'])
                best_epoch = history.history['val_loss'].index(min_val_loss) + 1

                # 记录结果
                seed_losses.append(min_val_loss)
                seed_models[seed] = model
                seed_epochs.append(best_epoch)

                print(f"      验证损失: {min_val_loss:.4f} (轮次: {best_epoch})")

            # 计算平均损失
            avg_loss = np.mean(seed_losses)
            print(f"  平均验证损失: {avg_loss:.4f} (学习率 {lr})")

            # 存储候选结果
            candidate_results.append({
                'variable': candidate_variable,
                'lr': lr,
                'avg_loss': avg_loss,
                'seed_losses': seed_losses,
                'seed_epochs': seed_epochs,
                'seed_models': seed_models
            })

            # 检查是否最佳组合
            if avg_loss < best_avg_loss_for_this_step:
                best_avg_loss_for_this_step = avg_loss
                best_variable_for_this_step = candidate_variable
                best_lr_for_this_step = lr

                # 暂时保存最佳模型
                best_seed_idx = np.argmin(seed_losses)
                best_seed = random_seeds[best_seed_idx]
                best_model_for_step = seed_models[best_seed]

                temp_model_save_path = f'/content/drive/My Drive/cnn3temp_best_model_step_{step+1}.keras'
                best_model_for_step.save(temp_model_save_path)
                print(f"  临时保存步骤 {step+1} 最佳模型: '{candidate_variable}', 学习率 {lr}, 种子 {best_seed}")

    # 添加最佳变量到已选列表
    if best_variable_for_this_step:
        selected_variables.append(best_variable_for_this_step)
        remaining_variables.remove(best_variable_for_this_step)

        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print(f"选中变量: '{best_variable_for_this_step}'")
        print(f"最佳平均验证损失: {best_avg_loss_for_this_step:.4f}")
        print(f"最佳学习率: {best_lr_for_this_step}")
        print(f"当前已选变量: {selected_variables}")

        # 获取最佳候选结果
        best_candidate_data = [d for d in candidate_results
                              if d['variable'] == best_variable_for_this_step
                              and d['lr'] == best_lr_for_this_step][0]

        # 记录结果到表格
        step_result = {
            'Step': step + 1,
            'Variable number': len(selected_variables),
            'Selected Variables': ', '.join(selected_variables),
            'Best average Val Loss': best_avg_loss_for_this_step,
            'Best average LR': best_lr_for_this_step,
        }

        # 添加种子详细结果
        for i, seed in enumerate(random_seeds):
            step_result[f'seed {seed} Val Loss'] = best_candidate_data['seed_losses'][i]
            step_result[f'seed {seed} Epochs Used'] = best_candidate_data['seed_epochs'][i]

        forward_selection_results.append(step_result)

        # 保存最终模型（两个种子中MSE最低的）
        best_seed_idx = np.argmin(best_candidate_data['seed_losses'])
        best_seed = random_seeds[best_seed_idx]
        best_model = best_candidate_data['seed_models'][best_seed]

        # 修改：使用新命名规则 GRU22_{变量数量}
        final_model_name = f'CNN3_{len(selected_variables)}.keras'  # 修改点
        final_model_save_path = os.path.join('/content/drive/My Drive', final_model_name)
        best_model.save(final_model_save_path)
        print(f"已保存最优模型到Google Drive: '{final_model_name}' (seed {best_seed})")

    else:
        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print("本步骤无改进变量")
        break

print("\n前向选择完成")
print(f"最终选中变量: {selected_variables}")

# 保存结果表格
results_df = pd.DataFrame(forward_selection_results)
results_csv_path = os.path.join('/content/drive/My Drive', 'CNN3_results.csv')
results_df.to_csv(results_csv_path, index=False)
print(f"已保存前向选择结果表格到Google Drive: {results_csv_path}")

# 显示结果表格
print("\n前向选择详细结果:")
display(results_df)
# Out:
# 开始前向选择，使用多个随机种子...
# 随机种子: [1, 2]
#
# 步骤 1: 选择第 1 个变量
# 当前已选变量: []
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0136 (轮次: 7)
#     种子 2:
#       验证损失: 0.0232 (轮次: 4)
#   平均验证损失: 0.0184 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0291 (轮次: 50)
#     种子 2:
#       验证损失: 0.0269 (轮次: 36)
#   平均验证损失: 0.0280 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0158 (轮次: 11)
#     种子 2:
#       验证损失: 0.0350 (轮次: 15)
#   平均验证损失: 0.0254 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0284 (轮次: 40)
#     种子 2:
#       验证损失: 0.0561 (轮次: 50)
#   平均验证损失: 0.0423 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0301 (轮次: 17)
#     种子 2:
#       验证损失: 0.0486 (轮次: 2)
#   平均验证损失: 0.0393 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0345 (轮次: 50)
#     种子 2:
#       验证损失: 0.0431 (轮次: 18)
#   平均验证损失: 0.0388 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0160 (轮次: 16)
#     种子 2:
#       验证损失: 0.0177 (轮次: 3)
#   平均验证损失: 0.0169 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dpc2_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0280 (轮次: 50)
#     种子 2:
#       验证损失: 0.0203 (轮次: 34)
#   平均验证损失: 0.0242 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0042 (轮次: 8)
#     种子 2:
#       验证损失: 0.0090 (轮次: 10)
#   平均验证损失: 0.0066 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0109 (轮次: 50)
#     种子 2:
#       验证损失: 0.0126 (轮次: 50)
#   平均验证损失: 0.0117 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0334 (轮次: 4)
#     种子 2:
#       验证损失: 0.0210 (轮次: 9)
#   平均验证损失: 0.0272 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0333 (轮次: 47)
#     种子 2:
#       验证损失: 0.0411 (轮次: 50)
#   平均验证损失: 0.0372 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0172 (轮次: 7)
#     种子 2:
#       验证损失: 0.0066 (轮次: 14)
#   平均验证损失: 0.0119 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0181 (轮次: 50)
#     种子 2:
#       验证损失: 0.0098 (轮次: 50)
#   平均验证损失: 0.0139 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0288 (轮次: 5)
#     种子 2:
#       验证损失: 0.0599 (轮次: 9)
#   平均验证损失: 0.0443 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0303 (轮次: 50)
#     种子 2:
#       验证损失: 0.0721 (轮次: 50)
#   平均验证损失: 0.0512 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0268 (轮次: 11)
#     种子 2:
#       验证损失: 0.0633 (轮次: 9)
#   平均验证损失: 0.0451 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0294 (轮次: 50)
#     种子 2:
#       验证损失: 0.0849 (轮次: 50)
#   平均验证损失: 0.0572 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0404 (轮次: 7)
#     种子 2:
#       验证损失: 0.0184 (轮次: 5)
#   平均验证损失: 0.0294 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0421 (轮次: 50)
#     种子 2:
#       验证损失: 0.0213 (轮次: 50)
#   平均验证损失: 0.0317 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0187 (轮次: 5)
#     种子 2:
#       验证损失: 0.0200 (轮次: 13)
#   平均验证损失: 0.0194 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0272 (轮次: 47)
#     种子 2:
#       验证损失: 0.0287 (轮次: 42)
#   平均验证损失: 0.0279 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0063 (轮次: 6)
#     种子 2:
#       验证损失: 0.0074 (轮次: 8)
#   平均验证损失: 0.0068 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0067 (轮次: 50)
#     种子 2:
#       验证损失: 0.0102 (轮次: 49)
#   平均验证损失: 0.0085 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0584 (轮次: 12)
#     种子 2:
#       验证损失: 0.0281 (轮次: 12)
#   平均验证损失: 0.0432 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0708 (轮次: 50)
#     种子 2:
#       验证损失: 0.0438 (轮次: 50)
#   平均验证损失: 0.0573 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0348 (轮次: 5)
#     种子 2:
#       验证损失: 0.0298 (轮次: 13)
#   平均验证损失: 0.0323 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0447 (轮次: 50)
#     种子 2:
#       验证损失: 0.0318 (轮次: 29)
#   平均验证损失: 0.0383 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0291 (轮次: 7)
#     种子 2:
#       验证损失: 0.0517 (轮次: 7)
#   平均验证损失: 0.0404 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0486 (轮次: 50)
#     种子 2:
#       验证损失: 0.0918 (轮次: 50)
#   平均验证损失: 0.0702 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0129 (轮次: 12)
#     种子 2:
#       验证损失: 0.0239 (轮次: 5)
#   平均验证损失: 0.0184 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0330 (轮次: 31)
#     种子 2:
#       验证损失: 0.0245 (轮次: 50)
#   平均验证损失: 0.0288 (学习率 0.001)
#
# --- 步骤 1 结果 ---
# 选中变量: 'dln_region_lag3'
# 最佳平均验证损失: 0.0066
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3']
# 已保存最优模型到Google Drive: 'CNN3_1.keras' (seed 1)
#
# 步骤 2: 选择第 2 个变量
# 当前已选变量: ['dln_region_lag3']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_region_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0223 (轮次: 16)
#     种子 2:
#       验证损失: 0.0201 (轮次: 4)
#   平均验证损失: 0.0212 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0296 (轮次: 50)
#     种子 2:
#       验证损失: 0.0215 (轮次: 37)
#   平均验证损失: 0.0255 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0068 (轮次: 9)
#     种子 2:
#       验证损失: 0.0224 (轮次: 8)
#   平均验证损失: 0.0146 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0203 (轮次: 50)
#     种子 2:
#       验证损失: 0.0342 (轮次: 50)
#   平均验证损失: 0.0272 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.1082 (轮次: 16)
#     种子 2:
#       验证损失: 0.0154 (轮次: 7)
#   平均验证损失: 0.0618 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.1219 (轮次: 50)
#     种子 2:
#       验证损失: 0.0217 (轮次: 42)
#   平均验证损失: 0.0718 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0627 (轮次: 6)
#     种子 2:
#       验证损失: 0.0221 (轮次: 2)
#   平均验证损失: 0.0424 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0815 (轮次: 50)
#     种子 2:
#       验证损失: 0.0213 (轮次: 20)
#   平均验证损失: 0.0514 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0325 (轮次: 16)
#     种子 2:
#       验证损失: 0.0260 (轮次: 12)
#   平均验证损失: 0.0293 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0467 (轮次: 50)
#     种子 2:
#       验证损失: 0.0256 (轮次: 20)
#   平均验证损失: 0.0362 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0220 (轮次: 5)
#     种子 2:
#       验证损失: 0.0261 (轮次: 3)
#   平均验证损失: 0.0241 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0293 (轮次: 47)
#     种子 2:
#       验证损失: 0.0263 (轮次: 23)
#   平均验证损失: 0.0278 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0542 (轮次: 19)
#     种子 2:
#       验证损失: 0.0496 (轮次: 8)
#   平均验证损失: 0.0519 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0677 (轮次: 50)
#     种子 2:
#       验证损失: 0.0577 (轮次: 50)
#   平均验证损失: 0.0627 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0254 (轮次: 21)
#     种子 2:
#       验证损失: 0.0155 (轮次: 6)
#   平均验证损失: 0.0205 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0465 (轮次: 50)
#     种子 2:
#       验证损失: 0.0274 (轮次: 40)
#   平均验证损失: 0.0369 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0059 (轮次: 6)
#     种子 2:
#       验证损失: 0.0159 (轮次: 15)
#   平均验证损失: 0.0109 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0077 (轮次: 45)
#     种子 2:
#       验证损失: 0.0239 (轮次: 26)
#   平均验证损失: 0.0158 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0470 (轮次: 4)
#     种子 2:
#       验证损失: 0.0321 (轮次: 3)
#   平均验证损失: 0.0396 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0594 (轮次: 41)
#     种子 2:
#       验证损失: 0.0310 (轮次: 40)
#   平均验证损失: 0.0452 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0103 (轮次: 5)
#     种子 2:
#       验证损失: 0.0242 (轮次: 3)
#   平均验证损失: 0.0172 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0123 (轮次: 41)
#     种子 2:
#       验证损失: 0.0244 (轮次: 27)
#   平均验证损失: 0.0183 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0495 (轮次: 7)
#     种子 2:
#       验证损失: 0.0443 (轮次: 2)
#   平均验证损失: 0.0469 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0733 (轮次: 50)
#     种子 2:
#       验证损失: 0.0401 (轮次: 19)
#   平均验证损失: 0.0567 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0245 (轮次: 18)
#     种子 2:
#       验证损失: 0.0443 (轮次: 10)
#   平均验证损失: 0.0344 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0387 (轮次: 29)
#     种子 2:
#       验证损失: 0.0528 (轮次: 48)
#   平均验证损失: 0.0458 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0825 (轮次: 14)
#     种子 2:
#       验证损失: 0.0493 (轮次: 20)
#   平均验证损失: 0.0659 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.1352 (轮次: 50)
#     种子 2:
#       验证损失: 0.0613 (轮次: 50)
#   平均验证损失: 0.0982 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0621 (轮次: 22)
#     种子 2:
#       验证损失: 0.0418 (轮次: 13)
#   平均验证损失: 0.0520 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0860 (轮次: 50)
#     种子 2:
#       验证损失: 0.0383 (轮次: 23)
#   平均验证损失: 0.0621 (学习率 0.001)
#
# --- 步骤 2 结果 ---
# 选中变量: 'dln_region_lag2'
# 最佳平均验证损失: 0.0109
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2']
# 已保存最优模型到Google Drive: 'CNN3_2.keras' (seed 1)
#
# 步骤 3: 选择第 3 个变量
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0297 (轮次: 11)
#     种子 2:
#       验证损失: 0.0165 (轮次: 16)
#   平均验证损失: 0.0231 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0297 (轮次: 43)
#     种子 2:
#       验证损失: 0.0271 (轮次: 50)
#   平均验证损失: 0.0284 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0350 (轮次: 1)
#     种子 2:
#       验证损失: 0.0340 (轮次: 14)
#   平均验证损失: 0.0345 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0343 (轮次: 7)
#     种子 2:
#       验证损失: 0.0446 (轮次: 5)
#   平均验证损失: 0.0395 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0435 (轮次: 11)
#     种子 2:
#       验证损失: 0.0170 (轮次: 11)
#   平均验证损失: 0.0303 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0444 (轮次: 14)
#     种子 2:
#       验证损失: 0.0178 (轮次: 41)
#   平均验证损失: 0.0311 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0521 (轮次: 1)
#     种子 2:
#       验证损失: 0.0251 (轮次: 8)
#   平均验证损失: 0.0386 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0555 (轮次: 6)
#     种子 2:
#       验证损失: 0.0423 (轮次: 10)
#   平均验证损失: 0.0489 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0094 (轮次: 1)
#     种子 2:
#       验证损失: 0.0475 (轮次: 10)
#   平均验证损失: 0.0285 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0086 (轮次: 10)
#     种子 2:
#       验证损失: 0.0783 (轮次: 8)
#   平均验证损失: 0.0434 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0153 (轮次: 8)
#     种子 2:
#       验证损失: 0.0164 (轮次: 7)
#   平均验证损失: 0.0158 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_city_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0140 (轮次: 15)
#     种子 2:
#       验证损失: 0.0230 (轮次: 50)
#   平均验证损失: 0.0185 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0793 (轮次: 10)
#     种子 2:
#       验证损失: 0.0203 (轮次: 14)
#   平均验证损失: 0.0498 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0900 (轮次: 10)
#     种子 2:
#       验证损失: 0.0368 (轮次: 11)
#   平均验证损失: 0.0634 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0263 (轮次: 12)
#     种子 2:
#       验证损失: 0.0451 (轮次: 11)
#   平均验证损失: 0.0357 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0356 (轮次: 50)
#     种子 2:
#       验证损失: 0.0534 (轮次: 9)
#   平均验证损失: 0.0445 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0118 (轮次: 2)
#     种子 2:
#       验证损失: 0.0189 (轮次: 6)
#   平均验证损失: 0.0153 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0099 (轮次: 14)
#     种子 2:
#       验证损失: 0.0245 (轮次: 15)
#   平均验证损失: 0.0172 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0112 (轮次: 11)
#     种子 2:
#       验证损失: 0.0124 (轮次: 10)
#   平均验证损失: 0.0118 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_city_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0163 (轮次: 30)
#     种子 2:
#       验证损失: 0.0154 (轮次: 50)
#   平均验证损失: 0.0158 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0516 (轮次: 11)
#     种子 2:
#       验证损失: 0.0452 (轮次: 10)
#   平均验证损失: 0.0484 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0570 (轮次: 50)
#     种子 2:
#       验证损失: 0.0680 (轮次: 12)
#   平均验证损失: 0.0625 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0535 (轮次: 9)
#     种子 2:
#       验证损失: 0.0566 (轮次: 13)
#   平均验证损失: 0.0550 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0612 (轮次: 50)
#     种子 2:
#       验证损失: 0.0633 (轮次: 8)
#   平均验证损失: 0.0622 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0277 (轮次: 2)
#     种子 2:
#       验证损失: 0.0164 (轮次: 3)
#   平均验证损失: 0.0221 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0251 (轮次: 29)
#     种子 2:
#       验证损失: 0.0182 (轮次: 27)
#   平均验证损失: 0.0216 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0335 (轮次: 11)
#     种子 2:
#       验证损失: 0.0308 (轮次: 5)
#   平均验证损失: 0.0321 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0334 (轮次: 13)
#     种子 2:
#       验证损失: 0.0332 (轮次: 30)
#   平均验证损失: 0.0333 (学习率 0.001)
#
# --- 步骤 3 结果 ---
# 选中变量: 'dln_city_lag2'
# 最佳平均验证损失: 0.0118
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2']
# 已保存最优模型到Google Drive: 'CNN3_3.keras' (seed 1)
#
# 步骤 4: 选择第 4 个变量
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0198 (轮次: 15)
#     种子 2:
#       验证损失: 0.0149 (轮次: 4)
#   平均验证损失: 0.0173 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0303 (轮次: 50)
#     种子 2:
#       验证损失: 0.0210 (轮次: 26)
#   平均验证损失: 0.0256 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0317 (轮次: 7)
#     种子 2:
#       验证损失: 0.0284 (轮次: 5)
#   平均验证损失: 0.0301 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0277 (轮次: 50)
#     种子 2:
#       验证损失: 0.0397 (轮次: 42)
#   平均验证损失: 0.0337 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0265 (轮次: 9)
#     种子 2:
#       验证损失: 0.0179 (轮次: 2)
#   平均验证损失: 0.0222 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0422 (轮次: 50)
#     种子 2:
#       验证损失: 0.0203 (轮次: 15)
#   平均验证损失: 0.0312 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0151 (轮次: 6)
#     种子 2:
#       验证损失: 0.0338 (轮次: 3)
#   平均验证损失: 0.0244 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0263 (轮次: 50)
#     种子 2:
#       验证损失: 0.0416 (轮次: 37)
#   平均验证损失: 0.0339 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0311 (轮次: 16)
#     种子 2:
#       验证损失: 0.0173 (轮次: 11)
#   平均验证损失: 0.0242 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0402 (轮次: 50)
#     种子 2:
#       验证损失: 0.0286 (轮次: 24)
#   平均验证损失: 0.0344 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0073 (轮次: 12)
#     种子 2:
#       验证损失: 0.0045 (轮次: 16)
#   平均验证损失: 0.0059 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_city_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0110 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 47)
#   平均验证损失: 0.0090 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0185 (轮次: 10)
#     种子 2:
#       验证损失: 0.0170 (轮次: 5)
#   平均验证损失: 0.0178 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0450 (轮次: 50)
#     种子 2:
#       验证损失: 0.0232 (轮次: 30)
#   平均验证损失: 0.0341 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0178 (轮次: 10)
#     种子 2:
#       验证损失: 0.0199 (轮次: 13)
#   平均验证损失: 0.0189 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0406 (轮次: 50)
#     种子 2:
#       验证损失: 0.0361 (轮次: 13)
#   平均验证损失: 0.0383 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0094 (轮次: 5)
#     种子 2:
#       验证损失: 0.0290 (轮次: 2)
#   平均验证损失: 0.0192 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0134 (轮次: 50)
#     种子 2:
#       验证损失: 0.0290 (轮次: 20)
#   平均验证损失: 0.0212 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0078 (轮次: 8)
#     种子 2:
#       验证损失: 0.0139 (轮次: 7)
#   平均验证损失: 0.0109 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0220 (轮次: 50)
#     种子 2:
#       验证损失: 0.0238 (轮次: 43)
#   平均验证损失: 0.0229 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0259 (轮次: 13)
#     种子 2:
#       验证损失: 0.0134 (轮次: 6)
#   平均验证损失: 0.0196 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0358 (轮次: 46)
#     种子 2:
#       验证损失: 0.0167 (轮次: 50)
#   平均验证损失: 0.0263 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0151 (轮次: 25)
#     种子 2:
#       验证损失: 0.0308 (轮次: 18)
#   平均验证损失: 0.0229 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0497 (轮次: 50)
#     种子 2:
#       验证损失: 0.0509 (轮次: 50)
#   平均验证损失: 0.0503 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0256 (轮次: 3)
#     种子 2:
#       验证损失: 0.0199 (轮次: 20)
#   平均验证损失: 0.0227 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0315 (轮次: 25)
#     种子 2:
#       验证损失: 0.0320 (轮次: 28)
#   平均验证损失: 0.0317 (学习率 0.001)
#
# --- 步骤 4 结果 ---
# 选中变量: 'dln_city_lag1'
# 最佳平均验证损失: 0.0059
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1']
# 已保存最优模型到Google Drive: 'CNN3_4.keras' (seed 2)
#
# 步骤 5: 选择第 5 个变量
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0074 (轮次: 5)
#     种子 2:
#       验证损失: 0.0275 (轮次: 26)
#   平均验证损失: 0.0174 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0082 (轮次: 44)
#     种子 2:
#       验证损失: 0.0465 (轮次: 50)
#   平均验证损失: 0.0273 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0450 (轮次: 15)
#     种子 2:
#       验证损失: 0.0200 (轮次: 10)
#   平均验证损失: 0.0325 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0697 (轮次: 50)
#     种子 2:
#       验证损失: 0.0545 (轮次: 13)
#   平均验证损失: 0.0621 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0176 (轮次: 6)
#     种子 2:
#       验证损失: 0.0197 (轮次: 7)
#   平均验证损失: 0.0186 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0227 (轮次: 36)
#     种子 2:
#       验证损失: 0.0157 (轮次: 7)
#   平均验证损失: 0.0192 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0153 (轮次: 6)
#     种子 2:
#       验证损失: 0.0546 (轮次: 1)
#   平均验证损失: 0.0350 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0235 (轮次: 50)
#     种子 2:
#       验证损失: 0.0608 (轮次: 10)
#   平均验证损失: 0.0421 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0266 (轮次: 7)
#     种子 2:
#       验证损失: 0.0235 (轮次: 9)
#   平均验证损失: 0.0251 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0358 (轮次: 48)
#     种子 2:
#       验证损失: 0.0313 (轮次: 16)
#   平均验证损失: 0.0336 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0166 (轮次: 10)
#     种子 2:
#       验证损失: 0.0657 (轮次: 9)
#   平均验证损失: 0.0411 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0179 (轮次: 26)
#     种子 2:
#       验证损失: 0.0840 (轮次: 15)
#   平均验证损失: 0.0509 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0119 (轮次: 6)
#     种子 2:
#       验证损失: 0.0482 (轮次: 1)
#   平均验证损失: 0.0301 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0174 (轮次: 50)
#     种子 2:
#       验证损失: 0.0445 (轮次: 13)
#   平均验证损失: 0.0310 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0123 (轮次: 6)
#     种子 2:
#       验证损失: 0.0177 (轮次: 10)
#   平均验证损失: 0.0150 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0101 (轮次: 50)
#     种子 2:
#       验证损失: 0.0331 (轮次: 17)
#   平均验证损失: 0.0216 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0176 (轮次: 9)
#     种子 2:
#       验证损失: 0.0205 (轮次: 23)
#   平均验证损失: 0.0190 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0197 (轮次: 50)
#     种子 2:
#       验证损失: 0.0735 (轮次: 17)
#   平均验证损失: 0.0466 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0143 (轮次: 14)
#     种子 2:
#       验证损失: 0.0130 (轮次: 14)
#   平均验证损失: 0.0137 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dpc2_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0179 (轮次: 42)
#     种子 2:
#       验证损失: 0.0438 (轮次: 17)
#   平均验证损失: 0.0309 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0357 (轮次: 1)
#     种子 2:
#       验证损失: 0.0426 (轮次: 5)
#   平均验证损失: 0.0391 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0364 (轮次: 14)
#     种子 2:
#       验证损失: 0.0549 (轮次: 50)
#   平均验证损失: 0.0456 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0025 (轮次: 7)
#     种子 2:
#       验证损失: 0.0407 (轮次: 1)
#   平均验证损失: 0.0216 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0060 (轮次: 50)
#     种子 2:
#       验证损失: 0.0415 (轮次: 9)
#   平均验证损失: 0.0237 (学习率 0.001)
#
# --- 步骤 5 结果 ---
# 选中变量: 'dpc2_lag1'
# 最佳平均验证损失: 0.0137
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1']
# 已保存最优模型到Google Drive: 'CNN3_5.keras' (seed 2)
#
# 步骤 6: 选择第 6 个变量
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0161 (轮次: 1)
#     种子 2:
#       验证损失: 0.0279 (轮次: 5)
#   平均验证损失: 0.0220 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0221 (轮次: 9)
#     种子 2:
#       验证损失: 0.0306 (轮次: 31)
#   平均验证损失: 0.0263 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0302 (轮次: 1)
#     种子 2:
#       验证损失: 0.0259 (轮次: 8)
#   平均验证损失: 0.0281 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0318 (轮次: 6)
#     种子 2:
#       验证损失: 0.0431 (轮次: 50)
#   平均验证损失: 0.0375 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0420 (轮次: 9)
#     种子 2:
#       验证损失: 0.0291 (轮次: 10)
#   平均验证损失: 0.0356 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0400 (轮次: 26)
#     种子 2:
#       验证损失: 0.0436 (轮次: 12)
#   平均验证损失: 0.0418 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0516 (轮次: 7)
#     种子 2:
#       验证损失: 0.0176 (轮次: 10)
#   平均验证损失: 0.0346 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0519 (轮次: 14)
#     种子 2:
#       验证损失: 0.0301 (轮次: 16)
#   平均验证损失: 0.0410 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0190 (轮次: 12)
#     种子 2:
#       验证损失: 0.0138 (轮次: 34)
#   平均验证损失: 0.0164 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc1_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0438 (轮次: 50)
#     种子 2:
#       验证损失: 0.0511 (轮次: 15)
#   平均验证损失: 0.0475 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0385 (轮次: 1)
#     种子 2:
#       验证损失: 0.0521 (轮次: 12)
#   平均验证损失: 0.0453 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0242 (轮次: 3)
#     种子 2:
#       验证损失: 0.0613 (轮次: 21)
#   平均验证损失: 0.0428 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0373 (轮次: 1)
#     种子 2:
#       验证损失: 0.0259 (轮次: 4)
#   平均验证损失: 0.0316 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0401 (轮次: 6)
#     种子 2:
#       验证损失: 0.0355 (轮次: 20)
#   平均验证损失: 0.0378 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0145 (轮次: 1)
#     种子 2:
#       验证损失: 0.0321 (轮次: 3)
#   平均验证损失: 0.0233 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0179 (轮次: 10)
#     种子 2:
#       验证损失: 0.0374 (轮次: 28)
#   平均验证损失: 0.0277 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0208 (轮次: 12)
#     种子 2:
#       验证损失: 0.0200 (轮次: 19)
#   平均验证损失: 0.0204 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0190 (轮次: 50)
#     种子 2:
#       验证损失: 0.0250 (轮次: 16)
#   平均验证损失: 0.0220 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0339 (轮次: 1)
#     种子 2:
#       验证损失: 0.0507 (轮次: 5)
#   平均验证损失: 0.0423 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0329 (轮次: 8)
#     种子 2:
#       验证损失: 0.0682 (轮次: 28)
#   平均验证损失: 0.0506 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0403 (轮次: 1)
#     种子 2:
#       验证损失: 0.0280 (轮次: 12)
#   平均验证损失: 0.0342 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0384 (轮次: 12)
#     种子 2:
#       验证损失: 0.0400 (轮次: 50)
#   平均验证损失: 0.0392 (学习率 0.001)
#
# --- 步骤 6 结果 ---
# 选中变量: 'pc1_lag1'
# 最佳平均验证损失: 0.0164
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1']
# 已保存最优模型到Google Drive: 'CNN3_6.keras' (seed 2)
#
# 步骤 7: 选择第 7 个变量
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'pc3_lag3', 'dpc2_lag3', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0514 (轮次: 3)
#     种子 2:
#       验证损失: 0.0719 (轮次: 18)
#   平均验证损失: 0.0617 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0527 (轮次: 35)
#     种子 2:
#       验证损失: 0.1339 (轮次: 50)
#   平均验证损失: 0.0933 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0358 (轮次: 3)
#     种子 2:
#       验证损失: 0.1099 (轮次: 13)
#   平均验证损失: 0.0729 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0418 (轮次: 33)
#     种子 2:
#       验证损失: 0.1121 (轮次: 31)
#   平均验证损失: 0.0769 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0409 (轮次: 2)
#     种子 2:
#       验证损失: 0.0857 (轮次: 31)
#   平均验证损失: 0.0633 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0399 (轮次: 22)
#     种子 2:
#       验证损失: 0.1063 (轮次: 36)
#   平均验证损失: 0.0731 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0175 (轮次: 35)
#     种子 2:
#       验证损失: 0.0627 (轮次: 14)
#   平均验证损失: 0.0401 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dpc2_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0248 (轮次: 50)
#     种子 2:
#       验证损失: 0.0687 (轮次: 50)
#   平均验证损失: 0.0467 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0129 (轮次: 31)
#     种子 2:
#       验证损失: 0.0655 (轮次: 12)
#   平均验证损失: 0.0392 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dln_gdp_sa_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0178 (轮次: 31)
#     种子 2:
#       验证损失: 0.0758 (轮次: 35)
#   平均验证损失: 0.0468 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0169 (轮次: 13)
#     种子 2:
#       验证损失: 0.0626 (轮次: 30)
#   平均验证损失: 0.0398 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0290 (轮次: 1)
#     种子 2:
#       验证损失: 0.0938 (轮次: 50)
#   平均验证损失: 0.0614 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0245 (轮次: 5)
#     种子 2:
#       验证损失: 0.0642 (轮次: 36)
#   平均验证损失: 0.0444 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0312 (轮次: 37)
#     种子 2:
#       验证损失: 0.1093 (轮次: 45)
#   平均验证损失: 0.0703 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0291 (轮次: 15)
#     种子 2:
#       验证损失: 0.0604 (轮次: 10)
#   平均验证损失: 0.0448 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0347 (轮次: 50)
#     种子 2:
#       验证损失: 0.0916 (轮次: 50)
#   平均验证损失: 0.0632 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0768 (轮次: 5)
#     种子 2:
#       验证损失: 0.0627 (轮次: 20)
#   平均验证损失: 0.0698 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0789 (轮次: 46)
#     种子 2:
#       验证损失: 0.0912 (轮次: 42)
#   平均验证损失: 0.0851 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0274 (轮次: 2)
#     种子 2:
#       验证损失: 0.0590 (轮次: 20)
#   平均验证损失: 0.0432 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0262 (轮次: 29)
#     种子 2:
#       验证损失: 0.0917 (轮次: 38)
#   平均验证损失: 0.0590 (学习率 0.001)
#
# --- 步骤 7 结果 ---
# 选中变量: 'dln_gdp_sa_lag3'
# 最佳平均验证损失: 0.0392
# 最佳学习率: 0.01
# 当前已选变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dln_gdp_sa_lag3']
# 已保存最优模型到Google Drive: 'CNN3_7.keras' (seed 1)
#
# 前向选择完成
# 最终选中变量: ['dln_region_lag3', 'dln_region_lag2', 'dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1', 'pc1_lag1', 'dln_gdp_sa_lag3']
# 已保存前向选择结果表格到Google Drive: /content/drive/My Drive/CNN3_results.csv
#
# 前向选择详细结果:
#    Step  Variable number                                 Selected Variables  \
# 0     1                1                                    dln_region_lag3
# 1     2                2                   dln_region_lag3, dln_region_lag2
# 2     3                3    dln_region_lag3, dln_region_lag2, dln_city_lag2
# 3     4                4  dln_region_lag3, dln_region_lag2, dln_city_lag...
# 4     5                5  dln_region_lag3, dln_region_lag2, dln_city_lag...
# 5     6                6  dln_region_lag3, dln_region_lag2, dln_city_lag...
# 6     7                7  dln_region_lag3, dln_region_lag2, dln_city_lag...
#
#    Best average Val Loss  Best average LR  seed 1 Val Loss  \
# 0               0.006609             0.01         0.004201
# 1               0.010909             0.01         0.005903
# 2               0.011786             0.01         0.011168
# 3               0.005873             0.01         0.007279
# 4               0.013651             0.01         0.014328
# 5               0.016414             0.01         0.019012
# 6               0.039162             0.01         0.012866
#
#    seed 1 Epochs Used  seed 2 Val Loss  seed 2 Epochs Used
# 0                   8         0.009016                  10
# 1                   6         0.015915                  15
# 2                  11         0.012405                  10
# 3                  12         0.004466                  16
# 4                  14         0.012974                  14
# 5                  12         0.013817                  34
# 6                  31         0.065458                  12

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

def build_cnn_model_filters4(input_shape, output_shape):
    """
    Builds a Sequential CNN model for time series forecasting with Conv1D filters=4.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).
        output_shape (int): The number of units in the output layer (prediction length).

    Returns:
        keras.src.engine.sequential.Sequential: Compiled CNN model.
    """
    model = Sequential()
    model.add(Conv1D(filters=4, kernel_size=4, activation='tanh', padding='causal', input_shape=input_shape)) # Changed filters to 4
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten()) # Flatten the output of the convolutional layers
    model.add(Dense(units=output_shape, activation='tanh')) # Output layer for forecasting

    model.compile(optimizer=Adam(), loss='mse') # Using Adam and MSE as requested
    return model

print("CNN model building function with filters=4 defined.")
# Out:
# CNN model building function with filters=4 defined.

# %%
# 确保可复现性
random_seeds = [1, 2]
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 定义GRU模型构建函数
def build_gru_model(input_shape, output_shape):
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh'))
    model.compile(optimizer=Adam(), loss='mse')
    return model

# 定义目标变量和候选自变量
target = 'dln_gdp_sa'
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# 滑动窗口参数
input_length = 40
output_length = 5

# 超参数
learning_rates = [0.01, 0.001]
epochs = 50
batch_size = 4
early_stopping_patience = 10
early_stopping_min_delta = 0.001

# 前向选择初始化
selected_variables = []
remaining_variables = candidate_independent_variables.copy()
forward_selection_results = []  # 存储结果表格

print("开始前向选择，使用多个随机种子...")
print(f"随机种子: {random_seeds}")

for step in range(7):
    best_variable_for_this_step = None
    best_avg_loss_for_this_step = float('inf')
    best_lr_for_this_step = None
    candidate_results = []  # 存储候选变量结果

    print(f"\n步骤 {step + 1}: 选择第 {len(selected_variables) + 1} 个变量")
    print(f"当前已选变量: {selected_variables}")
    print(f"剩余候选变量: {remaining_variables}")

    for candidate_variable in remaining_variables:
        current_variables = selected_variables + [candidate_variable]
        print(f"\n测试变量组合: {current_variables}")

        # 创建滑动窗口数据集
        X_full_current, y_full_current = create_sliding_window_datasets(
            data_clean, input_length, output_length, current_variables, target
        )

        num_samples_current = X_full_current.shape[0]
        num_train_samples_current = 8
        num_val_samples_current = 2

        if num_samples_current < num_train_samples_current + num_val_samples_current:
             print(f"跳过组合，样本不足 ({num_samples_current})")
             continue

        X_train_current = X_full_current[:num_train_samples_current]
        y_train_current = y_full_current[:num_train_samples_current]
        X_val_current = X_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]
        y_val_current = y_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]

        # 不同学习率训练
        for lr in learning_rates:
            print(f"  学习率: {lr}")
            seed_losses = []
            seed_models = {}
            seed_epochs = []

            for seed in random_seeds:
                # 设置种子
                np.random.seed(seed)
                tf.random.set_seed(seed)
                os.environ['PYTHONHASHSEED'] = str(seed)
                random.seed(seed)

                print(f"    种子 {seed}:")

                # 构建模型
                model = build_cnn_model_filters4(input_shape=(input_length, len(current_variables)),
                                      output_shape=output_length)
                model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

                # 早停回调
                early_stopping = EarlyStopping(
                    monitor='val_loss',
                    patience=early_stopping_patience,
                    min_delta=early_stopping_min_delta,
                    restore_best_weights=True
                )

                # 训练模型
                history = model.fit(
                    X_train_current, y_train_current,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val_current, y_val_current),
                    callbacks=[early_stopping],
                    verbose=0
                )

                # 获取最佳验证损失和轮次
                min_val_loss = min(history.history['val_loss'])
                best_epoch = history.history['val_loss'].index(min_val_loss) + 1

                # 记录结果
                seed_losses.append(min_val_loss)
                seed_models[seed] = model
                seed_epochs.append(best_epoch)

                print(f"      验证损失: {min_val_loss:.4f} (轮次: {best_epoch})")

            # 计算平均损失
            avg_loss = np.mean(seed_losses)
            print(f"  平均验证损失: {avg_loss:.4f} (学习率 {lr})")

            # 存储候选结果
            candidate_results.append({
                'variable': candidate_variable,
                'lr': lr,
                'avg_loss': avg_loss,
                'seed_losses': seed_losses,
                'seed_epochs': seed_epochs,
                'seed_models': seed_models
            })

            # 检查是否最佳组合
            if avg_loss < best_avg_loss_for_this_step:
                best_avg_loss_for_this_step = avg_loss
                best_variable_for_this_step = candidate_variable
                best_lr_for_this_step = lr

                # 暂时保存最佳模型
                best_seed_idx = np.argmin(seed_losses)
                best_seed = random_seeds[best_seed_idx]
                best_model_for_step = seed_models[best_seed]

                temp_model_save_path = f'/content/drive/My Drive/cnn4temp_best_model_step_{step+1}.keras'
                best_model_for_step.save(temp_model_save_path)
                print(f"  临时保存步骤 {step+1} 最佳模型: '{candidate_variable}', 学习率 {lr}, 种子 {best_seed}")

    # 添加最佳变量到已选列表
    if best_variable_for_this_step:
        selected_variables.append(best_variable_for_this_step)
        remaining_variables.remove(best_variable_for_this_step)

        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print(f"选中变量: '{best_variable_for_this_step}'")
        print(f"最佳平均验证损失: {best_avg_loss_for_this_step:.4f}")
        print(f"最佳学习率: {best_lr_for_this_step}")
        print(f"当前已选变量: {selected_variables}")

        # 获取最佳候选结果
        best_candidate_data = [d for d in candidate_results
                              if d['variable'] == best_variable_for_this_step
                              and d['lr'] == best_lr_for_this_step][0]

        # 记录结果到表格
        step_result = {
            'Step': step + 1,
            'Variable number': len(selected_variables),
            'Selected Variables': ', '.join(selected_variables),
            'Best average Val Loss': best_avg_loss_for_this_step,
            'Best average LR': best_lr_for_this_step,
        }

        # 添加种子详细结果
        for i, seed in enumerate(random_seeds):
            step_result[f'seed {seed} Val Loss'] = best_candidate_data['seed_losses'][i]
            step_result[f'seed {seed} Epochs Used'] = best_candidate_data['seed_epochs'][i]

        forward_selection_results.append(step_result)

        # 保存最终模型（两个种子中MSE最低的）
        best_seed_idx = np.argmin(best_candidate_data['seed_losses'])
        best_seed = random_seeds[best_seed_idx]
        best_model = best_candidate_data['seed_models'][best_seed]

        # 修改：使用新命名规则 CNN4_{变量数量}
        final_model_name = f'CNN4_{len(selected_variables)}.keras'  # 修改点
        final_model_save_path = os.path.join('/content/drive/My Drive', final_model_name)
        best_model.save(final_model_save_path)
        print(f"已保存最优模型到Google Drive: '{final_model_name}' (seed {best_seed})")

    else:
        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print("本步骤无改进变量")
        break

print("\n前向选择完成")
print(f"最终选中变量: {selected_variables}")

# 保存结果表格
results_df = pd.DataFrame(forward_selection_results)
results_csv_path = os.path.join('/content/drive/My Drive', 'CNN4_results.csv')
results_df.to_csv(results_csv_path, index=False)
print(f"已保存前向选择结果表格到Google Drive: {results_csv_path}")

# 显示结果表格
print("\n前向选择详细结果:")
display(results_df)
# Out:
# 开始前向选择，使用多个随机种子...
# 随机种子: [1, 2]
#
# 步骤 1: 选择第 1 个变量
# 当前已选变量: []
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0095 (轮次: 11)
#     种子 2:
#       验证损失: 0.0304 (轮次: 3)
#   平均验证损失: 0.0199 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0128 (轮次: 50)
#     种子 2:
#       验证损失: 0.0431 (轮次: 35)
#   平均验证损失: 0.0280 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0389 (轮次: 1)
#     种子 2:
#       验证损失: 0.0430 (轮次: 10)
#   平均验证损失: 0.0409 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0364 (轮次: 8)
#     种子 2:
#       验证损失: 0.0477 (轮次: 47)
#   平均验证损失: 0.0420 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0183 (轮次: 2)
#     种子 2:
#       验证损失: 0.0518 (轮次: 8)
#   平均验证损失: 0.0351 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0226 (轮次: 37)
#     种子 2:
#       验证损失: 0.0406 (轮次: 31)
#   平均验证损失: 0.0316 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0418 (轮次: 15)
#     种子 2:
#       验证损失: 0.0251 (轮次: 15)
#   平均验证损失: 0.0334 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0458 (轮次: 16)
#     种子 2:
#       验证损失: 0.0475 (轮次: 17)
#   平均验证损失: 0.0467 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0152 (轮次: 15)
#     种子 2:
#       验证损失: 0.0158 (轮次: 13)
#   平均验证损失: 0.0155 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0241 (轮次: 50)
#     种子 2:
#       验证损失: 0.0178 (轮次: 50)
#   平均验证损失: 0.0210 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0395 (轮次: 5)
#     种子 2:
#       验证损失: 0.0130 (轮次: 3)
#   平均验证损失: 0.0263 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0488 (轮次: 43)
#     种子 2:
#       验证损失: 0.0218 (轮次: 30)
#   平均验证损失: 0.0353 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0063 (轮次: 10)
#     种子 2:
#       验证损失: 0.0057 (轮次: 2)
#   平均验证损失: 0.0060 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_city_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0046 (轮次: 26)
#     种子 2:
#       验证损失: 0.0047 (轮次: 20)
#   平均验证损失: 0.0046 (学习率 0.001)
#   临时保存步骤 1 最佳模型: 'dln_city_lag1', 学习率 0.001, 种子 1
#
# 测试变量组合: ['dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0265 (轮次: 2)
#     种子 2:
#       验证损失: 0.0231 (轮次: 15)
#   平均验证损失: 0.0248 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0302 (轮次: 14)
#     种子 2:
#       验证损失: 0.0340 (轮次: 29)
#   平均验证损失: 0.0321 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0302 (轮次: 12)
#     种子 2:
#       验证损失: 0.0398 (轮次: 12)
#   平均验证损失: 0.0350 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0379 (轮次: 10)
#     种子 2:
#       验证损失: 0.0507 (轮次: 23)
#   平均验证损失: 0.0443 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0220 (轮次: 4)
#     种子 2:
#       验证损失: 0.0118 (轮次: 12)
#   平均验证损失: 0.0169 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0232 (轮次: 50)
#     种子 2:
#       验证损失: 0.0163 (轮次: 45)
#   平均验证损失: 0.0198 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0187 (轮次: 11)
#     种子 2:
#       验证损失: 0.0186 (轮次: 3)
#   平均验证损失: 0.0186 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0198 (轮次: 50)
#     种子 2:
#       验证损失: 0.0235 (轮次: 48)
#   平均验证损失: 0.0216 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0037 (轮次: 9)
#     种子 2:
#       验证损失: 0.0092 (轮次: 3)
#   平均验证损失: 0.0064 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0042 (轮次: 39)
#     种子 2:
#       验证损失: 0.0078 (轮次: 28)
#   平均验证损失: 0.0060 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0301 (轮次: 16)
#     种子 2:
#       验证损失: 0.0467 (轮次: 11)
#   平均验证损失: 0.0384 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0478 (轮次: 8)
#     种子 2:
#       验证损失: 0.0653 (轮次: 50)
#   平均验证损失: 0.0566 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0278 (轮次: 11)
#     种子 2:
#       验证损失: 0.0240 (轮次: 3)
#   平均验证损失: 0.0259 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0564 (轮次: 14)
#     种子 2:
#       验证损失: 0.0389 (轮次: 27)
#   平均验证损失: 0.0477 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0247 (轮次: 13)
#     种子 2:
#       验证损失: 0.0330 (轮次: 5)
#   平均验证损失: 0.0289 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0355 (轮次: 50)
#     种子 2:
#       验证损失: 0.0427 (轮次: 32)
#   平均验证损失: 0.0391 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0191 (轮次: 3)
#     种子 2:
#       验证损失: 0.0189 (轮次: 4)
#   平均验证损失: 0.0190 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0206 (轮次: 38)
#     种子 2:
#       验证损失: 0.0216 (轮次: 41)
#   平均验证损失: 0.0211 (学习率 0.001)
#
# --- 步骤 1 结果 ---
# 选中变量: 'dln_city_lag1'
# 最佳平均验证损失: 0.0046
# 最佳学习率: 0.001
# 当前已选变量: ['dln_city_lag1']
# 已保存最优模型到Google Drive: 'CNN4_1.keras' (seed 1)
#
# 步骤 2: 选择第 2 个变量
# 当前已选变量: ['dln_city_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0449 (轮次: 7)
#     种子 2:
#       验证损失: 0.0126 (轮次: 8)
#   平均验证损失: 0.0288 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0379 (轮次: 48)
#     种子 2:
#       验证损失: 0.0091 (轮次: 18)
#   平均验证损失: 0.0235 (学习率 0.001)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.001, 种子 2
#
# 测试变量组合: ['dln_city_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0376 (轮次: 14)
#     种子 2:
#       验证损失: 0.0269 (轮次: 17)
#   平均验证损失: 0.0323 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0514 (轮次: 46)
#     种子 2:
#       验证损失: 0.0359 (轮次: 50)
#   平均验证损失: 0.0437 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0341 (轮次: 12)
#     种子 2:
#       验证损失: 0.0398 (轮次: 1)
#   平均验证损失: 0.0370 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0460 (轮次: 50)
#     种子 2:
#       验证损失: 0.0495 (轮次: 14)
#   平均验证损失: 0.0477 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0236 (轮次: 7)
#     种子 2:
#       验证损失: 0.0311 (轮次: 2)
#   平均验证损失: 0.0274 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0396 (轮次: 50)
#     种子 2:
#       验证损失: 0.0303 (轮次: 17)
#   平均验证损失: 0.0349 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0085 (轮次: 10)
#     种子 2:
#       验证损失: 0.0050 (轮次: 7)
#   平均验证损失: 0.0068 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0152 (轮次: 50)
#     种子 2:
#       验证损失: 0.0087 (轮次: 35)
#   平均验证损失: 0.0120 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0261 (轮次: 6)
#     种子 2:
#       验证损失: 0.0251 (轮次: 18)
#   平均验证损失: 0.0256 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0470 (轮次: 50)
#     种子 2:
#       验证损失: 0.0396 (轮次: 28)
#   平均验证损失: 0.0433 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0209 (轮次: 7)
#     种子 2:
#       验证损失: 0.0380 (轮次: 10)
#   平均验证损失: 0.0294 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0229 (轮次: 44)
#     种子 2:
#       验证损失: 0.0484 (轮次: 43)
#   平均验证损失: 0.0356 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0385 (轮次: 14)
#     种子 2:
#       验证损失: 0.0227 (轮次: 14)
#   平均验证损失: 0.0306 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0408 (轮次: 36)
#     种子 2:
#       验证损失: 0.0410 (轮次: 9)
#   平均验证损失: 0.0409 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0084 (轮次: 10)
#     种子 2:
#       验证损失: 0.0113 (轮次: 1)
#   平均验证损失: 0.0099 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0085 (轮次: 48)
#     种子 2:
#       验证损失: 0.0109 (轮次: 19)
#   平均验证损失: 0.0097 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0262 (轮次: 4)
#     种子 2:
#       验证损失: 0.0098 (轮次: 1)
#   平均验证损失: 0.0180 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0281 (轮次: 47)
#     种子 2:
#       验证损失: 0.0112 (轮次: 12)
#   平均验证损失: 0.0196 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0039 (轮次: 6)
#     种子 2:
#       验证损失: 0.0080 (轮次: 8)
#   平均验证损失: 0.0060 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_city_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0043 (轮次: 37)
#     种子 2:
#       验证损失: 0.0094 (轮次: 35)
#   平均验证损失: 0.0068 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0240 (轮次: 16)
#     种子 2:
#       验证损失: 0.0394 (轮次: 15)
#   平均验证损失: 0.0317 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0386 (轮次: 50)
#     种子 2:
#       验证损失: 0.0614 (轮次: 12)
#   平均验证损失: 0.0500 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0560 (轮次: 4)
#     种子 2:
#       验证损失: 0.0241 (轮次: 10)
#   平均验证损失: 0.0400 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0533 (轮次: 50)
#     种子 2:
#       验证损失: 0.0344 (轮次: 7)
#   平均验证损失: 0.0439 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0449 (轮次: 3)
#     种子 2:
#       验证损失: 0.0400 (轮次: 3)
#   平均验证损失: 0.0424 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0524 (轮次: 38)
#     种子 2:
#       验证损失: 0.0507 (轮次: 24)
#   平均验证损失: 0.0516 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0121 (轮次: 6)
#     种子 2:
#       验证损失: 0.0105 (轮次: 2)
#   平均验证损失: 0.0113 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0121 (轮次: 50)
#     种子 2:
#       验证损失: 0.0103 (轮次: 25)
#   平均验证损失: 0.0112 (学习率 0.001)
#
# --- 步骤 2 结果 ---
# 选中变量: 'dln_city_lag2'
# 最佳平均验证损失: 0.0060
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2']
# 已保存最优模型到Google Drive: 'CNN4_2.keras' (seed 1)
#
# 步骤 3: 选择第 3 个变量
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0104 (轮次: 5)
#     种子 2:
#       验证损失: 0.0105 (轮次: 7)
#   平均验证损失: 0.0105 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0107 (轮次: 50)
#     种子 2:
#       验证损失: 0.0098 (轮次: 13)
#   平均验证损失: 0.0103 (学习率 0.001)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.001, 种子 2
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0207 (轮次: 9)
#     种子 2:
#       验证损失: 0.0248 (轮次: 2)
#   平均验证损失: 0.0228 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0202 (轮次: 50)
#     种子 2:
#       验证损失: 0.0217 (轮次: 28)
#   平均验证损失: 0.0210 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0304 (轮次: 2)
#     种子 2:
#       验证损失: 0.0401 (轮次: 3)
#   平均验证损失: 0.0353 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0247 (轮次: 17)
#     种子 2:
#       验证损失: 0.0367 (轮次: 40)
#   平均验证损失: 0.0307 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0118 (轮次: 3)
#     种子 2:
#       验证损失: 0.0187 (轮次: 16)
#   平均验证损失: 0.0153 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0212 (轮次: 29)
#     种子 2:
#       验证损失: 0.0322 (轮次: 50)
#   平均验证损失: 0.0267 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0186 (轮次: 11)
#     种子 2:
#       验证损失: 0.0062 (轮次: 5)
#   平均验证损失: 0.0124 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0274 (轮次: 31)
#     种子 2:
#       验证损失: 0.0078 (轮次: 34)
#   平均验证损失: 0.0176 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0353 (轮次: 5)
#     种子 2:
#       验证损失: 0.0074 (轮次: 12)
#   平均验证损失: 0.0214 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0472 (轮次: 50)
#     种子 2:
#       验证损失: 0.0182 (轮次: 50)
#   平均验证损失: 0.0327 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0169 (轮次: 9)
#     种子 2:
#       验证损失: 0.0240 (轮次: 14)
#   平均验证损失: 0.0204 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0168 (轮次: 20)
#     种子 2:
#       验证损失: 0.0212 (轮次: 37)
#   平均验证损失: 0.0190 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0264 (轮次: 10)
#     种子 2:
#       验证损失: 0.0186 (轮次: 6)
#   平均验证损失: 0.0225 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0296 (轮次: 39)
#     种子 2:
#       验证损失: 0.0239 (轮次: 38)
#   平均验证损失: 0.0268 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0314 (轮次: 11)
#     种子 2:
#       验证损失: 0.0078 (轮次: 6)
#   平均验证损失: 0.0196 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0354 (轮次: 36)
#     种子 2:
#       验证损失: 0.0097 (轮次: 38)
#   平均验证损失: 0.0225 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0211 (轮次: 4)
#     种子 2:
#       验证损失: 0.0126 (轮次: 4)
#   平均验证损失: 0.0169 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0215 (轮次: 37)
#     种子 2:
#       验证损失: 0.0138 (轮次: 30)
#   平均验证损失: 0.0177 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0181 (轮次: 3)
#     种子 2:
#       验证损失: 0.0098 (轮次: 15)
#   平均验证损失: 0.0139 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0211 (轮次: 26)
#     种子 2:
#       验证损失: 0.0255 (轮次: 50)
#   平均验证损失: 0.0233 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0446 (轮次: 3)
#     种子 2:
#       验证损失: 0.0104 (轮次: 8)
#   平均验证损失: 0.0275 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0527 (轮次: 28)
#     种子 2:
#       验证损失: 0.0248 (轮次: 50)
#   平均验证损失: 0.0387 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0245 (轮次: 2)
#     种子 2:
#       验证损失: 0.0409 (轮次: 7)
#   平均验证损失: 0.0327 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0250 (轮次: 21)
#     种子 2:
#       验证损失: 0.0502 (轮次: 49)
#   平均验证损失: 0.0376 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0282 (轮次: 4)
#     种子 2:
#       验证损失: 0.0238 (轮次: 11)
#   平均验证损失: 0.0260 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0414 (轮次: 50)
#     种子 2:
#       验证损失: 0.0247 (轮次: 23)
#   平均验证损失: 0.0331 (学习率 0.001)
#
# --- 步骤 3 结果 ---
# 选中变量: 'pc3_lag4'
# 最佳平均验证损失: 0.0103
# 最佳学习率: 0.001
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4']
# 已保存最优模型到Google Drive: 'CNN4_3.keras' (seed 2)
#
# 步骤 4: 选择第 4 个变量
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4']
# 剩余候选变量: ['dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0589 (轮次: 6)
#     种子 2:
#       验证损失: 0.0120 (轮次: 2)
#   平均验证损失: 0.0354 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0672 (轮次: 50)
#     种子 2:
#       验证损失: 0.0148 (轮次: 16)
#   平均验证损失: 0.0410 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0349 (轮次: 3)
#     种子 2:
#       验证损失: 0.0234 (轮次: 9)
#   平均验证损失: 0.0292 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0393 (轮次: 25)
#     种子 2:
#       验证损失: 0.0300 (轮次: 19)
#   平均验证损失: 0.0346 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0441 (轮次: 3)
#     种子 2:
#       验证损失: 0.0258 (轮次: 32)
#   平均验证损失: 0.0349 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0493 (轮次: 30)
#     种子 2:
#       验证损失: 0.0339 (轮次: 35)
#   平均验证损失: 0.0416 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0371 (轮次: 12)
#     种子 2:
#       验证损失: 0.0129 (轮次: 20)
#   平均验证损失: 0.0250 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0435 (轮次: 50)
#     种子 2:
#       验证损失: 0.0160 (轮次: 15)
#   平均验证损失: 0.0297 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0580 (轮次: 4)
#     种子 2:
#       验证损失: 0.0122 (轮次: 6)
#   平均验证损失: 0.0351 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0750 (轮次: 50)
#     种子 2:
#       验证损失: 0.0271 (轮次: 8)
#   平均验证损失: 0.0510 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0407 (轮次: 10)
#     种子 2:
#       验证损失: 0.0319 (轮次: 4)
#   平均验证损失: 0.0363 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0442 (轮次: 28)
#     种子 2:
#       验证损失: 0.0385 (轮次: 30)
#   平均验证损失: 0.0414 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0165 (轮次: 2)
#     种子 2:
#       验证损失: 0.0450 (轮次: 10)
#   平均验证损失: 0.0307 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0148 (轮次: 16)
#     种子 2:
#       验证损失: 0.0757 (轮次: 11)
#   平均验证损失: 0.0452 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0338 (轮次: 12)
#     种子 2:
#       验证损失: 0.0132 (轮次: 24)
#   平均验证损失: 0.0235 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0304 (轮次: 50)
#     种子 2:
#       验证损失: 0.0194 (轮次: 14)
#   平均验证损失: 0.0249 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0286 (轮次: 13)
#     种子 2:
#       验证损失: 0.0099 (轮次: 6)
#   平均验证损失: 0.0192 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0379 (轮次: 50)
#     种子 2:
#       验证损失: 0.0164 (轮次: 31)
#   平均验证损失: 0.0272 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0321 (轮次: 2)
#     种子 2:
#       验证损失: 0.0491 (轮次: 10)
#   平均验证损失: 0.0406 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0334 (轮次: 19)
#     种子 2:
#       验证损失: 0.0633 (轮次: 50)
#   平均验证损失: 0.0483 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0355 (轮次: 20)
#     种子 2:
#       验证损失: 0.0192 (轮次: 4)
#   平均验证损失: 0.0273 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0417 (轮次: 49)
#     种子 2:
#       验证损失: 0.0186 (轮次: 38)
#   平均验证损失: 0.0302 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0458 (轮次: 5)
#     种子 2:
#       验证损失: 0.0244 (轮次: 4)
#   平均验证损失: 0.0351 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0428 (轮次: 32)
#     种子 2:
#       验证损失: 0.0232 (轮次: 40)
#   平均验证损失: 0.0330 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0400 (轮次: 6)
#     种子 2:
#       验证损失: 0.0281 (轮次: 1)
#   平均验证损失: 0.0341 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0391 (轮次: 42)
#     种子 2:
#       验证损失: 0.0298 (轮次: 10)
#   平均验证损失: 0.0345 (学习率 0.001)
#
# --- 步骤 4 结果 ---
# 选中变量: 'pc3_lag3'
# 最佳平均验证损失: 0.0192
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3']
# 已保存最优模型到Google Drive: 'CNN4_4.keras' (seed 2)
#
# 步骤 5: 选择第 5 个变量
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3']
# 剩余候选变量: ['dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0262 (轮次: 5)
#     种子 2:
#       验证损失: 0.0415 (轮次: 9)
#   平均验证损失: 0.0339 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0411 (轮次: 43)
#     种子 2:
#       验证损失: 0.0547 (轮次: 13)
#   平均验证损失: 0.0479 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0096 (轮次: 10)
#     种子 2:
#       验证损失: 0.0447 (轮次: 16)
#   平均验证损失: 0.0271 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0212 (轮次: 48)
#     种子 2:
#       验证损失: 0.0678 (轮次: 50)
#   平均验证损失: 0.0445 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0301 (轮次: 13)
#     种子 2:
#       验证损失: 0.0261 (轮次: 4)
#   平均验证损失: 0.0281 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0570 (轮次: 45)
#     种子 2:
#       验证损失: 0.0399 (轮次: 50)
#   平均验证损失: 0.0485 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0295 (轮次: 10)
#     种子 2:
#       验证损失: 0.0137 (轮次: 15)
#   平均验证损失: 0.0216 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0436 (轮次: 28)
#     种子 2:
#       验证损失: 0.0259 (轮次: 50)
#   平均验证损失: 0.0348 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0727 (轮次: 6)
#     种子 2:
#       验证损失: 0.0156 (轮次: 15)
#   平均验证损失: 0.0441 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.1011 (轮次: 33)
#     种子 2:
#       验证损失: 0.0302 (轮次: 50)
#   平均验证损失: 0.0656 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0461 (轮次: 9)
#     种子 2:
#       验证损失: 0.0232 (轮次: 5)
#   平均验证损失: 0.0346 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0641 (轮次: 40)
#     种子 2:
#       验证损失: 0.0376 (轮次: 41)
#   平均验证损失: 0.0508 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0499 (轮次: 38)
#     种子 2:
#       验证损失: 0.0351 (轮次: 5)
#   平均验证损失: 0.0425 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0793 (轮次: 30)
#     种子 2:
#       验证损失: 0.0400 (轮次: 14)
#   平均验证损失: 0.0597 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0315 (轮次: 11)
#     种子 2:
#       验证损失: 0.0208 (轮次: 6)
#   平均验证损失: 0.0261 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0502 (轮次: 50)
#     种子 2:
#       验证损失: 0.0265 (轮次: 50)
#   平均验证损失: 0.0384 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0196 (轮次: 3)
#     种子 2:
#       验证损失: 0.0516 (轮次: 2)
#   平均验证损失: 0.0356 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0173 (轮次: 27)
#     种子 2:
#       验证损失: 0.0588 (轮次: 31)
#   平均验证损失: 0.0381 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0446 (轮次: 11)
#     种子 2:
#       验证损失: 0.0086 (轮次: 8)
#   平均验证损失: 0.0266 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0877 (轮次: 36)
#     种子 2:
#       验证损失: 0.0144 (轮次: 50)
#   平均验证损失: 0.0510 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0459 (轮次: 4)
#     种子 2:
#       验证损失: 0.0334 (轮次: 23)
#   平均验证损失: 0.0396 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0566 (轮次: 24)
#     种子 2:
#       验证损失: 0.0441 (轮次: 43)
#   平均验证损失: 0.0504 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0359 (轮次: 4)
#     种子 2:
#       验证损失: 0.0344 (轮次: 7)
#   平均验证损失: 0.0351 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0545 (轮次: 34)
#     种子 2:
#       验证损失: 0.0358 (轮次: 42)
#   平均验证损失: 0.0451 (学习率 0.001)
#
# --- 步骤 5 结果 ---
# 选中变量: 'dln_region_lag3'
# 最佳平均验证损失: 0.0216
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3']
# 已保存最优模型到Google Drive: 'CNN4_5.keras' (seed 2)
#
# 步骤 6: 选择第 6 个变量
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3']
# 剩余候选变量: ['dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0157 (轮次: 1)
#     种子 2:
#       验证损失: 0.0485 (轮次: 3)
#   平均验证损失: 0.0321 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0161 (轮次: 8)
#     种子 2:
#       验证损失: 0.0476 (轮次: 22)
#   平均验证损失: 0.0318 (学习率 0.001)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.001, 种子 1
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0149 (轮次: 10)
#     种子 2:
#       验证损失: 0.0578 (轮次: 4)
#   平均验证损失: 0.0363 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0208 (轮次: 50)
#     种子 2:
#       验证损失: 0.0662 (轮次: 33)
#   平均验证损失: 0.0435 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0216 (轮次: 10)
#     种子 2:
#       验证损失: 0.0422 (轮次: 3)
#   平均验证损失: 0.0319 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0338 (轮次: 48)
#     种子 2:
#       验证损失: 0.0466 (轮次: 29)
#   平均验证损失: 0.0402 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0383 (轮次: 2)
#     种子 2:
#       验证损失: 0.0169 (轮次: 3)
#   平均验证损失: 0.0276 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc1_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0428 (轮次: 20)
#     种子 2:
#       验证损失: 0.0279 (轮次: 26)
#   平均验证损失: 0.0353 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0129 (轮次: 11)
#     种子 2:
#       验证损失: 0.0242 (轮次: 11)
#   平均验证损失: 0.0185 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag3', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0220 (轮次: 20)
#     种子 2:
#       验证损失: 0.0300 (轮次: 50)
#   平均验证损失: 0.0260 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0126 (轮次: 2)
#     种子 2:
#       验证损失: 0.0260 (轮次: 7)
#   平均验证损失: 0.0193 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0069 (轮次: 16)
#     种子 2:
#       验证损失: 0.0281 (轮次: 31)
#   平均验证损失: 0.0175 (学习率 0.001)
#   临时保存步骤 6 最佳模型: 'dln_gdp_sa_lag2', 学习率 0.001, 种子 1
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0072 (轮次: 10)
#     种子 2:
#       验证损失: 0.0122 (轮次: 5)
#   平均验证损失: 0.0097 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dln_region_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0087 (轮次: 16)
#     种子 2:
#       验证损失: 0.0145 (轮次: 30)
#   平均验证损失: 0.0116 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0226 (轮次: 22)
#     种子 2:
#       验证损失: 0.0520 (轮次: 19)
#   平均验证损失: 0.0373 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0378 (轮次: 18)
#     种子 2:
#       验证损失: 0.0498 (轮次: 48)
#   平均验证损失: 0.0438 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0190 (轮次: 4)
#     种子 2:
#       验证损失: 0.0732 (轮次: 37)
#   平均验证损失: 0.0461 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0182 (轮次: 24)
#     种子 2:
#       验证损失: 0.0819 (轮次: 14)
#   平均验证损失: 0.0500 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0202 (轮次: 5)
#     种子 2:
#       验证损失: 0.0470 (轮次: 5)
#   平均验证损失: 0.0336 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0202 (轮次: 30)
#     种子 2:
#       验证损失: 0.0513 (轮次: 50)
#   平均验证损失: 0.0358 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0052 (轮次: 9)
#     种子 2:
#       验证损失: 0.0205 (轮次: 9)
#   平均验证损失: 0.0128 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0065 (轮次: 19)
#     种子 2:
#       验证损失: 0.0241 (轮次: 25)
#   平均验证损失: 0.0153 (学习率 0.001)
#
# --- 步骤 6 结果 ---
# 选中变量: 'dln_region_lag2'
# 最佳平均验证损失: 0.0097
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2']
# 已保存最优模型到Google Drive: 'CNN4_6.keras' (seed 1)
#
# 步骤 7: 选择第 7 个变量
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2']
# 剩余候选变量: ['dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0493 (轮次: 9)
#     种子 2:
#       验证损失: 0.1118 (轮次: 10)
#   平均验证损失: 0.0805 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0628 (轮次: 15)
#     种子 2:
#       验证损失: 0.1310 (轮次: 16)
#   平均验证损失: 0.0969 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0462 (轮次: 11)
#     种子 2:
#       验证损失: 0.0643 (轮次: 28)
#   平均验证损失: 0.0553 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0550 (轮次: 21)
#     种子 2:
#       验证损失: 0.1072 (轮次: 50)
#   平均验证损失: 0.0811 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0168 (轮次: 1)
#     种子 2:
#       验证损失: 0.0652 (轮次: 24)
#   平均验证损失: 0.0410 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'dpc2_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0159 (轮次: 12)
#     种子 2:
#       验证损失: 0.0830 (轮次: 41)
#   平均验证损失: 0.0494 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0356 (轮次: 7)
#     种子 2:
#       验证损失: 0.0860 (轮次: 24)
#   平均验证损失: 0.0608 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0442 (轮次: 35)
#     种子 2:
#       验证损失: 0.1540 (轮次: 50)
#   平均验证损失: 0.0991 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0298 (轮次: 9)
#     种子 2:
#       验证损失: 0.0543 (轮次: 4)
#   平均验证损失: 0.0420 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0459 (轮次: 14)
#     种子 2:
#       验证损失: 0.0625 (轮次: 50)
#   平均验证损失: 0.0542 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0205 (轮次: 8)
#     种子 2:
#       验证损失: 0.1478 (轮次: 3)
#   平均验证损失: 0.0842 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0328 (轮次: 12)
#     种子 2:
#       验证损失: 0.1488 (轮次: 17)
#   平均验证损失: 0.0908 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0247 (轮次: 8)
#     种子 2:
#       验证损失: 0.1089 (轮次: 1)
#   平均验证损失: 0.0668 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0219 (轮次: 22)
#     种子 2:
#       验证损失: 0.1145 (轮次: 4)
#   平均验证损失: 0.0682 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0213 (轮次: 8)
#     种子 2:
#       验证损失: 0.0816 (轮次: 13)
#   平均验证损失: 0.0515 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0421 (轮次: 10)
#     种子 2:
#       验证损失: 0.0999 (轮次: 50)
#   平均验证损失: 0.0710 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0653 (轮次: 7)
#     种子 2:
#       验证损失: 0.0556 (轮次: 18)
#   平均验证损失: 0.0605 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0653 (轮次: 5)
#     种子 2:
#       验证损失: 0.1201 (轮次: 50)
#   平均验证损失: 0.0927 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0269 (轮次: 7)
#     种子 2:
#       验证损失: 0.0894 (轮次: 19)
#   平均验证损失: 0.0581 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0324 (轮次: 32)
#     种子 2:
#       验证损失: 0.1737 (轮次: 50)
#   平均验证损失: 0.1031 (学习率 0.001)
#
# --- 步骤 7 结果 ---
# 选中变量: 'dpc2_lag4'
# 最佳平均验证损失: 0.0410
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dpc2_lag4']
# 已保存最优模型到Google Drive: 'CNN4_7.keras' (seed 1)
#
# 前向选择完成
# 最终选中变量: ['dln_city_lag1', 'dln_city_lag2', 'pc3_lag4', 'pc3_lag3', 'dln_region_lag3', 'dln_region_lag2', 'dpc2_lag4']
# 已保存前向选择结果表格到Google Drive: /content/drive/My Drive/CNN4_results.csv
#
# 前向选择详细结果:
#    Step  Variable number                                 Selected Variables  \
# 0     1                1                                      dln_city_lag1
# 1     2                2                       dln_city_lag1, dln_city_lag2
# 2     3                3             dln_city_lag1, dln_city_lag2, pc3_lag4
# 3     4                4   dln_city_lag1, dln_city_lag2, pc3_lag4, pc3_lag3
# 4     5                5  dln_city_lag1, dln_city_lag2, pc3_lag4, pc3_la...
# 5     6                6  dln_city_lag1, dln_city_lag2, pc3_lag4, pc3_la...
# 6     7                7  dln_city_lag1, dln_city_lag2, pc3_lag4, pc3_la...
#
#    Best average Val Loss  Best average LR  seed 1 Val Loss  \
# 0               0.004625            0.001         0.004598
# 1               0.005959            0.010         0.003881
# 2               0.010270            0.001         0.010703
# 3               0.019232            0.010         0.028578
# 4               0.021572            0.010         0.029470
# 5               0.009689            0.010         0.007192
# 6               0.040992            0.010         0.016795
#
#    seed 1 Epochs Used  seed 2 Val Loss  seed 2 Epochs Used
# 0                  26         0.004652                  20
# 1                   6         0.008038                   8
# 2                  50         0.009837                  13
# 3                  13         0.009885                   6
# 4                  10         0.013674                  15
# 5                  10         0.012186                   5
# 6                   1         0.065189                  24

# %%
import os
from google.colab import drive
import pandas as pd

# Mount Google Drive if not already mounted
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
else:
    print("Google Drive is already mounted.")

# Define the save path and filename
save_path = '/content/drive/My Drive'
summary_filename_cnn4 = os.path.join(save_path, 'CNN4_summary.csv') # Updated filename for CNN4

# Save the summary DataFrame to a CSV file
if 'summary_df_cnn4' in globals():
    summary_df_cnn4.to_csv(summary_filename_cnn4, index=False)
    print(f"Forward selection summary (CNN Filters=4) saved to: {summary_filename_cnn4}")
else:
    print("Error: 'summary_df_cnn4' DataFrame not found. Please ensure the forward selection code for CNN Filters=4 has been executed.")
# Out:
# Google Drive is already mounted.
# Forward selection summary (CNN Filters=4) saved to: /content/drive/My Drive/CNN4_summary.csv

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

def build_cnn_model_2layers_2filters(input_shape, output_shape):
    """
    Builds a Sequential 2-layer 1D CNN model for time series forecasting
    with 2 filters per layer.

    Args:
        input_shape (tuple): The shape of the input data (timesteps, features).
        output_shape (int): The number of units in the output layer (prediction length).

    Returns:
        keras.src.engine.sequential.Sequential: Compiled CNN model.
    """
    model = Sequential()
    # First Convolutional Block
    model.add(Conv1D(filters=2, kernel_size=4, activation='tanh', padding='causal', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))

    # Second Convolutional Block
    # Input shape to the second Conv1D will be (new_timesteps_after_pooling1, filters_1)
    model.add(Conv1D(filters=2, kernel_size=4, activation='tanh', padding='causal')) # No input_shape needed here
    model.add(MaxPooling1D(pool_size=2))

    # Flatten the output before the Dense layer
    model.add(Flatten())

    # Output Dense layer
    model.add(Dense(units=output_shape, activation='tanh'))

    model.compile(optimizer=Adam(), loss='mse') # Using Adam and MSE as requested
    return model

print("New 2-layer 1D CNN model building function with 2 filters per layer defined.")
# Out:
# New 2-layer 1D CNN model building function with 2 filters per layer defined.

# %%
# 确保可复现性
random_seeds = [1, 2]
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# 定义GRU模型构建函数
def build_gru_model(input_shape, output_shape):
    model = Sequential()
    model.add(GRU(units=3, return_sequences=False, input_shape=input_shape))
    model.add(Dropout(0.1))
    model.add(Dense(units=output_shape, activation='tanh'))
    model.compile(optimizer=Adam(), loss='mse')
    return model

# 定义目标变量和候选自变量
target = 'dln_gdp_sa'
candidate_independent_variables = ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']

# 滑动窗口参数
input_length = 40
output_length = 5

# 超参数
learning_rates = [0.01, 0.001]
epochs = 50
batch_size = 4
early_stopping_patience = 10
early_stopping_min_delta = 0.001

# 前向选择初始化
selected_variables = []
remaining_variables = candidate_independent_variables.copy()
forward_selection_results = []  # 存储结果表格

print("开始前向选择，使用多个随机种子...")
print(f"随机种子: {random_seeds}")

for step in range(7):
    best_variable_for_this_step = None
    best_avg_loss_for_this_step = float('inf')
    best_lr_for_this_step = None
    candidate_results = []  # 存储候选变量结果

    print(f"\n步骤 {step + 1}: 选择第 {len(selected_variables) + 1} 个变量")
    print(f"当前已选变量: {selected_variables}")
    print(f"剩余候选变量: {remaining_variables}")

    for candidate_variable in remaining_variables:
        current_variables = selected_variables + [candidate_variable]
        print(f"\n测试变量组合: {current_variables}")

        # 创建滑动窗口数据集
        X_full_current, y_full_current = create_sliding_window_datasets(
            data_clean, input_length, output_length, current_variables, target
        )

        num_samples_current = X_full_current.shape[0]
        num_train_samples_current = 8
        num_val_samples_current = 2

        if num_samples_current < num_train_samples_current + num_val_samples_current:
             print(f"跳过组合，样本不足 ({num_samples_current})")
             continue

        X_train_current = X_full_current[:num_train_samples_current]
        y_train_current = y_full_current[:num_train_samples_current]
        X_val_current = X_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]
        y_val_current = y_full_current[num_train_samples_current:num_train_samples_current + num_val_samples_current]

        # 不同学习率训练
        for lr in learning_rates:
            print(f"  学习率: {lr}")
            seed_losses = []
            seed_models = {}
            seed_epochs = []

            for seed in random_seeds:
                # 设置种子
                np.random.seed(seed)
                tf.random.set_seed(seed)
                os.environ['PYTHONHASHSEED'] = str(seed)
                random.seed(seed)

                print(f"    种子 {seed}:")

                # 构建模型
                model = build_cnn_model_2layers_2filters(input_shape=(input_length, len(current_variables)),
                                      output_shape=output_length)
                model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

                # 早停回调
                early_stopping = EarlyStopping(
                    monitor='val_loss',
                    patience=early_stopping_patience,
                    min_delta=early_stopping_min_delta,
                    restore_best_weights=True
                )

                # 训练模型
                history = model.fit(
                    X_train_current, y_train_current,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val_current, y_val_current),
                    callbacks=[early_stopping],
                    verbose=0
                )

                # 获取最佳验证损失和轮次
                min_val_loss = min(history.history['val_loss'])
                best_epoch = history.history['val_loss'].index(min_val_loss) + 1

                # 记录结果
                seed_losses.append(min_val_loss)
                seed_models[seed] = model
                seed_epochs.append(best_epoch)

                print(f"      验证损失: {min_val_loss:.4f} (轮次: {best_epoch})")

            # 计算平均损失
            avg_loss = np.mean(seed_losses)
            print(f"  平均验证损失: {avg_loss:.4f} (学习率 {lr})")

            # 存储候选结果
            candidate_results.append({
                'variable': candidate_variable,
                'lr': lr,
                'avg_loss': avg_loss,
                'seed_losses': seed_losses,
                'seed_epochs': seed_epochs,
                'seed_models': seed_models
            })

            # 检查是否最佳组合
            if avg_loss < best_avg_loss_for_this_step:
                best_avg_loss_for_this_step = avg_loss
                best_variable_for_this_step = candidate_variable
                best_lr_for_this_step = lr

                # 暂时保存最佳模型
                best_seed_idx = np.argmin(seed_losses)
                best_seed = random_seeds[best_seed_idx]
                best_model_for_step = seed_models[best_seed]

                temp_model_save_path = f'/content/drive/My Drive/cnn22temp_best_model_step_{step+1}.keras'
                best_model_for_step.save(temp_model_save_path)
                print(f"  临时保存步骤 {step+1} 最佳模型: '{candidate_variable}', 学习率 {lr}, 种子 {best_seed}")

    # 添加最佳变量到已选列表
    if best_variable_for_this_step:
        selected_variables.append(best_variable_for_this_step)
        remaining_variables.remove(best_variable_for_this_step)

        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print(f"选中变量: '{best_variable_for_this_step}'")
        print(f"最佳平均验证损失: {best_avg_loss_for_this_step:.4f}")
        print(f"最佳学习率: {best_lr_for_this_step}")
        print(f"当前已选变量: {selected_variables}")

        # 获取最佳候选结果
        best_candidate_data = [d for d in candidate_results
                              if d['variable'] == best_variable_for_this_step
                              and d['lr'] == best_lr_for_this_step][0]

        # 记录结果到表格
        step_result = {
            'Step': step + 1,
            'Variable number': len(selected_variables),
            'Selected Variables': ', '.join(selected_variables),
            'Best average Val Loss': best_avg_loss_for_this_step,
            'Best average LR': best_lr_for_this_step,
        }

        # 添加种子详细结果
        for i, seed in enumerate(random_seeds):
            step_result[f'seed {seed} Val Loss'] = best_candidate_data['seed_losses'][i]
            step_result[f'seed {seed} Epochs Used'] = best_candidate_data['seed_epochs'][i]

        forward_selection_results.append(step_result)

        # 保存最终模型（两个种子中MSE最低的）
        best_seed_idx = np.argmin(best_candidate_data['seed_losses'])
        best_seed = random_seeds[best_seed_idx]
        best_model = best_candidate_data['seed_models'][best_seed]

        # 修改：使用新命名规则 CNN4_{变量数量}
        final_model_name = f'CNN22_{len(selected_variables)}.keras'  # 修改点
        final_model_save_path = os.path.join('/content/drive/My Drive', final_model_name)
        best_model.save(final_model_save_path)
        print(f"已保存最优模型到Google Drive: '{final_model_name}' (seed {best_seed})")

    else:
        print(f"\n--- 步骤 {step + 1} 结果 ---")
        print("本步骤无改进变量")
        break

print("\n前向选择完成")
print(f"最终选中变量: {selected_variables}")

# 保存结果表格
results_df = pd.DataFrame(forward_selection_results)
results_csv_path = os.path.join('/content/drive/My Drive', 'CNN22_results.csv')
results_df.to_csv(results_csv_path, index=False)
print(f"已保存前向选择结果表格到Google Drive: {results_csv_path}")

# 显示结果表格
print("\n前向选择详细结果:")
display(results_df)
# Out:
# 开始前向选择，使用多个随机种子...
# 随机种子: [1, 2]
#
# 步骤 1: 选择第 1 个变量
# 当前已选变量: []
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dln_city_lag2', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0046 (轮次: 12)
#     种子 2:
#       验证损失: 0.0044 (轮次: 4)
#   平均验证损失: 0.0045 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0073 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 46)
#   平均验证损失: 0.0070 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0055 (轮次: 14)
#     种子 2:
#       验证损失: 0.0128 (轮次: 8)
#   平均验证损失: 0.0091 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0127 (轮次: 41)
#     种子 2:
#       验证损失: 0.0168 (轮次: 50)
#   平均验证损失: 0.0147 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0050 (轮次: 15)
#     种子 2:
#       验证损失: 0.0155 (轮次: 22)
#   平均验证损失: 0.0103 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0088 (轮次: 50)
#     种子 2:
#       验证损失: 0.0264 (轮次: 44)
#   平均验证损失: 0.0176 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0101 (轮次: 15)
#     种子 2:
#       验证损失: 0.0033 (轮次: 8)
#   平均验证损失: 0.0067 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0238 (轮次: 50)
#     种子 2:
#       验证损失: 0.0068 (轮次: 50)
#   平均验证损失: 0.0153 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0035 (轮次: 9)
#     种子 2:
#       验证损失: 0.0118 (轮次: 3)
#   平均验证损失: 0.0076 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0035 (轮次: 35)
#     种子 2:
#       验证损失: 0.0139 (轮次: 27)
#   平均验证损失: 0.0087 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0139 (轮次: 1)
#     种子 2:
#       验证损失: 0.0173 (轮次: 26)
#   平均验证损失: 0.0156 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0112 (轮次: 15)
#     种子 2:
#       验证损失: 0.0478 (轮次: 50)
#   平均验证损失: 0.0295 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0048 (轮次: 13)
#     种子 2:
#       验证损失: 0.0080 (轮次: 3)
#   平均验证损失: 0.0064 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0053 (轮次: 32)
#     种子 2:
#       验证损失: 0.0102 (轮次: 35)
#   平均验证损失: 0.0077 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0100 (轮次: 11)
#     种子 2:
#       验证损失: 0.0219 (轮次: 7)
#   平均验证损失: 0.0159 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0124 (轮次: 50)
#     种子 2:
#       验证损失: 0.0294 (轮次: 50)
#   平均验证损失: 0.0209 (学习率 0.001)
#
# 测试变量组合: ['dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0089 (轮次: 12)
#     种子 2:
#       验证损失: 0.0165 (轮次: 8)
#   平均验证损失: 0.0127 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0126 (轮次: 50)
#     种子 2:
#       验证损失: 0.0235 (轮次: 50)
#   平均验证损失: 0.0180 (学习率 0.001)
#
# 测试变量组合: ['dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0070 (轮次: 3)
#     种子 2:
#       验证损失: 0.0054 (轮次: 3)
#   平均验证损失: 0.0062 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0067 (轮次: 34)
#     种子 2:
#       验证损失: 0.0092 (轮次: 30)
#   平均验证损失: 0.0079 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0065 (轮次: 7)
#     种子 2:
#       验证损失: 0.0046 (轮次: 25)
#   平均验证损失: 0.0056 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0083 (轮次: 50)
#     种子 2:
#       验证损失: 0.0127 (轮次: 50)
#   平均验证损失: 0.0105 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0024 (轮次: 13)
#     种子 2:
#       验证损失: 0.0059 (轮次: 7)
#   平均验证损失: 0.0042 (学习率 0.01)
#   临时保存步骤 1 最佳模型: 'dln_city_lag2', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0044 (轮次: 29)
#     种子 2:
#       验证损失: 0.0071 (轮次: 30)
#   平均验证损失: 0.0058 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0116 (轮次: 14)
#     种子 2:
#       验证损失: 0.0158 (轮次: 4)
#   平均验证损失: 0.0137 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0222 (轮次: 50)
#     种子 2:
#       验证损失: 0.0214 (轮次: 50)
#   平均验证损失: 0.0218 (学习率 0.001)
#
# 测试变量组合: ['dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0080 (轮次: 7)
#     种子 2:
#       验证损失: 0.0248 (轮次: 18)
#   平均验证损失: 0.0164 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0168 (轮次: 50)
#     种子 2:
#       验证损失: 0.0436 (轮次: 50)
#   平均验证损失: 0.0302 (学习率 0.001)
#
# 测试变量组合: ['pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0117 (轮次: 13)
#     种子 2:
#       验证损失: 0.0108 (轮次: 22)
#   平均验证损失: 0.0113 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0191 (轮次: 50)
#     种子 2:
#       验证损失: 0.0529 (轮次: 50)
#   平均验证损失: 0.0360 (学习率 0.001)
#
# 测试变量组合: ['pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0065 (轮次: 11)
#     种子 2:
#       验证损失: 0.0102 (轮次: 12)
#   平均验证损失: 0.0083 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0124 (轮次: 50)
#     种子 2:
#       验证损失: 0.0093 (轮次: 20)
#   平均验证损失: 0.0108 (学习率 0.001)
#
# --- 步骤 1 结果 ---
# 选中变量: 'dln_city_lag2'
# 最佳平均验证损失: 0.0042
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2']
# 已保存最优模型到Google Drive: 'CNN22_1.keras' (seed 1)
#
# 步骤 2: 选择第 2 个变量
# 当前已选变量: ['dln_city_lag2']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_city_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag2', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0040 (轮次: 21)
#     种子 2:
#       验证损失: 0.0066 (轮次: 4)
#   平均验证损失: 0.0053 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0182 (轮次: 50)
#     种子 2:
#       验证损失: 0.0071 (轮次: 44)
#   平均验证损失: 0.0126 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0038 (轮次: 9)
#     种子 2:
#       验证损失: 0.0206 (轮次: 9)
#   平均验证损失: 0.0122 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0101 (轮次: 50)
#     种子 2:
#       验证损失: 0.0266 (轮次: 50)
#   平均验证损失: 0.0184 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0081 (轮次: 17)
#     种子 2:
#       验证损失: 0.0087 (轮次: 2)
#   平均验证损失: 0.0084 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0232 (轮次: 50)
#     种子 2:
#       验证损失: 0.0089 (轮次: 16)
#   平均验证损失: 0.0160 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0063 (轮次: 5)
#     种子 2:
#       验证损失: 0.0140 (轮次: 9)
#   平均验证损失: 0.0101 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0125 (轮次: 50)
#     种子 2:
#       验证损失: 0.0218 (轮次: 50)
#   平均验证损失: 0.0171 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0049 (轮次: 12)
#     种子 2:
#       验证损失: 0.0064 (轮次: 7)
#   平均验证损失: 0.0057 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0074 (轮次: 50)
#     种子 2:
#       验证损失: 0.0081 (轮次: 20)
#   平均验证损失: 0.0078 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0080 (轮次: 3)
#     种子 2:
#       验证损失: 0.0104 (轮次: 4)
#   平均验证损失: 0.0092 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0079 (轮次: 32)
#     种子 2:
#       验证损失: 0.0150 (轮次: 35)
#   平均验证损失: 0.0114 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0026 (轮次: 15)
#     种子 2:
#       验证损失: 0.0039 (轮次: 7)
#   平均验证损失: 0.0033 (学习率 0.01)
#   临时保存步骤 2 最佳模型: 'dln_city_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0039 (轮次: 40)
#     种子 2:
#       验证损失: 0.0074 (轮次: 48)
#   平均验证损失: 0.0057 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0032 (轮次: 10)
#     种子 2:
#       验证损失: 0.0102 (轮次: 8)
#   平均验证损失: 0.0067 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0130 (轮次: 50)
#     种子 2:
#       验证损失: 0.0183 (轮次: 50)
#   平均验证损失: 0.0157 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0187 (轮次: 13)
#     种子 2:
#       验证损失: 0.0160 (轮次: 3)
#   平均验证损失: 0.0173 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0480 (轮次: 50)
#     种子 2:
#       验证损失: 0.0197 (轮次: 35)
#   平均验证损失: 0.0338 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0093 (轮次: 17)
#     种子 2:
#       验证损失: 0.0031 (轮次: 3)
#   平均验证损失: 0.0062 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0154 (轮次: 38)
#     种子 2:
#       验证损失: 0.0038 (轮次: 28)
#   平均验证损失: 0.0096 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0059 (轮次: 13)
#     种子 2:
#       验证损失: 0.0056 (轮次: 5)
#   平均验证损失: 0.0057 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0102 (轮次: 50)
#     种子 2:
#       验证损失: 0.0105 (轮次: 50)
#   平均验证损失: 0.0103 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0079 (轮次: 6)
#     种子 2:
#       验证损失: 0.0144 (轮次: 15)
#   平均验证损失: 0.0111 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0154 (轮次: 50)
#     种子 2:
#       验证损失: 0.0288 (轮次: 50)
#   平均验证损失: 0.0221 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0069 (轮次: 5)
#     种子 2:
#       验证损失: 0.0083 (轮次: 5)
#   平均验证损失: 0.0076 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0132 (轮次: 46)
#     种子 2:
#       验证损失: 0.0147 (轮次: 50)
#   平均验证损失: 0.0139 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0184 (轮次: 9)
#     种子 2:
#       验证损失: 0.0234 (轮次: 5)
#   平均验证损失: 0.0209 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0511 (轮次: 50)
#     种子 2:
#       验证损失: 0.0275 (轮次: 50)
#   平均验证损失: 0.0393 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0021 (轮次: 16)
#     种子 2:
#       验证损失: 0.0128 (轮次: 10)
#   平均验证损失: 0.0075 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0045 (轮次: 50)
#     种子 2:
#       验证损失: 0.0207 (轮次: 24)
#   平均验证损失: 0.0126 (学习率 0.001)
#
# --- 步骤 2 结果 ---
# 选中变量: 'dln_city_lag1'
# 最佳平均验证损失: 0.0033
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1']
# 已保存最优模型到Google Drive: 'CNN22_2.keras' (seed 1)
#
# 步骤 3: 选择第 3 个变量
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0097 (轮次: 13)
#     种子 2:
#       验证损失: 0.0067 (轮次: 5)
#   平均验证损失: 0.0082 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0150 (轮次: 19)
#     种子 2:
#       验证损失: 0.0132 (轮次: 50)
#   平均验证损失: 0.0141 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0105 (轮次: 16)
#     种子 2:
#       验证损失: 0.0161 (轮次: 2)
#   平均验证损失: 0.0133 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0135 (轮次: 50)
#     种子 2:
#       验证损失: 0.0158 (轮次: 27)
#   平均验证损失: 0.0147 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0037 (轮次: 12)
#     种子 2:
#       验证损失: 0.0056 (轮次: 6)
#   平均验证损失: 0.0047 (学习率 0.01)
#   临时保存步骤 3 最佳模型: 'dln_gdp_sa_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0079 (轮次: 20)
#     种子 2:
#       验证损失: 0.0067 (轮次: 32)
#   平均验证损失: 0.0073 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0091 (轮次: 2)
#     种子 2:
#       验证损失: 0.0092 (轮次: 9)
#   平均验证损失: 0.0092 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0127 (轮次: 21)
#     种子 2:
#       验证损失: 0.0134 (轮次: 50)
#   平均验证损失: 0.0131 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0038 (轮次: 10)
#     种子 2:
#       验证损失: 0.0063 (轮次: 2)
#   平均验证损失: 0.0050 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0054 (轮次: 37)
#     种子 2:
#       验证损失: 0.0068 (轮次: 29)
#   平均验证损失: 0.0061 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0097 (轮次: 13)
#     种子 2:
#       验证损失: 0.0113 (轮次: 3)
#   平均验证损失: 0.0105 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0183 (轮次: 50)
#     种子 2:
#       验证损失: 0.0124 (轮次: 36)
#   平均验证损失: 0.0153 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0104 (轮次: 13)
#     种子 2:
#       验证损失: 0.0121 (轮次: 8)
#   平均验证损失: 0.0112 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0174 (轮次: 21)
#     种子 2:
#       验证损失: 0.0174 (轮次: 17)
#   平均验证损失: 0.0174 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0098 (轮次: 13)
#     种子 2:
#       验证损失: 0.0083 (轮次: 7)
#   平均验证损失: 0.0091 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0132 (轮次: 20)
#     种子 2:
#       验证损失: 0.0108 (轮次: 46)
#   平均验证损失: 0.0120 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0068 (轮次: 12)
#     种子 2:
#       验证损失: 0.0126 (轮次: 5)
#   平均验证损失: 0.0097 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0095 (轮次: 31)
#     种子 2:
#       验证损失: 0.0133 (轮次: 42)
#   平均验证损失: 0.0114 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0063 (轮次: 12)
#     种子 2:
#       验证损失: 0.0033 (轮次: 5)
#   平均验证损失: 0.0048 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0126 (轮次: 23)
#     种子 2:
#       验证损失: 0.0078 (轮次: 50)
#   平均验证损失: 0.0102 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0187 (轮次: 14)
#     种子 2:
#       验证损失: 0.0126 (轮次: 18)
#   平均验证损失: 0.0157 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0240 (轮次: 37)
#     种子 2:
#       验证损失: 0.0222 (轮次: 50)
#   平均验证损失: 0.0231 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0232 (轮次: 12)
#     种子 2:
#       验证损失: 0.0126 (轮次: 6)
#   平均验证损失: 0.0179 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0300 (轮次: 26)
#     种子 2:
#       验证损失: 0.0199 (轮次: 43)
#   平均验证损失: 0.0249 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0131 (轮次: 6)
#     种子 2:
#       验证损失: 0.0291 (轮次: 7)
#   平均验证损失: 0.0211 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0217 (轮次: 50)
#     种子 2:
#       验证损失: 0.0426 (轮次: 50)
#   平均验证损失: 0.0321 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0035 (轮次: 11)
#     种子 2:
#       验证损失: 0.0073 (轮次: 15)
#   平均验证损失: 0.0054 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0077 (轮次: 50)
#     种子 2:
#       验证损失: 0.0101 (轮次: 32)
#   平均验证损失: 0.0089 (学习率 0.001)
#
# --- 步骤 3 结果 ---
# 选中变量: 'dln_gdp_sa_lag4'
# 最佳平均验证损失: 0.0047
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4']
# 已保存最优模型到Google Drive: 'CNN22_3.keras' (seed 1)
#
# 步骤 4: 选择第 4 个变量
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4']
# 剩余候选变量: ['pc3_lag4', 'dln_gdp_sa_lag1', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0053 (轮次: 7)
#     种子 2:
#       验证损失: 0.0169 (轮次: 16)
#   平均验证损失: 0.0111 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0099 (轮次: 50)
#     种子 2:
#       验证损失: 0.0246 (轮次: 27)
#   平均验证损失: 0.0172 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0030 (轮次: 12)
#     种子 2:
#       验证损失: 0.0127 (轮次: 8)
#   平均验证损失: 0.0079 (学习率 0.01)
#   临时保存步骤 4 最佳模型: 'dln_gdp_sa_lag1', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0125 (轮次: 50)
#     种子 2:
#       验证损失: 0.0153 (轮次: 41)
#   平均验证损失: 0.0139 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0120 (轮次: 19)
#     种子 2:
#       验证损失: 0.0113 (轮次: 17)
#   平均验证损失: 0.0116 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0361 (轮次: 50)
#     种子 2:
#       验证损失: 0.0155 (轮次: 50)
#   平均验证损失: 0.0258 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0087 (轮次: 13)
#     种子 2:
#       验证损失: 0.0132 (轮次: 8)
#   平均验证损失: 0.0109 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0326 (轮次: 50)
#     种子 2:
#       验证损失: 0.0118 (轮次: 32)
#   平均验证损失: 0.0222 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0103 (轮次: 19)
#     种子 2:
#       验证损失: 0.0193 (轮次: 7)
#   平均验证损失: 0.0148 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0287 (轮次: 50)
#     种子 2:
#       验证损失: 0.0209 (轮次: 37)
#   平均验证损失: 0.0248 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0074 (轮次: 16)
#     种子 2:
#       验证损失: 0.0156 (轮次: 8)
#   平均验证损失: 0.0115 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0146 (轮次: 50)
#     种子 2:
#       验证损失: 0.0158 (轮次: 50)
#   平均验证损失: 0.0152 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0099 (轮次: 6)
#     种子 2:
#       验证损失: 0.0148 (轮次: 8)
#   平均验证损失: 0.0123 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0113 (轮次: 50)
#     种子 2:
#       验证损失: 0.0129 (轮次: 48)
#   平均验证损失: 0.0121 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0098 (轮次: 27)
#     种子 2:
#       验证损失: 0.0097 (轮次: 19)
#   平均验证损失: 0.0097 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0341 (轮次: 50)
#     种子 2:
#       验证损失: 0.0124 (轮次: 26)
#   平均验证损失: 0.0232 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0114 (轮次: 17)
#     种子 2:
#       验证损失: 0.0156 (轮次: 8)
#   平均验证损失: 0.0135 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0209 (轮次: 50)
#     种子 2:
#       验证损失: 0.0173 (轮次: 25)
#   平均验证损失: 0.0191 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0252 (轮次: 7)
#     种子 2:
#       验证损失: 0.0062 (轮次: 20)
#   平均验证损失: 0.0157 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0410 (轮次: 50)
#     种子 2:
#       验证损失: 0.0173 (轮次: 50)
#   平均验证损失: 0.0292 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0148 (轮次: 8)
#     种子 2:
#       验证损失: 0.0109 (轮次: 9)
#   平均验证损失: 0.0129 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0281 (轮次: 50)
#     种子 2:
#       验证损失: 0.0177 (轮次: 50)
#   平均验证损失: 0.0229 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0040 (轮次: 12)
#     种子 2:
#       验证损失: 0.0152 (轮次: 8)
#   平均验证损失: 0.0096 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0179 (轮次: 50)
#     种子 2:
#       验证损失: 0.0166 (轮次: 50)
#   平均验证损失: 0.0173 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0084 (轮次: 22)
#     种子 2:
#       验证损失: 0.0166 (轮次: 8)
#   平均验证损失: 0.0125 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0242 (轮次: 50)
#     种子 2:
#       验证损失: 0.0166 (轮次: 50)
#   平均验证损失: 0.0204 (学习率 0.001)
#
# --- 步骤 4 结果 ---
# 选中变量: 'dln_gdp_sa_lag1'
# 最佳平均验证损失: 0.0079
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1']
# 已保存最优模型到Google Drive: 'CNN22_4.keras' (seed 1)
#
# 步骤 5: 选择第 5 个变量
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1']
# 剩余候选变量: ['pc3_lag4', 'dpc2_lag4', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0182 (轮次: 6)
#     种子 2:
#       验证损失: 0.0045 (轮次: 9)
#   平均验证损失: 0.0114 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0226 (轮次: 50)
#     种子 2:
#       验证损失: 0.0059 (轮次: 50)
#   平均验证损失: 0.0143 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0090 (轮次: 18)
#     种子 2:
#       验证损失: 0.0113 (轮次: 4)
#   平均验证损失: 0.0101 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dpc2_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0323 (轮次: 50)
#     种子 2:
#       验证损失: 0.0209 (轮次: 33)
#   平均验证损失: 0.0266 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0107 (轮次: 16)
#     种子 2:
#       验证损失: 0.0042 (轮次: 5)
#   平均验证损失: 0.0074 (学习率 0.01)
#   临时保存步骤 5 最佳模型: 'dln_region_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0408 (轮次: 50)
#     种子 2:
#       验证损失: 0.0110 (轮次: 45)
#   平均验证损失: 0.0259 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0130 (轮次: 15)
#     种子 2:
#       验证损失: 0.0179 (轮次: 5)
#   平均验证损失: 0.0155 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0197 (轮次: 50)
#     种子 2:
#       验证损失: 0.0200 (轮次: 50)
#   平均验证损失: 0.0199 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0162 (轮次: 12)
#     种子 2:
#       验证损失: 0.0066 (轮次: 3)
#   平均验证损失: 0.0114 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0458 (轮次: 50)
#     种子 2:
#       验证损失: 0.0109 (轮次: 32)
#   平均验证损失: 0.0284 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0109 (轮次: 22)
#     种子 2:
#       验证损失: 0.0111 (轮次: 15)
#   平均验证损失: 0.0110 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0396 (轮次: 50)
#     种子 2:
#       验证损失: 0.0149 (轮次: 40)
#   平均验证损失: 0.0272 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0098 (轮次: 12)
#     种子 2:
#       验证损失: 0.0124 (轮次: 4)
#   平均验证损失: 0.0111 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0241 (轮次: 50)
#     种子 2:
#       验证损失: 0.0165 (轮次: 50)
#   平均验证损失: 0.0203 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0334 (轮次: 12)
#     种子 2:
#       验证损失: 0.0066 (轮次: 4)
#   平均验证损失: 0.0200 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0633 (轮次: 50)
#     种子 2:
#       验证损失: 0.0091 (轮次: 43)
#   平均验证损失: 0.0362 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0060 (轮次: 20)
#     种子 2:
#       验证损失: 0.0096 (轮次: 7)
#   平均验证损失: 0.0078 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0128 (轮次: 50)
#     种子 2:
#       验证损失: 0.0080 (轮次: 38)
#   平均验证损失: 0.0104 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0156 (轮次: 14)
#     种子 2:
#       验证损失: 0.0180 (轮次: 8)
#   平均验证损失: 0.0168 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0272 (轮次: 50)
#     种子 2:
#       验证损失: 0.0212 (轮次: 40)
#   平均验证损失: 0.0242 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0078 (轮次: 12)
#     种子 2:
#       验证损失: 0.0107 (轮次: 4)
#   平均验证损失: 0.0093 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0371 (轮次: 50)
#     种子 2:
#       验证损失: 0.0123 (轮次: 38)
#   平均验证损失: 0.0247 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0143 (轮次: 9)
#     种子 2:
#       验证损失: 0.0104 (轮次: 4)
#   平均验证损失: 0.0123 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0274 (轮次: 50)
#     种子 2:
#       验证损失: 0.0156 (轮次: 40)
#   平均验证损失: 0.0215 (学习率 0.001)
#
# --- 步骤 5 结果 ---
# 选中变量: 'dln_region_lag3'
# 最佳平均验证损失: 0.0074
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3']
# 已保存最优模型到Google Drive: 'CNN22_5.keras' (seed 2)
#
# 步骤 6: 选择第 6 个变量
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3']
# 剩余候选变量: ['pc3_lag4', 'dpc2_lag4', 'pc1_lag1', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0077 (轮次: 12)
#     种子 2:
#       验证损失: 0.0115 (轮次: 9)
#   平均验证损失: 0.0096 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 45)
#     种子 2:
#       验证损失: 0.0191 (轮次: 35)
#   平均验证损失: 0.0164 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0091 (轮次: 8)
#     种子 2:
#       验证损失: 0.0074 (轮次: 30)
#   平均验证损失: 0.0083 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'dpc2_lag4', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0139 (轮次: 45)
#     种子 2:
#       验证损失: 0.0170 (轮次: 23)
#   平均验证损失: 0.0154 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0090 (轮次: 4)
#     种子 2:
#       验证损失: 0.0048 (轮次: 17)
#   平均验证损失: 0.0069 (学习率 0.01)
#   临时保存步骤 6 最佳模型: 'pc1_lag1', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0221 (轮次: 37)
#     种子 2:
#       验证损失: 0.0160 (轮次: 50)
#   平均验证损失: 0.0191 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0079 (轮次: 6)
#     种子 2:
#       验证损失: 0.0105 (轮次: 25)
#   平均验证损失: 0.0092 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0094 (轮次: 50)
#     种子 2:
#       验证损失: 0.0203 (轮次: 50)
#   平均验证损失: 0.0148 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0138 (轮次: 8)
#     种子 2:
#       验证损失: 0.0146 (轮次: 13)
#   平均验证损失: 0.0142 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0239 (轮次: 50)
#     种子 2:
#       验证损失: 0.0182 (轮次: 25)
#   平均验证损失: 0.0211 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0088 (轮次: 20)
#     种子 2:
#       验证损失: 0.0220 (轮次: 2)
#   平均验证损失: 0.0154 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0237 (轮次: 50)
#     种子 2:
#       验证损失: 0.0258 (轮次: 23)
#   平均验证损失: 0.0247 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0085 (轮次: 10)
#     种子 2:
#       验证损失: 0.0129 (轮次: 10)
#   平均验证损失: 0.0107 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0163 (轮次: 31)
#     种子 2:
#       验证损失: 0.0201 (轮次: 33)
#   平均验证损失: 0.0182 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0113 (轮次: 11)
#     种子 2:
#       验证损失: 0.0205 (轮次: 6)
#   平均验证损失: 0.0159 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0208 (轮次: 20)
#     种子 2:
#       验证损失: 0.0314 (轮次: 43)
#   平均验证损失: 0.0261 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0118 (轮次: 12)
#     种子 2:
#       验证损失: 0.0120 (轮次: 3)
#   平均验证损失: 0.0119 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0225 (轮次: 22)
#     种子 2:
#       验证损失: 0.0173 (轮次: 43)
#   平均验证损失: 0.0199 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0047 (轮次: 10)
#     种子 2:
#       验证损失: 0.0140 (轮次: 10)
#   平均验证损失: 0.0093 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0124 (轮次: 25)
#     种子 2:
#       验证损失: 0.0250 (轮次: 50)
#   平均验证损失: 0.0187 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0111 (轮次: 20)
#     种子 2:
#       验证损失: 0.0087 (轮次: 10)
#   平均验证损失: 0.0099 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0248 (轮次: 50)
#     种子 2:
#       验证损失: 0.0161 (轮次: 50)
#   平均验证损失: 0.0204 (学习率 0.001)
#
# --- 步骤 6 结果 ---
# 选中变量: 'pc1_lag1'
# 最佳平均验证损失: 0.0069
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1']
# 已保存最优模型到Google Drive: 'CNN22_6.keras' (seed 2)
#
# 步骤 7: 选择第 7 个变量
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1']
# 剩余候选变量: ['pc3_lag4', 'dpc2_lag4', 'dln_gdp_sa_lag3', 'dln_gdp_sa_lag2', 'dln_region_lag2', 'pc3_lag3', 'dpc2_lag3', 'dpc2_lag1', 'pc1_lag4', 'pc3_lag1']
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'pc3_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0066 (轮次: 10)
#     种子 2:
#       验证损失: 0.0102 (轮次: 9)
#   平均验证损失: 0.0084 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'pc3_lag4', 学习率 0.01, 种子 1
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0090 (轮次: 50)
#     种子 2:
#       验证损失: 0.0168 (轮次: 50)
#   平均验证损失: 0.0129 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'dpc2_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0061 (轮次: 16)
#     种子 2:
#       验证损失: 0.0270 (轮次: 10)
#   平均验证损失: 0.0165 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0130 (轮次: 50)
#     种子 2:
#       验证损失: 0.0399 (轮次: 50)
#   平均验证损失: 0.0264 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0055 (轮次: 9)
#     种子 2:
#       验证损失: 0.0453 (轮次: 9)
#   平均验证损失: 0.0254 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0076 (轮次: 50)
#     种子 2:
#       验证损失: 0.0437 (轮次: 50)
#   平均验证损失: 0.0257 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'dln_gdp_sa_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0040 (轮次: 12)
#     种子 2:
#       验证损失: 0.0178 (轮次: 18)
#   平均验证损失: 0.0109 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0075 (轮次: 50)
#     种子 2:
#       验证损失: 0.0384 (轮次: 30)
#   平均验证损失: 0.0230 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'dln_region_lag2']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0079 (轮次: 17)
#     种子 2:
#       验证损失: 0.0160 (轮次: 2)
#   平均验证损失: 0.0120 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0103 (轮次: 50)
#     种子 2:
#       验证损失: 0.0206 (轮次: 26)
#   平均验证损失: 0.0155 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'pc3_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0103 (轮次: 4)
#     种子 2:
#       验证损失: 0.0054 (轮次: 9)
#   平均验证损失: 0.0078 (学习率 0.01)
#   临时保存步骤 7 最佳模型: 'pc3_lag3', 学习率 0.01, 种子 2
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0135 (轮次: 42)
#     种子 2:
#       验证损失: 0.0175 (轮次: 33)
#   平均验证损失: 0.0155 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'dpc2_lag3']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0046 (轮次: 11)
#     种子 2:
#       验证损失: 0.0150 (轮次: 9)
#   平均验证损失: 0.0098 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0074 (轮次: 50)
#     种子 2:
#       验证损失: 0.0183 (轮次: 50)
#   平均验证损失: 0.0128 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'dpc2_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0087 (轮次: 17)
#     种子 2:
#       验证损失: 0.0170 (轮次: 3)
#   平均验证损失: 0.0128 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0156 (轮次: 50)
#     种子 2:
#       验证损失: 0.0231 (轮次: 28)
#   平均验证损失: 0.0193 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'pc1_lag4']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0055 (轮次: 9)
#     种子 2:
#       验证损失: 0.0123 (轮次: 20)
#   平均验证损失: 0.0089 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0136 (轮次: 50)
#     种子 2:
#       验证损失: 0.0289 (轮次: 19)
#   平均验证损失: 0.0213 (学习率 0.001)
#
# 测试变量组合: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'pc3_lag1']
#   学习率: 0.01
#     种子 1:
#       验证损失: 0.0139 (轮次: 14)
#     种子 2:
#       验证损失: 0.0160 (轮次: 9)
#   平均验证损失: 0.0149 (学习率 0.01)
#   学习率: 0.001
#     种子 1:
#       验证损失: 0.0186 (轮次: 50)
#     种子 2:
#       验证损失: 0.0260 (轮次: 50)
#   平均验证损失: 0.0223 (学习率 0.001)
#
# --- 步骤 7 结果 ---
# 选中变量: 'pc3_lag3'
# 最佳平均验证损失: 0.0078
# 最佳学习率: 0.01
# 当前已选变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'pc3_lag3']
# 已保存最优模型到Google Drive: 'CNN22_7.keras' (seed 2)
#
# 前向选择完成
# 最终选中变量: ['dln_city_lag2', 'dln_city_lag1', 'dln_gdp_sa_lag4', 'dln_gdp_sa_lag1', 'dln_region_lag3', 'pc1_lag1', 'pc3_lag3']
# 已保存前向选择结果表格到Google Drive: /content/drive/My Drive/CNN22_results.csv
#
# 前向选择详细结果:
#    Step  Variable number                                 Selected Variables  \
# 0     1                1                                      dln_city_lag2
# 1     2                2                       dln_city_lag2, dln_city_lag1
# 2     3                3      dln_city_lag2, dln_city_lag1, dln_gdp_sa_lag4
# 3     4                4  dln_city_lag2, dln_city_lag1, dln_gdp_sa_lag4,...
# 4     5                5  dln_city_lag2, dln_city_lag1, dln_gdp_sa_lag4,...
# 5     6                6  dln_city_lag2, dln_city_lag1, dln_gdp_sa_lag4,...
# 6     7                7  dln_city_lag2, dln_city_lag1, dln_gdp_sa_lag4,...
#
#    Best average Val Loss  Best average LR  seed 1 Val Loss  \
# 0               0.004163             0.01         0.002445
# 1               0.003269             0.01         0.002601
# 2               0.004656             0.01         0.003744
# 3               0.007856             0.01         0.002983
# 4               0.007439             0.01         0.010667
# 5               0.006916             0.01         0.009022
# 6               0.007816             0.01         0.010266
#
#    seed 1 Epochs Used  seed 2 Val Loss  seed 2 Epochs Used
# 0                  13         0.005880                   7
# 1                  15         0.003936                   7
# 2                  12         0.005569                   6
# 3                  12         0.012729                   8
# 4                  16         0.004211                   5
# 5                   4         0.004811                  17
# 6                   4         0.005366                   9
